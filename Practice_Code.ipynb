# %% [markdown]
# <a href="https://colab.research.google.com/github/RahulBattula/Bird-Audio-Classification/blob/main/Practice_Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# $\huge \color{#1C110A}{\textbf{Bird's Audio Classification}}$

# %%
import pandas as pd
import os
import librosa

audio_dataset_path='/content/wavfiles'
metadata=pd.read_csv('/content/bird_songs_metadata.csv',usecols=['name','filename'])
metadata.head()
# Out:
#             name      filename
# 0  Bewick's Wren  557838-0.wav
# 1  Bewick's Wren  557838-1.wav
# 2  Bewick's Wren  557838-4.wav
# 3  Bewick's Wren  557838-5.wav
# 4  Bewick's Wren  557838-6.wav

# %%
metadata['name'].value_counts()
# Out:
# Song Sparrow            1256
# Northern Mockingbird    1182
# Northern Cardinal       1074
# American Robin          1017
# Bewick's Wren            893
# Name: name, dtype: int64

# %%
import os
os.environ['KAGGLE_USERNAME'] = 'rahulbattula1'
os.environ['KAGGLE_KEY'] = '7220f5ccf343309b5f337d6ad9b49afc'

# %%
# !kaggle datasets download -d vinayshanbhag/bird-song-data-set

# %%
# !unzip bird-song-data-set.zip

# %%
ls -l ./wavfiles/ | grep -c ^-
# Out:
# 9107

# %%
import os
import librosa
import pandas as pd

audio_folder = "/content/wavfiles"
metadata = pd.read_csv('/content/bird_songs_metadata.csv', usecols=['name', 'filename'])

# Function to calculate audio duration and print files with 3 seconds duration
def get_audio_duration(row):
    file_path = os.path.join(audio_folder, row['filename'])

    # Check if the file exists
    if os.path.exists(file_path):
        try:
            audio_data, _ = librosa.load(file_path, sr=None)
            duration = librosa.get_duration(y=audio_data)

            return duration
        except Exception as e:
            print(f"Error processing {file_path}: {e}")
            return None
    else:
        print(f"File not found: {file_path}")
        return None

# Calculating duration for each audio file
metadata['duration'] = metadata.apply(get_audio_duration, axis=1)

count_greater_than_3s = (metadata['duration'] > 3).sum()
count_less_than_3s = (metadata['duration'] < 3).sum()
count_equal_to_3s = (metadata['duration'] == 3).sum()

print(f"Number of files with duration greater than 3 seconds: {count_greater_than_3s}")
print(f"Number of files with duration less than 3 seconds: {count_less_than_3s}")
print(f"Number of files with duration equal to 3 seconds: {count_equal_to_3s}")
# Out:
# Number of files with duration greater than 3 seconds: 0
# Number of files with duration less than 3 seconds: 0
# Number of files with duration equal to 3 seconds: 5422

# %%
import random
from scipy.io import wavfile
from IPython.display import Audio, display
import matplotlib.pyplot as plt

audio_folder = "/content/wavfiles"

def plot_and_play_wav(metadata, audio_folder):
    random_row = metadata.sample(n=1).iloc[0]
    audio_file_path = os.path.join(audio_folder, random_row['filename'])

    sample_rate, audio_data = wavfile.read(audio_file_path)
    random_color = '#%06x' % random.randint(0, 0xFFFFFF)

    print(f"Species: {random_row['name']}")
    print(f"Sample rate: {sample_rate}")
    print(f"Bit depth: {audio_data.dtype.itemsize * 8} bits")
    print(f"Bit rate: {sample_rate * audio_data.dtype.itemsize * 8} bps")
    print(f"Number of channels: {audio_data.shape[1] if len(audio_data.shape) > 1 else 1}")
    print(f"Audio data shape: {audio_data.shape}")
    print(f"Audio file path: {audio_file_path}")

    plt.figure(figsize=(8, 3))
    plt.plot(audio_data, color=random_color)
    plt.xlabel("Time (samples)")
    plt.ylabel("Amplitude")
    plt.title(f"Waveform - {random_row['name']}")
    plt.show()

    # Play the audio file
    display(Audio(audio_file_path))

# Iterate through each unique species and plot a random waveform
unique_species = metadata['name'].unique()
for species in unique_species:
    species_metadata = metadata[metadata['name'] == species]
    plot_and_play_wav(species_metadata, audio_folder)
# Out:
# Species: Bewick's Wren
# Sample rate: 22050
# Bit depth: 32 bits
# Bit rate: 705600 bps
# Number of channels: 1
# Audio data shape: (66150,)
# Audio file path: /content/wavfiles/61472-2.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Species: Northern Mockingbird
# Sample rate: 22050
# Bit depth: 32 bits
# Bit rate: 705600 bps
# Number of channels: 1
# Audio data shape: (66150,)
# Audio file path: /content/wavfiles/192423-8.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Species: American Robin
# Sample rate: 22050
# Bit depth: 32 bits
# Bit rate: 705600 bps
# Number of channels: 1
# Audio data shape: (66150,)
# Audio file path: /content/wavfiles/351861-0.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Species: Song Sparrow
# Sample rate: 22050
# Bit depth: 32 bits
# Bit rate: 705600 bps
# Number of channels: 1
# Audio data shape: (66150,)
# Audio file path: /content/wavfiles/358837-5.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Species: Northern Cardinal
# Sample rate: 22050
# Bit depth: 32 bits
# Bit rate: 705600 bps
# Number of channels: 1
# Audio data shape: (66150,)
# Audio file path: /content/wavfiles/172437-8.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# $\Large \color{blue}{\texttt{MFCC}}$

# %%
def features_extractor(file):
    audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast')
    mfccs_features = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=21)
    mfccs_scaled_features = np.mean(mfccs_features.T,axis=0)
    return mfccs_scaled_features

# %%
import numpy as np
from tqdm import tqdm
extracted_features=[]
for index_num,row in tqdm(metadata.iterrows()):
    file_name = os.path.join(os.path.abspath(audio_dataset_path), str(row["filename"]))
    final_class_labels=row["name"]
    data=features_extractor(file_name)
    extracted_features.append([data,final_class_labels])
# Out:
# 5422it [01:22, 65.60it/s]

# %%
extracted_features_df=pd.DataFrame(extracted_features,columns=['feature','class'])
extracted_features_df.head()
# Out:
#                                              feature          class
# 0  [-132.85225, 81.13991, 17.018225, 54.974297, -...  Bewick's Wren
# 1  [-147.74393, 99.42544, 20.885645, 44.11881, 1....  Bewick's Wren
# 2  [-92.42778, 84.10636, 17.362778, 53.86046, -8....  Bewick's Wren
# 3  [-93.07557, 81.17431, 16.225544, 52.088425, -8...  Bewick's Wren
# 4  [-107.959145, 92.416, 17.773256, 43.13245, -1....  Bewick's Wren

# %%
extracted_features_df['feature'].shape
# Out:
# (5422,)

# %%
extracted_features_df['feature'][0].shape
# Out:
# (21,)

# %%
pd.DataFrame(extracted_features_df['feature'][0])
# Out:
#              0
# 0  -132.852249
# 1    81.139908
# 2    17.018225
# 3    54.974297
# 4   -10.344643
# 5    24.577351
# 6     3.074978
# 7    19.339340
# 8     5.271629
# 9    15.171051
# 10   -0.072439
# 11    7.569126
# 12   10.887994
# 13    2.635523
# 14   -0.179219
# 15   10.019793
# 16   -4.870444
# 17    4.988724
# 18   -3.737550
# 19    6.274313
# 20   -1.888968

# %%
type(extracted_features_df['feature'])
# Out:
# pandas.core.series.Series

# %%
X=np.array(extracted_features_df['feature'].tolist())
y=np.array(extracted_features_df['class'].tolist())

# %%
type(X)
# Out:
# numpy.ndarray

# %%
X.shape
# Out:
# (5422, 21)

# %%
X[0]
# Out:
# array([-1.3285225e+02,  8.1139908e+01,  1.7018225e+01,  5.4974297e+01,
#        -1.0344643e+01,  2.4577351e+01,  3.0749784e+00,  1.9339340e+01,
#         5.2716293e+00,  1.5171051e+01, -7.2438858e-02,  7.5691257e+00,
#         1.0887994e+01,  2.6355228e+00, -1.7921886e-01,  1.0019793e+01,
#        -4.8704443e+00,  4.9887242e+00, -3.7375500e+00,  6.2743134e+00,
#        -1.8889681e+00], dtype=float32)

# %%
y.shape
# Out:
# (5422,)

# %%
y[0:10]
# Out:
# array(["Bewick's Wren", "Bewick's Wren", "Bewick's Wren", "Bewick's Wren",
#        "Bewick's Wren", "Bewick's Wren", "Bewick's Wren", "Bewick's Wren",
#        "Bewick's Wren", "Bewick's Wren"], dtype='<U20')

# %%
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
labelencoder=LabelEncoder()
y=to_categorical(labelencoder.fit_transform(y))

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
X_train
# Out:
# array([[-271.31616  ,  -26.419064 ,  -63.76474  , ...,    3.886096 ,
#            0.5488589,   -2.5603206],
#        [-401.3699   ,  -31.111534 ,  -92.245224 , ...,   -5.4280133,
#           -4.4046926,   -6.6012044],
#        [-366.7505   ,   -3.9161208, -118.178535 , ...,    5.0247483,
#           -4.953003 ,    3.951971 ],
#        ...,
#        [ -63.003605 ,   88.0372   ,  -30.77855  , ...,   -8.846015 ,
#           -8.056691 ,  -10.128775 ],
#        [-361.9076   ,   30.67692  ,  -64.73752  , ...,   -7.2064624,
#            3.933869 ,    9.0967455],
#        [-168.7206   ,    1.3105384,  -65.46302  , ...,   -5.7669735,
#           -2.3251848,   -5.445334 ]], dtype=float32)

# %%
X_train.shape
# Out:
# (4337, 21)

# %%
X_test.shape
# Out:
# (1085, 21)

# %%
y_train.shape
# Out:
# (4337, 5)

# %%
y_test.shape
# Out:
# (1085, 5)

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.15.0

# %%
from tensorflow.keras.models import Sequential,Model
from tensorflow.keras.layers import Dense,Dropout,Activation,Flatten,LSTM, Input, Conv1D, MaxPooling1D
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import Adam
from sklearn import metrics
import warnings
warnings.filterwarnings('ignore')

# %%
num_labels=y.shape[1]

# %%
num_labels
# Out:
# 5

# %% [markdown]
# $\Large \color{orange}{\texttt{Sequential}}$

# %%
model=Sequential()
###first layer
model.add(Dense(100,input_shape=(21,)))
model.add(Activation('relu'))
model.add(Dropout(0.5))
###second layer
model.add(Dense(200))
model.add(Activation('relu'))
model.add(Dropout(0.5))
###third layer
model.add(Dense(100))
model.add(Activation('relu'))
model.add(Dropout(0.5))
###final layer
model.add(Dense(num_labels))
model.add(Activation('softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 100)               2200
#
#  activation (Activation)     (None, 100)               0
#
#  dropout (Dropout)           (None, 100)               0
#
#  dense_1 (Dense)             (None, 200)               20200
#
#  activation_1 (Activation)   (None, 200)               0
#
#  dropout_1 (Dropout)         (None, 200)               0
#
#  dense_2 (Dense)             (None, 100)               20100
#
#  activation_2 (Activation)   (None, 100)               0
#
#  dropout_2 (Dropout)         (None, 100)               0
#
#  dense_3 (Dense)             (None, 5)                 505
#
#  activation_3 (Activation)   (None, 5)                 0
#
# =================================================================
# Total params: 43005 (167.99 KB)
# Trainable params: 43005 (167.99 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',metrics=['accuracy'],optimizer='adam')

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
from datetime import datetime
checkpointer = ModelCheckpoint(filepath='saved_models/audio_classification_sequential.hdf5',
                               verbose=1, save_best_only=True)
np.save("sequential_labelencoder.npy", labelencoder.classes_)
start = datetime.now()

history = model.fit(X_train, y_train, batch_size=32, epochs=100,
                    validation_data=(X_test, y_test), callbacks=[checkpointer], verbose=1)

duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Epoch 1/100
# 128/136 [===========================>..] - ETA: 0s - loss: 13.1953 - accuracy: 0.2078
# Epoch 1: val_loss improved from inf to 1.51771, saving model to saved_models/audio_classification_sequential.hdf5
# 136/136 [==============================] - 4s 6ms/step - loss: 12.7495 - accuracy: 0.2061 - val_loss: 1.5177 - val_accuracy: 0.3041
# Epoch 2/100
# 126/136 [==========================>...] - ETA: 0s - loss: 3.0204 - accuracy: 0.2463
# Epoch 2: val_loss did not improve from 1.51771
# 136/136 [==============================] - 1s 5ms/step - loss: 2.9586 - accuracy: 0.2442 - val_loss: 1.5964 - val_accuracy: 0.2406
# Epoch 3/100
# 125/136 [==========================>...] - ETA: 0s - loss: 1.9180 - accuracy: 0.2395
# Epoch 3: val_loss did not improve from 1.51771
# 136/136 [==============================] - 1s 5ms/step - loss: 1.9124 - accuracy: 0.2384 - val_loss: 1.5943 - val_accuracy: 0.2240
# Epoch 4/100
# 127/136 [===========================>..] - ETA: 0s - loss: 1.7108 - accuracy: 0.2542
# Epoch 4: val_loss did not improve from 1.51771
# 136/136 [==============================] - 1s 5ms/step - loss: 1.7121 - accuracy: 0.2527 - val_loss: 1.5870 - val_accuracy: 0.2249
# Epoch 5/100
# 131/136 [===========================>..] - ETA: 0s - loss: 1.6331 - accuracy: 0.2483
# Epoch 5: val_loss did not improve from 1.51771
# 136/136 [==============================] - 1s 4ms/step - loss: 1.6290 - accuracy: 0.2499 - val_loss: 1.5635 - val_accuracy: 0.2387
# Epoch 6/100
# 127/136 [===========================>..] - ETA: 0s - loss: 1.5917 - accuracy: 0.2630
# Epoch 6: val_loss improved from 1.51771 to 1.50290, saving model to saved_models/audio_classification_sequential.hdf5
# 136/136 [==============================] - 1s 4ms/step - loss: 1.5890 - accuracy: 0.2633 - val_loss: 1.5029 - val_accuracy: 0.3097
# Epoch 7/100
# 130/136 [===========================>..] - ETA: 0s - loss: 1.5329 - accuracy: 0.3024
# Epoch 7: val_loss improved from 1.50290 to 1.40001, saving model to saved_models/audio_classification_sequential.hdf5
# 136/136 [==============================] - 1s 4ms/step - loss: 1.5305 - accuracy: 0.3018 - val_loss: 1.4000 - val_accuracy: 0.3825
# Epoch 8/100
# 131/136 [===========================>..] - ETA: 0s - loss: 1.4812 - accuracy: 0.3182
# Epoch 8: val_loss improved from 1.40001 to 1.31110, saving model to saved_models/audio_classification_sequential.hdf5
# 136/136 [==============================] - 1s 4ms/step - loss: 1.4806 - accuracy: 0.3180 - val_loss: 1.3111 - val_accuracy: 0.3963
# Epoch 9/100
# 129/136 [===========================>..] - ETA: 0s - loss: 1.4333 - accuracy: 0.3484
# Epoch 9: val_loss improved from 1.31110 to 1.24907, saving model to saved_models/audio_classification_sequential.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 1.4377 - accuracy: 0.3470 - val_loss: 1.2491 - val_accuracy: 0.3908
# Epoch 10/100
# 131/136 [===========================>..] - ETA: 0s - loss: 1.4078 - accuracy: 0.3571
# Epoch 10: val_loss improved from 1.24907 to 1.23287, saving model to saved_models/audio_classification_sequential.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 1.4080 - accuracy: 0.3555 - val_loss: 1.2329 - val_accuracy: 0.3862
# Epoch 11/100
# 128/136 [===========================>..] - ETA: 0s - loss: 1.3548 - accuracy: 0.3718
# Epoch 11: val_loss improved from 1.23287 to 1.21051, saving model to saved_models/audio_classification_sequential.hdf5
# 136/136 [==============================] - 1s 4ms/step - loss: 1.3639 - accuracy: 0.3708 - val_loss: 1.2105 - val_accuracy: 0.3926
# Epoch 12/100
# 132/136 [============================>.] - ETA: 0s - loss: 1.3294 - accuracy: 0.3674
# Epoch 12: val_loss improved from 1.21051 to 1.19346, saving model to saved_models/audio_classification_sequential.hdf5
# 136/136 [==============================] - 1s 4ms/step - loss: 1.3304 - accuracy: 0.3671 - val_loss: 1.1935 - val_accuracy: 0.4083
# Epoch 13/100
# 131/136 [===========================>..] - ETA: 0s - loss: 1.3376 - accuracy: 0.3683
# Epoch 13: val_loss did not improve from 1.19346
# 136/136 [==============================] - 1s 5ms/step - loss: 1.3362 - accuracy: 0.3715 - val_loss: 1.1941 - val_accuracy: 0.3982
# Epoch 14/100
# 131/136 [===========================>..] - ETA: 0s - loss: 1.3274 - accuracy: 0.3731
# Epoch 14: val_loss did not improve from 1.19346
# 136/136 [==============================] - 1s 4ms/step - loss: 1.3293 - accuracy: 0.3724 - val_loss: 1.1945 - val_accuracy: 0.4157
# Epoch 15/100
# 128/136 [===========================>..] - ETA: 0s - loss: 1.3047 - accuracy: 0.3701
# Epoch 15: val_loss improved from 1.19346 to 1.18502, saving model to saved_models/audio_classification_sequential.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 1.3055 - accuracy: 0.3694 - val_loss: 1.1850 - val_accuracy: 0.4028
# Epoch 16/100
# 128/136 [===========================>..] - ETA: 0s - loss: 1.2918 - accuracy: 0.3862
# Epoch 16: val_loss did not improve from 1.18502
# 136/136 [==============================] - 1s 6ms/step - loss: 1.2940 - accuracy: 0.3855 - val_loss: 1.1859 - val_accuracy: 0.4046
# Epoch 17/100
# 136/136 [==============================] - ETA: 0s - loss: 1.2730 - accuracy: 0.3871
# Epoch 17: val_loss improved from 1.18502 to 1.16640, saving model to saved_models/audio_classification_sequential.hdf5
# 136/136 [==============================] - 1s 6ms/step - loss: 1.2730 - accuracy: 0.3871 - val_loss: 1.1664 - val_accuracy: 0.4203
# Epoch 18/100
# 131/136 [===========================>..] - ETA: 0s - loss: 1.2670 - accuracy: 0.3967
# Epoch 18: val_loss improved from 1.16640 to 1.15582, saving model to saved_models/audio_classification_sequential.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 1.2660 - accuracy: 0.3961 - val_loss: 1.1558 - val_accuracy: 0.4378
# Epoch 19/100
# 131/136 [===========================>..] - ETA: 0s - loss: 1.2705 - accuracy: 0.3910
# Epoch 19: val_loss improved from 1.15582 to 1.14700, saving model to saved_models/audio_classification_sequential.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 1.2722 - accuracy: 0.3908 - val_loss: 1.1470 - val_accuracy: 0.4323
# Epoch 20/100
# 131/136 [===========================>..] - ETA: 0s - loss: 1.2503 - accuracy: 0.4129
# Epoch 20: val_loss improved from 1.14700 to 1.11706, saving model to saved_models/audio_classification_sequential.hdf5
# 136/136 [==============================] - 1s 4ms/step - loss: 1.2515 - accuracy: 0.4141 - val_loss: 1.1171 - val_accuracy: 0.4636
# Epoch 21/100
# 130/136 [===========================>..] - ETA: 0s - loss: 1.2362 - accuracy: 0.4125
# Epoch 21: val_loss did not improve from 1.11706
# 136/136 [==============================] - 1s 4ms/step - loss: 1.2388 - accuracy: 0.4139 - val_loss: 1.1178 - val_accuracy: 0.4700
# Epoch 22/100
# 129/136 [===========================>..] - ETA: 0s - loss: 1.2171 - accuracy: 0.4331
# Epoch 22: val_loss improved from 1.11706 to 1.09296, saving model to saved_models/audio_classification_sequential.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 1.2156 - accuracy: 0.4321 - val_loss: 1.0930 - val_accuracy: 0.4959
# Epoch 23/100
# 136/136 [==============================] - ETA: 0s - loss: 1.2000 - accuracy: 0.4349
# Epoch 23: val_loss improved from 1.09296 to 1.08754, saving model to saved_models/audio_classification_sequential.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 1.2000 - accuracy: 0.4349 - val_loss: 1.0875 - val_accuracy: 0.4728
# Epoch 24/100
# 130/136 [===========================>..] - ETA: 0s - loss: 1.1798 - accuracy: 0.4565
# Epoch 24: val_loss improved from 1.08754 to 1.04027, saving model to saved_models/audio_classification_sequential.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 1.1808 - accuracy: 0.4572 - val_loss: 1.0403 - val_accuracy: 0.5512
# Epoch 25/100
# 135/136 [============================>.] - ETA: 0s - loss: 1.1599 - accuracy: 0.4618
# Epoch 25: val_loss improved from 1.04027 to 1.02978, saving model to saved_models/audio_classification_sequential.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 1.1602 - accuracy: 0.4611 - val_loss: 1.0298 - val_accuracy: 0.5189
# Epoch 26/100
# 126/136 [==========================>...] - ETA: 0s - loss: 1.1364 - accuracy: 0.4638
# Epoch 26: val_loss improved from 1.02978 to 1.00504, saving model to saved_models/audio_classification_sequential.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 1.1367 - accuracy: 0.4658 - val_loss: 1.0050 - val_accuracy: 0.5152
# Epoch 27/100
# 133/136 [============================>.] - ETA: 0s - loss: 1.1265 - accuracy: 0.4845
# Epoch 27: val_loss did not improve from 1.00504
# 136/136 [==============================] - 1s 5ms/step - loss: 1.1287 - accuracy: 0.4842 - val_loss: 1.0061 - val_accuracy: 0.5097
# Epoch 28/100
# 126/136 [==========================>...] - ETA: 0s - loss: 1.1224 - accuracy: 0.4814
# Epoch 28: val_loss improved from 1.00504 to 0.96533, saving model to saved_models/audio_classification_sequential.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 1.1190 - accuracy: 0.4819 - val_loss: 0.9653 - val_accuracy: 0.5180
# Epoch 29/100
# 126/136 [==========================>...] - ETA: 0s - loss: 1.1174 - accuracy: 0.4990
# Epoch 29: val_loss did not improve from 0.96533
# 136/136 [==============================] - 1s 5ms/step - loss: 1.1100 - accuracy: 0.4978 - val_loss: 0.9721 - val_accuracy: 0.5567
# Epoch 30/100
# 131/136 [===========================>..] - ETA: 0s - loss: 1.1048 - accuracy: 0.4959
# Epoch 30: val_loss did not improve from 0.96533
# 136/136 [==============================] - 1s 5ms/step - loss: 1.1099 - accuracy: 0.4953 - val_loss: 0.9960 - val_accuracy: 0.5650
# Epoch 31/100
# 126/136 [==========================>...] - ETA: 0s - loss: 1.0902 - accuracy: 0.5032
# Epoch 31: val_loss improved from 0.96533 to 0.95449, saving model to saved_models/audio_classification_sequential.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 1.0927 - accuracy: 0.4999 - val_loss: 0.9545 - val_accuracy: 0.5733
# Epoch 32/100
# 123/136 [==========================>...] - ETA: 0s - loss: 1.0829 - accuracy: 0.4970
# Epoch 32: val_loss improved from 0.95449 to 0.93857, saving model to saved_models/audio_classification_sequential.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 1.0859 - accuracy: 0.5001 - val_loss: 0.9386 - val_accuracy: 0.5751
# Epoch 33/100
# 127/136 [===========================>..] - ETA: 0s - loss: 1.0636 - accuracy: 0.5145
# Epoch 33: val_loss did not improve from 0.93857
# 136/136 [==============================] - 1s 5ms/step - loss: 1.0625 - accuracy: 0.5146 - val_loss: 0.9394 - val_accuracy: 0.5779
# Epoch 34/100
# 136/136 [==============================] - ETA: 0s - loss: 1.0453 - accuracy: 0.5176
# Epoch 34: val_loss improved from 0.93857 to 0.89892, saving model to saved_models/audio_classification_sequential.hdf5
# 136/136 [==============================] - 1s 6ms/step - loss: 1.0453 - accuracy: 0.5176 - val_loss: 0.8989 - val_accuracy: 0.5853
# Epoch 35/100
# 136/136 [==============================] - ETA: 0s - loss: 1.0533 - accuracy: 0.5239
# Epoch 35: val_loss did not improve from 0.89892
# 136/136 [==============================] - 1s 6ms/step - loss: 1.0533 - accuracy: 0.5239 - val_loss: 0.9188 - val_accuracy: 0.5622
# Epoch 36/100
# 135/136 [============================>.] - ETA: 0s - loss: 1.0421 - accuracy: 0.5262
# Epoch 36: val_loss did not improve from 0.89892
# 136/136 [==============================] - 1s 5ms/step - loss: 1.0419 - accuracy: 0.5262 - val_loss: 0.9154 - val_accuracy: 0.5908
# Epoch 37/100
# 128/136 [===========================>..] - ETA: 0s - loss: 1.0386 - accuracy: 0.5249
# Epoch 37: val_loss did not improve from 0.89892
# 136/136 [==============================] - 1s 5ms/step - loss: 1.0372 - accuracy: 0.5280 - val_loss: 0.9157 - val_accuracy: 0.5991
# Epoch 38/100
# 136/136 [==============================] - ETA: 0s - loss: 1.0111 - accuracy: 0.5379
# Epoch 38: val_loss improved from 0.89892 to 0.88072, saving model to saved_models/audio_classification_sequential.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 1.0111 - accuracy: 0.5379 - val_loss: 0.8807 - val_accuracy: 0.6111
# Epoch 39/100
# 127/136 [===========================>..] - ETA: 0s - loss: 1.0242 - accuracy: 0.5490
# Epoch 39: val_loss improved from 0.88072 to 0.87687, saving model to saved_models/audio_classification_sequential.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 1.0246 - accuracy: 0.5460 - val_loss: 0.8769 - val_accuracy: 0.6111
# Epoch 40/100
# 131/136 [===========================>..] - ETA: 0s - loss: 1.0155 - accuracy: 0.5484
# Epoch 40: val_loss did not improve from 0.87687
# 136/136 [==============================] - 1s 5ms/step - loss: 1.0159 - accuracy: 0.5483 - val_loss: 0.8907 - val_accuracy: 0.6092
# Epoch 41/100
# 130/136 [===========================>..] - ETA: 0s - loss: 1.0115 - accuracy: 0.5502
# Epoch 41: val_loss improved from 0.87687 to 0.85524, saving model to saved_models/audio_classification_sequential.hdf5
# 136/136 [==============================] - 1s 4ms/step - loss: 1.0085 - accuracy: 0.5511 - val_loss: 0.8552 - val_accuracy: 0.6249
# Epoch 42/100
# 129/136 [===========================>..] - ETA: 0s - loss: 1.0091 - accuracy: 0.5506
# Epoch 42: val_loss did not improve from 0.85524
# 136/136 [==============================] - 1s 4ms/step - loss: 1.0092 - accuracy: 0.5522 - val_loss: 0.8702 - val_accuracy: 0.6221
# Epoch 43/100
# 132/136 [============================>.] - ETA: 0s - loss: 0.9986 - accuracy: 0.5518
# Epoch 43: val_loss improved from 0.85524 to 0.84769, saving model to saved_models/audio_classification_sequential.hdf5
# 136/136 [==============================] - 1s 4ms/step - loss: 0.9998 - accuracy: 0.5534 - val_loss: 0.8477 - val_accuracy: 0.6323
# Epoch 44/100
# 128/136 [===========================>..] - ETA: 0s - loss: 0.9778 - accuracy: 0.5654
# Epoch 44: val_loss improved from 0.84769 to 0.83891, saving model to saved_models/audio_classification_sequential.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 0.9747 - accuracy: 0.5693 - val_loss: 0.8389 - val_accuracy: 0.6507
# Epoch 45/100
# 130/136 [===========================>..] - ETA: 0s - loss: 0.9628 - accuracy: 0.5702
# Epoch 45: val_loss improved from 0.83891 to 0.82505, saving model to saved_models/audio_classification_sequential.hdf5
# 136/136 [==============================] - 1s 4ms/step - loss: 0.9611 - accuracy: 0.5716 - val_loss: 0.8250 - val_accuracy: 0.6341
# Epoch 46/100
# 124/136 [==========================>...] - ETA: 0s - loss: 0.9539 - accuracy: 0.5696
# Epoch 46: val_loss did not improve from 0.82505
# 136/136 [==============================] - 1s 4ms/step - loss: 0.9511 - accuracy: 0.5700 - val_loss: 0.8290 - val_accuracy: 0.6221
# Epoch 47/100
# 133/136 [============================>.] - ETA: 0s - loss: 0.9536 - accuracy: 0.5742
# Epoch 47: val_loss improved from 0.82505 to 0.81293, saving model to saved_models/audio_classification_sequential.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 0.9547 - accuracy: 0.5730 - val_loss: 0.8129 - val_accuracy: 0.6516
# Epoch 48/100
# 132/136 [============================>.] - ETA: 0s - loss: 0.9455 - accuracy: 0.5755
# Epoch 48: val_loss did not improve from 0.81293
# 136/136 [==============================] - 1s 5ms/step - loss: 0.9447 - accuracy: 0.5739 - val_loss: 0.8170 - val_accuracy: 0.6424
# Epoch 49/100
# 126/136 [==========================>...] - ETA: 0s - loss: 0.9513 - accuracy: 0.5853
# Epoch 49: val_loss improved from 0.81293 to 0.79600, saving model to saved_models/audio_classification_sequential.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 0.9514 - accuracy: 0.5824 - val_loss: 0.7960 - val_accuracy: 0.6710
# Epoch 50/100
# 130/136 [===========================>..] - ETA: 0s - loss: 0.9446 - accuracy: 0.5755
# Epoch 50: val_loss did not improve from 0.79600
# 136/136 [==============================] - 1s 5ms/step - loss: 0.9426 - accuracy: 0.5774 - val_loss: 0.8025 - val_accuracy: 0.6461
# Epoch 51/100
# 135/136 [============================>.] - ETA: 0s - loss: 0.9179 - accuracy: 0.5868
# Epoch 51: val_loss did not improve from 0.79600
# 136/136 [==============================] - 1s 6ms/step - loss: 0.9172 - accuracy: 0.5870 - val_loss: 0.7980 - val_accuracy: 0.6415
# Epoch 52/100
# 130/136 [===========================>..] - ETA: 0s - loss: 0.9247 - accuracy: 0.6012
# Epoch 52: val_loss improved from 0.79600 to 0.76754, saving model to saved_models/audio_classification_sequential.hdf5
# 136/136 [==============================] - 1s 7ms/step - loss: 0.9267 - accuracy: 0.6006 - val_loss: 0.7675 - val_accuracy: 0.6811
# Epoch 53/100
# 136/136 [==============================] - ETA: 0s - loss: 0.9054 - accuracy: 0.6078
# Epoch 53: val_loss did not improve from 0.76754
# 136/136 [==============================] - 1s 10ms/step - loss: 0.9054 - accuracy: 0.6078 - val_loss: 0.7734 - val_accuracy: 0.6507
# Epoch 54/100
# 124/136 [==========================>...] - ETA: 0s - loss: 0.9047 - accuracy: 0.6109
# Epoch 54: val_loss did not improve from 0.76754
# 136/136 [==============================] - 1s 5ms/step - loss: 0.9057 - accuracy: 0.6089 - val_loss: 0.7712 - val_accuracy: 0.6553
# Epoch 55/100
# 125/136 [==========================>...] - ETA: 0s - loss: 0.9010 - accuracy: 0.6110
# Epoch 55: val_loss improved from 0.76754 to 0.75700, saving model to saved_models/audio_classification_sequential.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 0.9037 - accuracy: 0.6108 - val_loss: 0.7570 - val_accuracy: 0.6977
# Epoch 56/100
# 130/136 [===========================>..] - ETA: 0s - loss: 0.8918 - accuracy: 0.6185
# Epoch 56: val_loss did not improve from 0.75700
# 136/136 [==============================] - 1s 4ms/step - loss: 0.8940 - accuracy: 0.6161 - val_loss: 0.7647 - val_accuracy: 0.6820
# Epoch 57/100
# 127/136 [===========================>..] - ETA: 0s - loss: 0.8811 - accuracy: 0.6206
# Epoch 57: val_loss did not improve from 0.75700
# 136/136 [==============================] - 1s 4ms/step - loss: 0.8797 - accuracy: 0.6193 - val_loss: 0.7701 - val_accuracy: 0.6627
# Epoch 58/100
# 135/136 [============================>.] - ETA: 0s - loss: 0.8832 - accuracy: 0.6225
# Epoch 58: val_loss improved from 0.75700 to 0.75400, saving model to saved_models/audio_classification_sequential.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 0.8837 - accuracy: 0.6223 - val_loss: 0.7540 - val_accuracy: 0.6903
# Epoch 59/100
# 136/136 [==============================] - ETA: 0s - loss: 0.8721 - accuracy: 0.6133
# Epoch 59: val_loss improved from 0.75400 to 0.74783, saving model to saved_models/audio_classification_sequential.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 0.8721 - accuracy: 0.6133 - val_loss: 0.7478 - val_accuracy: 0.6737
# Epoch 60/100
# 136/136 [==============================] - ETA: 0s - loss: 0.8666 - accuracy: 0.6341
# Epoch 60: val_loss did not improve from 0.74783
# 136/136 [==============================] - 1s 6ms/step - loss: 0.8666 - accuracy: 0.6341 - val_loss: 0.7561 - val_accuracy: 0.6737
# Epoch 61/100
# 134/136 [============================>.] - ETA: 0s - loss: 0.8708 - accuracy: 0.6269
# Epoch 61: val_loss improved from 0.74783 to 0.74094, saving model to saved_models/audio_classification_sequential.hdf5
# 136/136 [==============================] - 1s 7ms/step - loss: 0.8693 - accuracy: 0.6276 - val_loss: 0.7409 - val_accuracy: 0.7088
# Epoch 62/100
# 131/136 [===========================>..] - ETA: 0s - loss: 0.8424 - accuracy: 0.6446
# Epoch 62: val_loss improved from 0.74094 to 0.72145, saving model to saved_models/audio_classification_sequential.hdf5
# 136/136 [==============================] - 1s 7ms/step - loss: 0.8463 - accuracy: 0.6431 - val_loss: 0.7214 - val_accuracy: 0.7198
# Epoch 63/100
# 125/136 [==========================>...] - ETA: 0s - loss: 0.8525 - accuracy: 0.6357
# Epoch 63: val_loss did not improve from 0.72145
# 136/136 [==============================] - 1s 5ms/step - loss: 0.8668 - accuracy: 0.6327 - val_loss: 0.7342 - val_accuracy: 0.6995
# Epoch 64/100
# 133/136 [============================>.] - ETA: 0s - loss: 0.8551 - accuracy: 0.6353
# Epoch 64: val_loss did not improve from 0.72145
# 136/136 [==============================] - 1s 5ms/step - loss: 0.8569 - accuracy: 0.6355 - val_loss: 0.7359 - val_accuracy: 0.7171
# Epoch 65/100
# 134/136 [============================>.] - ETA: 0s - loss: 0.8521 - accuracy: 0.6378
# Epoch 65: val_loss did not improve from 0.72145
# 136/136 [==============================] - 1s 5ms/step - loss: 0.8523 - accuracy: 0.6382 - val_loss: 0.7338 - val_accuracy: 0.7051
# Epoch 66/100
# 126/136 [==========================>...] - ETA: 0s - loss: 0.8349 - accuracy: 0.6362
# Epoch 66: val_loss did not improve from 0.72145
# 136/136 [==============================] - 1s 5ms/step - loss: 0.8335 - accuracy: 0.6362 - val_loss: 0.7240 - val_accuracy: 0.7106
# Epoch 67/100
# 133/136 [============================>.] - ETA: 0s - loss: 0.8223 - accuracy: 0.6565
# Epoch 67: val_loss improved from 0.72145 to 0.70297, saving model to saved_models/audio_classification_sequential.hdf5
# 136/136 [==============================] - 1s 6ms/step - loss: 0.8228 - accuracy: 0.6569 - val_loss: 0.7030 - val_accuracy: 0.7060
# Epoch 68/100
# 131/136 [===========================>..] - ETA: 0s - loss: 0.8374 - accuracy: 0.6434
# Epoch 68: val_loss did not improve from 0.70297
# 136/136 [==============================] - 1s 7ms/step - loss: 0.8367 - accuracy: 0.6431 - val_loss: 0.7204 - val_accuracy: 0.7088
# Epoch 69/100
# 131/136 [===========================>..] - ETA: 0s - loss: 0.8313 - accuracy: 0.6348
# Epoch 69: val_loss did not improve from 0.70297
# 136/136 [==============================] - 1s 6ms/step - loss: 0.8285 - accuracy: 0.6375 - val_loss: 0.7104 - val_accuracy: 0.7134
# Epoch 70/100
# 131/136 [===========================>..] - ETA: 0s - loss: 0.8404 - accuracy: 0.6381
# Epoch 70: val_loss did not improve from 0.70297
# 136/136 [==============================] - 1s 4ms/step - loss: 0.8415 - accuracy: 0.6375 - val_loss: 0.7116 - val_accuracy: 0.7152
# Epoch 71/100
# 126/136 [==========================>...] - ETA: 0s - loss: 0.8527 - accuracy: 0.6381
# Epoch 71: val_loss did not improve from 0.70297
# 136/136 [==============================] - 1s 5ms/step - loss: 0.8580 - accuracy: 0.6389 - val_loss: 0.7317 - val_accuracy: 0.7115
# Epoch 72/100
# 130/136 [===========================>..] - ETA: 0s - loss: 0.8384 - accuracy: 0.6310
# Epoch 72: val_loss did not improve from 0.70297
# 136/136 [==============================] - 1s 5ms/step - loss: 0.8422 - accuracy: 0.6322 - val_loss: 0.7034 - val_accuracy: 0.7152
# Epoch 73/100
# 127/136 [===========================>..] - ETA: 0s - loss: 0.8190 - accuracy: 0.6575
# Epoch 73: val_loss improved from 0.70297 to 0.69377, saving model to saved_models/audio_classification_sequential.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 0.8180 - accuracy: 0.6599 - val_loss: 0.6938 - val_accuracy: 0.7235
# Epoch 74/100
# 128/136 [===========================>..] - ETA: 0s - loss: 0.8227 - accuracy: 0.6553
# Epoch 74: val_loss did not improve from 0.69377
# 136/136 [==============================] - 1s 5ms/step - loss: 0.8231 - accuracy: 0.6546 - val_loss: 0.6999 - val_accuracy: 0.7207
# Epoch 75/100
# 132/136 [============================>.] - ETA: 0s - loss: 0.8048 - accuracy: 0.6605
# Epoch 75: val_loss improved from 0.69377 to 0.66536, saving model to saved_models/audio_classification_sequential.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 0.8024 - accuracy: 0.6629 - val_loss: 0.6654 - val_accuracy: 0.7465
# Epoch 76/100
# 130/136 [===========================>..] - ETA: 0s - loss: 0.8183 - accuracy: 0.6591
# Epoch 76: val_loss did not improve from 0.66536
# 136/136 [==============================] - 1s 5ms/step - loss: 0.8151 - accuracy: 0.6615 - val_loss: 0.6985 - val_accuracy: 0.7290
# Epoch 77/100
# 124/136 [==========================>...] - ETA: 0s - loss: 0.7980 - accuracy: 0.6764
# Epoch 77: val_loss did not improve from 0.66536
# 136/136 [==============================] - 1s 5ms/step - loss: 0.7961 - accuracy: 0.6770 - val_loss: 0.6873 - val_accuracy: 0.7235
# Epoch 78/100
# 129/136 [===========================>..] - ETA: 0s - loss: 0.7898 - accuracy: 0.6652
# Epoch 78: val_loss did not improve from 0.66536
# 136/136 [==============================] - 1s 4ms/step - loss: 0.7951 - accuracy: 0.6641 - val_loss: 0.6915 - val_accuracy: 0.7217
# Epoch 79/100
# 125/136 [==========================>...] - ETA: 0s - loss: 0.7831 - accuracy: 0.6735
# Epoch 79: val_loss did not improve from 0.66536
# 136/136 [==============================] - 1s 5ms/step - loss: 0.7859 - accuracy: 0.6737 - val_loss: 0.6830 - val_accuracy: 0.7161
# Epoch 80/100
# 123/136 [==========================>...] - ETA: 0s - loss: 0.8139 - accuracy: 0.6672
# Epoch 80: val_loss did not improve from 0.66536
# 136/136 [==============================] - 1s 5ms/step - loss: 0.8146 - accuracy: 0.6668 - val_loss: 0.6727 - val_accuracy: 0.7336
# Epoch 81/100
# 130/136 [===========================>..] - ETA: 0s - loss: 0.7897 - accuracy: 0.6757
# Epoch 81: val_loss improved from 0.66536 to 0.65602, saving model to saved_models/audio_classification_sequential.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 0.7906 - accuracy: 0.6747 - val_loss: 0.6560 - val_accuracy: 0.7456
# Epoch 82/100
# 133/136 [============================>.] - ETA: 0s - loss: 0.7822 - accuracy: 0.6711
# Epoch 82: val_loss did not improve from 0.65602
# 136/136 [==============================] - 1s 5ms/step - loss: 0.7819 - accuracy: 0.6712 - val_loss: 0.6783 - val_accuracy: 0.7355
# Epoch 83/100
# 136/136 [==============================] - ETA: 0s - loss: 0.7877 - accuracy: 0.6677
# Epoch 83: val_loss did not improve from 0.65602
# 136/136 [==============================] - 1s 5ms/step - loss: 0.7877 - accuracy: 0.6677 - val_loss: 0.6639 - val_accuracy: 0.7594
# Epoch 84/100
# 135/136 [============================>.] - ETA: 0s - loss: 0.7776 - accuracy: 0.6762
# Epoch 84: val_loss improved from 0.65602 to 0.65417, saving model to saved_models/audio_classification_sequential.hdf5
# 136/136 [==============================] - 1s 6ms/step - loss: 0.7787 - accuracy: 0.6754 - val_loss: 0.6542 - val_accuracy: 0.7346
# Epoch 85/100
# 128/136 [===========================>..] - ETA: 0s - loss: 0.7754 - accuracy: 0.6753
# Epoch 85: val_loss did not improve from 0.65417
# 136/136 [==============================] - 1s 6ms/step - loss: 0.7779 - accuracy: 0.6758 - val_loss: 0.6558 - val_accuracy: 0.7465
# Epoch 86/100
# 128/136 [===========================>..] - ETA: 0s - loss: 0.7687 - accuracy: 0.6838
# Epoch 86: val_loss improved from 0.65417 to 0.64872, saving model to saved_models/audio_classification_sequential.hdf5
# 136/136 [==============================] - 1s 7ms/step - loss: 0.7717 - accuracy: 0.6830 - val_loss: 0.6487 - val_accuracy: 0.7475
# Epoch 87/100
# 136/136 [==============================] - ETA: 0s - loss: 0.7746 - accuracy: 0.6797
# Epoch 87: val_loss did not improve from 0.64872
# 136/136 [==============================] - 1s 5ms/step - loss: 0.7746 - accuracy: 0.6797 - val_loss: 0.6525 - val_accuracy: 0.7484
# Epoch 88/100
# 126/136 [==========================>...] - ETA: 0s - loss: 0.7784 - accuracy: 0.6677
# Epoch 88: val_loss did not improve from 0.64872
# 136/136 [==============================] - 1s 4ms/step - loss: 0.7797 - accuracy: 0.6689 - val_loss: 0.6658 - val_accuracy: 0.7373
# Epoch 89/100
# 128/136 [===========================>..] - ETA: 0s - loss: 0.7714 - accuracy: 0.6680
# Epoch 89: val_loss did not improve from 0.64872
# 136/136 [==============================] - 1s 4ms/step - loss: 0.7757 - accuracy: 0.6677 - val_loss: 0.6509 - val_accuracy: 0.7631
# Epoch 90/100
# 128/136 [===========================>..] - ETA: 0s - loss: 0.7829 - accuracy: 0.6670
# Epoch 90: val_loss did not improve from 0.64872
# 136/136 [==============================] - 1s 4ms/step - loss: 0.7812 - accuracy: 0.6664 - val_loss: 0.6555 - val_accuracy: 0.7539
# Epoch 91/100
# 129/136 [===========================>..] - ETA: 0s - loss: 0.7682 - accuracy: 0.6911
# Epoch 91: val_loss did not improve from 0.64872
# 136/136 [==============================] - 1s 4ms/step - loss: 0.7680 - accuracy: 0.6910 - val_loss: 0.6613 - val_accuracy: 0.7530
# Epoch 92/100
# 124/136 [==========================>...] - ETA: 0s - loss: 0.7589 - accuracy: 0.6746
# Epoch 92: val_loss improved from 0.64872 to 0.63436, saving model to saved_models/audio_classification_sequential.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 0.7623 - accuracy: 0.6719 - val_loss: 0.6344 - val_accuracy: 0.7751
# Epoch 93/100
# 134/136 [============================>.] - ETA: 0s - loss: 0.7715 - accuracy: 0.6784
# Epoch 93: val_loss improved from 0.63436 to 0.63422, saving model to saved_models/audio_classification_sequential.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 0.7722 - accuracy: 0.6779 - val_loss: 0.6342 - val_accuracy: 0.7548
# Epoch 94/100
# 132/136 [============================>.] - ETA: 0s - loss: 0.7440 - accuracy: 0.6911
# Epoch 94: val_loss did not improve from 0.63422
# 136/136 [==============================] - 1s 5ms/step - loss: 0.7465 - accuracy: 0.6913 - val_loss: 0.6447 - val_accuracy: 0.7530
# Epoch 95/100
# 123/136 [==========================>...] - ETA: 0s - loss: 0.7530 - accuracy: 0.6870
# Epoch 95: val_loss did not improve from 0.63422
# 136/136 [==============================] - 1s 4ms/step - loss: 0.7573 - accuracy: 0.6864 - val_loss: 0.6373 - val_accuracy: 0.7622
# Epoch 96/100
# 128/136 [===========================>..] - ETA: 0s - loss: 0.7515 - accuracy: 0.6978
# Epoch 96: val_loss did not improve from 0.63422
# 136/136 [==============================] - 1s 4ms/step - loss: 0.7530 - accuracy: 0.6947 - val_loss: 0.6493 - val_accuracy: 0.7438
# Epoch 97/100
# 125/136 [==========================>...] - ETA: 0s - loss: 0.7298 - accuracy: 0.7048
# Epoch 97: val_loss improved from 0.63422 to 0.63036, saving model to saved_models/audio_classification_sequential.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 0.7361 - accuracy: 0.7026 - val_loss: 0.6304 - val_accuracy: 0.7650
# Epoch 98/100
# 127/136 [===========================>..] - ETA: 0s - loss: 0.7396 - accuracy: 0.6949
# Epoch 98: val_loss improved from 0.63036 to 0.61696, saving model to saved_models/audio_classification_sequential.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 0.7339 - accuracy: 0.6975 - val_loss: 0.6170 - val_accuracy: 0.7705
# Epoch 99/100
# 125/136 [==========================>...] - ETA: 0s - loss: 0.7367 - accuracy: 0.6975
# Epoch 99: val_loss did not improve from 0.61696
# 136/136 [==============================] - 1s 5ms/step - loss: 0.7348 - accuracy: 0.6986 - val_loss: 0.6302 - val_accuracy: 0.7438
# Epoch 100/100
# 134/136 [============================>.] - ETA: 0s - loss: 0.7476 - accuracy: 0.6880
# Epoch 100: val_loss did not improve from 0.61696
# 136/136 [==============================] - 1s 5ms/step - loss: 0.7462 - accuracy: 0.6892 - val_loss: 0.6289 - val_accuracy: 0.7714
# Training completed in time:  0:01:12.684240

# %%
test_accuracy=model.evaluate(X_test,y_test,verbose=0)
print(test_accuracy[1])
# Out:
# 0.7714285850524902

# %%
filename= "/content/wavfiles/101308-5.wav"
audio, sample_rate = librosa.load(filename, res_type='kaiser_fast')
mfccs_features = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=21)
mfccs_scaled_features = np.mean(mfccs_features.T,axis=0)

print(mfccs_scaled_features)
mfccs_scaled_features=mfccs_scaled_features.reshape(1,-1)
print(mfccs_scaled_features)
print(mfccs_scaled_features.shape)
predicted_label = model.predict(mfccs_scaled_features)
predicted_class_index = np.argmax(predicted_label)
prediction_class = labelencoder.inverse_transform([predicted_class_index])
print(f"The predicted bird is: {prediction_class}")
# Out:
# [-2.0822256e+02  4.7379898e+01 -4.1454041e+01  4.0189480e+01
#  -2.3528139e+01 -5.5456023e+00  1.8695351e+01  4.9905853e+00
#  -7.6499872e+00  1.0349575e+01 -5.9336252e+00  6.0427871e+00
#  -5.0681181e+00  8.7633657e-01  1.0736929e+00  2.0575190e+00
#  -6.6417375e+00  6.8580632e+00 -2.3993657e+00 -3.3767705e+00
#  -1.9962448e-01]
# [[-2.0822256e+02  4.7379898e+01 -4.1454041e+01  4.0189480e+01
#   -2.3528139e+01 -5.5456023e+00  1.8695351e+01  4.9905853e+00
#   -7.6499872e+00  1.0349575e+01 -5.9336252e+00  6.0427871e+00
#   -5.0681181e+00  8.7633657e-01  1.0736929e+00  2.0575190e+00
#   -6.6417375e+00  6.8580632e+00 -2.3993657e+00 -3.3767705e+00
#   -1.9962448e-01]]
# (1, 21)
# 1/1 [==============================] - 0s 109ms/step
# The predicted bird is: ['Northern Mockingbird']

# %% [markdown]
# $\Large \color{green}{\texttt{LSTM}}$

# %%
X_train_lstm = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test_lstm = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# %%
# Define LSTM model
model_lstm = Sequential()
model_lstm.add(LSTM(128, input_shape=(X_train.shape[1], 1), return_sequences=True))
model_lstm.add(LSTM(128))
model_lstm.add(Dropout(0.5))
model_lstm.add(Dense(num_labels, activation='softmax'))

model_lstm.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model_lstm.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 21, 128)           66560
#
#  lstm_1 (LSTM)               (None, 128)               131584
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 198789 (776.52 KB)
# Trainable params: 198789 (776.52 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Define checkpoint to save the best model
checkpointer_lstm = ModelCheckpoint(filepath='saved_models/audio_classification_lstm.hdf5', verbose=1, save_best_only=True)
np.save("lstm_labelencoder.npy", labelencoder.classes_)

# Implement early stopping based on validation loss
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# %%
# Train LSTM model
start = datetime.now()
history_lstm = model_lstm.fit(X_train_lstm, y_train, batch_size=35, epochs=30,validation_data=(X_test_lstm, y_test),
                               callbacks=[checkpointer_lstm, early_stopping], verbose=1)
duration_lstm = datetime.now() - start
print("Training completed in time: ", duration_lstm)
# Out:
# Epoch 1/30
# 124/124 [==============================] - ETA: 0s - loss: 1.5784 - accuracy: 0.2691
# Epoch 1: val_loss improved from inf to 1.51664, saving model to saved_models/audio_classification_lstm.hdf5
# 124/124 [==============================] - 6s 14ms/step - loss: 1.5784 - accuracy: 0.2691 - val_loss: 1.5166 - val_accuracy: 0.2894
# Epoch 2/30
# 124/124 [==============================] - ETA: 0s - loss: 1.4284 - accuracy: 0.3774
# Epoch 2: val_loss improved from 1.51664 to 1.22551, saving model to saved_models/audio_classification_lstm.hdf5
# 124/124 [==============================] - 1s 8ms/step - loss: 1.4284 - accuracy: 0.3774 - val_loss: 1.2255 - val_accuracy: 0.4765
# Epoch 3/30
# 120/124 [============================>.] - ETA: 0s - loss: 1.2055 - accuracy: 0.4924
# Epoch 3: val_loss improved from 1.22551 to 1.09785, saving model to saved_models/audio_classification_lstm.hdf5
# 124/124 [==============================] - 1s 8ms/step - loss: 1.2053 - accuracy: 0.4923 - val_loss: 1.0978 - val_accuracy: 0.5364
# Epoch 4/30
# 116/124 [===========================>..] - ETA: 0s - loss: 1.0883 - accuracy: 0.5537
# Epoch 4: val_loss improved from 1.09785 to 0.98551, saving model to saved_models/audio_classification_lstm.hdf5
# 124/124 [==============================] - 1s 7ms/step - loss: 1.0854 - accuracy: 0.5548 - val_loss: 0.9855 - val_accuracy: 0.5982
# Epoch 5/30
# 119/124 [===========================>..] - ETA: 0s - loss: 0.9774 - accuracy: 0.6026
# Epoch 5: val_loss improved from 0.98551 to 0.91460, saving model to saved_models/audio_classification_lstm.hdf5
# 124/124 [==============================] - 1s 8ms/step - loss: 0.9753 - accuracy: 0.6025 - val_loss: 0.9146 - val_accuracy: 0.6092
# Epoch 6/30
# 118/124 [===========================>..] - ETA: 0s - loss: 0.8679 - accuracy: 0.6581
# Epoch 6: val_loss improved from 0.91460 to 0.84058, saving model to saved_models/audio_classification_lstm.hdf5
# 124/124 [==============================] - 1s 8ms/step - loss: 0.8626 - accuracy: 0.6599 - val_loss: 0.8406 - val_accuracy: 0.6498
# Epoch 7/30
# 120/124 [============================>.] - ETA: 0s - loss: 0.7781 - accuracy: 0.6869
# Epoch 7: val_loss improved from 0.84058 to 0.72473, saving model to saved_models/audio_classification_lstm.hdf5
# 124/124 [==============================] - 1s 8ms/step - loss: 0.7719 - accuracy: 0.6899 - val_loss: 0.7247 - val_accuracy: 0.7180
# Epoch 8/30
# 122/124 [============================>.] - ETA: 0s - loss: 0.7000 - accuracy: 0.7244
# Epoch 8: val_loss improved from 0.72473 to 0.67813, saving model to saved_models/audio_classification_lstm.hdf5
# 124/124 [==============================] - 1s 11ms/step - loss: 0.6962 - accuracy: 0.7263 - val_loss: 0.6781 - val_accuracy: 0.7382
# Epoch 9/30
# 123/124 [============================>.] - ETA: 0s - loss: 0.6483 - accuracy: 0.7433
# Epoch 9: val_loss improved from 0.67813 to 0.66156, saving model to saved_models/audio_classification_lstm.hdf5
# 124/124 [==============================] - 1s 10ms/step - loss: 0.6476 - accuracy: 0.7434 - val_loss: 0.6616 - val_accuracy: 0.7244
# Epoch 10/30
# 123/124 [============================>.] - ETA: 0s - loss: 0.5730 - accuracy: 0.7810
# Epoch 10: val_loss did not improve from 0.66156
# 124/124 [==============================] - 1s 8ms/step - loss: 0.5742 - accuracy: 0.7805 - val_loss: 0.7007 - val_accuracy: 0.7235
# Epoch 11/30
# 119/124 [===========================>..] - ETA: 0s - loss: 0.5221 - accuracy: 0.8026
# Epoch 11: val_loss improved from 0.66156 to 0.58021, saving model to saved_models/audio_classification_lstm.hdf5
# 124/124 [==============================] - 1s 8ms/step - loss: 0.5212 - accuracy: 0.8040 - val_loss: 0.5802 - val_accuracy: 0.7834
# Epoch 12/30
# 119/124 [===========================>..] - ETA: 0s - loss: 0.4511 - accuracy: 0.8305
# Epoch 12: val_loss did not improve from 0.58021
# 124/124 [==============================] - 1s 8ms/step - loss: 0.4520 - accuracy: 0.8308 - val_loss: 0.5810 - val_accuracy: 0.7926
# Epoch 13/30
# 121/124 [============================>.] - ETA: 0s - loss: 0.4192 - accuracy: 0.8472
# Epoch 13: val_loss did not improve from 0.58021
# 124/124 [==============================] - 1s 8ms/step - loss: 0.4185 - accuracy: 0.8478 - val_loss: 0.5826 - val_accuracy: 0.7908
# Epoch 14/30
# 121/124 [============================>.] - ETA: 0s - loss: 0.3700 - accuracy: 0.8645
# Epoch 14: val_loss improved from 0.58021 to 0.52325, saving model to saved_models/audio_classification_lstm.hdf5
# 124/124 [==============================] - 1s 8ms/step - loss: 0.3719 - accuracy: 0.8635 - val_loss: 0.5233 - val_accuracy: 0.8147
# Epoch 15/30
# 117/124 [===========================>..] - ETA: 0s - loss: 0.3291 - accuracy: 0.8835
# Epoch 15: val_loss improved from 0.52325 to 0.50104, saving model to saved_models/audio_classification_lstm.hdf5
# 124/124 [==============================] - 1s 8ms/step - loss: 0.3266 - accuracy: 0.8840 - val_loss: 0.5010 - val_accuracy: 0.8295
# Epoch 16/30
# 120/124 [============================>.] - ETA: 0s - loss: 0.3110 - accuracy: 0.8893
# Epoch 16: val_loss improved from 0.50104 to 0.49768, saving model to saved_models/audio_classification_lstm.hdf5
# 124/124 [==============================] - 1s 8ms/step - loss: 0.3125 - accuracy: 0.8882 - val_loss: 0.4977 - val_accuracy: 0.8304
# Epoch 17/30
# 120/124 [============================>.] - ETA: 0s - loss: 0.2575 - accuracy: 0.9052
# Epoch 17: val_loss improved from 0.49768 to 0.45621, saving model to saved_models/audio_classification_lstm.hdf5
# 124/124 [==============================] - 1s 8ms/step - loss: 0.2576 - accuracy: 0.9052 - val_loss: 0.4562 - val_accuracy: 0.8498
# Epoch 18/30
# 120/124 [============================>.] - ETA: 0s - loss: 0.2373 - accuracy: 0.9155
# Epoch 18: val_loss did not improve from 0.45621
# 124/124 [==============================] - 1s 8ms/step - loss: 0.2373 - accuracy: 0.9149 - val_loss: 0.4791 - val_accuracy: 0.8415
# Epoch 19/30
# 124/124 [==============================] - ETA: 0s - loss: 0.2182 - accuracy: 0.9200
# Epoch 19: val_loss did not improve from 0.45621
# 124/124 [==============================] - 1s 9ms/step - loss: 0.2182 - accuracy: 0.9200 - val_loss: 0.4606 - val_accuracy: 0.8608
# Epoch 20/30
# 122/124 [============================>.] - ETA: 0s - loss: 0.1967 - accuracy: 0.9295
# Epoch 20: val_loss did not improve from 0.45621
# 124/124 [==============================] - 1s 10ms/step - loss: 0.1979 - accuracy: 0.9292 - val_loss: 0.4721 - val_accuracy: 0.8562
# Epoch 21/30
# 124/124 [==============================] - ETA: 0s - loss: 0.1832 - accuracy: 0.9368
# Epoch 21: val_loss improved from 0.45621 to 0.44982, saving model to saved_models/audio_classification_lstm.hdf5
# 124/124 [==============================] - 1s 8ms/step - loss: 0.1832 - accuracy: 0.9368 - val_loss: 0.4498 - val_accuracy: 0.8664
# Epoch 22/30
# 118/124 [===========================>..] - ETA: 0s - loss: 0.1599 - accuracy: 0.9448
# Epoch 22: val_loss did not improve from 0.44982
# 124/124 [==============================] - 1s 8ms/step - loss: 0.1576 - accuracy: 0.9454 - val_loss: 0.4778 - val_accuracy: 0.8700
# Epoch 23/30
# 122/124 [============================>.] - ETA: 0s - loss: 0.1481 - accuracy: 0.9494
# Epoch 23: val_loss did not improve from 0.44982
# 124/124 [==============================] - 1s 8ms/step - loss: 0.1474 - accuracy: 0.9500 - val_loss: 0.4985 - val_accuracy: 0.8645
# Epoch 24/30
# 118/124 [===========================>..] - ETA: 0s - loss: 0.1166 - accuracy: 0.9581
# Epoch 24: val_loss improved from 0.44982 to 0.43025, saving model to saved_models/audio_classification_lstm.hdf5
# 124/124 [==============================] - 1s 8ms/step - loss: 0.1178 - accuracy: 0.9583 - val_loss: 0.4302 - val_accuracy: 0.8876
# Epoch 25/30
# 118/124 [===========================>..] - ETA: 0s - loss: 0.1309 - accuracy: 0.9564
# Epoch 25: val_loss improved from 0.43025 to 0.41166, saving model to saved_models/audio_classification_lstm.hdf5
# 124/124 [==============================] - 1s 8ms/step - loss: 0.1277 - accuracy: 0.9576 - val_loss: 0.4117 - val_accuracy: 0.8857
# Epoch 26/30
# 120/124 [============================>.] - ETA: 0s - loss: 0.1424 - accuracy: 0.9486
# Epoch 26: val_loss did not improve from 0.41166
# 124/124 [==============================] - 1s 8ms/step - loss: 0.1419 - accuracy: 0.9486 - val_loss: 0.4569 - val_accuracy: 0.8636
# Epoch 27/30
# 120/124 [============================>.] - ETA: 0s - loss: 0.1274 - accuracy: 0.9567
# Epoch 27: val_loss did not improve from 0.41166
# 124/124 [==============================] - 1s 8ms/step - loss: 0.1263 - accuracy: 0.9569 - val_loss: 0.4333 - val_accuracy: 0.8737
# Epoch 28/30
# 118/124 [===========================>..] - ETA: 0s - loss: 0.0878 - accuracy: 0.9712
# Epoch 28: val_loss improved from 0.41166 to 0.39578, saving model to saved_models/audio_classification_lstm.hdf5
# 124/124 [==============================] - 1s 8ms/step - loss: 0.0864 - accuracy: 0.9716 - val_loss: 0.3958 - val_accuracy: 0.8940
# Epoch 29/30
# 119/124 [===========================>..] - ETA: 0s - loss: 0.0781 - accuracy: 0.9731
# Epoch 29: val_loss did not improve from 0.39578
# 124/124 [==============================] - 1s 8ms/step - loss: 0.0793 - accuracy: 0.9726 - val_loss: 0.5197 - val_accuracy: 0.8719
# Epoch 30/30
# 119/124 [===========================>..] - ETA: 0s - loss: 0.1038 - accuracy: 0.9661
# Epoch 30: val_loss did not improve from 0.39578
# 124/124 [==============================] - 1s 8ms/step - loss: 0.1031 - accuracy: 0.9666 - val_loss: 0.4514 - val_accuracy: 0.8968
# Training completed in time:  0:00:44.155444

# %%
test_accuracy=model_lstm.evaluate(X_test_lstm,y_test,verbose=0)
print(test_accuracy[1])
# Out:
# 0.896774172782898

# %%
filename= "/content/wavfiles/101308-5.wav"
audio, sample_rate = librosa.load(filename, res_type='kaiser_fast')
mfccs_features = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=21)
mfccs_scaled_features = np.mean(mfccs_features.T,axis=0)

print(mfccs_scaled_features)
mfccs_scaled_features=mfccs_scaled_features.reshape(1,-1)
print(mfccs_scaled_features)
print(mfccs_scaled_features.shape)
predicted_label = model_lstm.predict(mfccs_scaled_features)
predicted_class_index = np.argmax(predicted_label)
prediction_class = labelencoder.inverse_transform([predicted_class_index])
print(f"The predicted bird is: {prediction_class}")
# Out:
# [-2.0822256e+02  4.7379898e+01 -4.1454041e+01  4.0189480e+01
#  -2.3528139e+01 -5.5456023e+00  1.8695351e+01  4.9905853e+00
#  -7.6499872e+00  1.0349575e+01 -5.9336252e+00  6.0427871e+00
#  -5.0681181e+00  8.7633657e-01  1.0736929e+00  2.0575190e+00
#  -6.6417375e+00  6.8580632e+00 -2.3993657e+00 -3.3767705e+00
#  -1.9962448e-01]
# [[-2.0822256e+02  4.7379898e+01 -4.1454041e+01  4.0189480e+01
#   -2.3528139e+01 -5.5456023e+00  1.8695351e+01  4.9905853e+00
#   -7.6499872e+00  1.0349575e+01 -5.9336252e+00  6.0427871e+00
#   -5.0681181e+00  8.7633657e-01  1.0736929e+00  2.0575190e+00
#   -6.6417375e+00  6.8580632e+00 -2.3993657e+00 -3.3767705e+00
#   -1.9962448e-01]]
# (1, 21)
# 1/1 [==============================] - 1s 636ms/step
# The predicted bird is: ['Northern Mockingbird']

# %% [markdown]
# $\Large \color{purple}{\texttt{VGGish}}$

# %%
def vggish_model(input_shape, num_labels, dropout_rate=0.5, l2_reg=0.0002):
    model_input = Input(shape=input_shape, name='input')

    # Block 1
    x = Conv1D(128, kernel_size=3, activation='relu', padding='same', kernel_regularizer='l2', name='conv1')(model_input)
    x = MaxPooling1D(pool_size=2, name='pool1')(x)

    # Block 2
    x = Conv1D(256, kernel_size=3, activation='relu', padding='same', kernel_regularizer='l2', name='conv2')(x)
    x = MaxPooling1D(pool_size=2, name='pool2')(x)

    # Block 3
    x = Conv1D(512, kernel_size=3, activation='relu', padding='same', kernel_regularizer='l2', name='conv3')(x)
    x = Conv1D(512, kernel_size=3, activation='relu', padding='same', kernel_regularizer='l2', name='conv4')(x)
    x = MaxPooling1D(pool_size=2, name='pool3')(x)

    # Block 4
    x = Conv1D(1024, kernel_size=3, activation='relu', padding='same', kernel_regularizer='l2', name='conv5')(x)
    x = Conv1D(1024, kernel_size=3, activation='relu', padding='same', kernel_regularizer='l2', name='conv6')(x)
    x = MaxPooling1D(pool_size=2, name='pool4')(x)

    # Flatten and fully connected layers
    x = Flatten(name='flatten')(x)
    x = Dense(2048, activation='relu', kernel_regularizer='l2', name='fc1')(x)
    x = Dropout(dropout_rate, name='dropout1')(x)
    x = Dense(2048, activation='relu', kernel_regularizer='l2', name='fc2')(x)
    x = Dropout(dropout_rate, name='dropout2')(x)

    # Output layer
    model_output = Dense(num_labels, activation='softmax', name='predictions')(x)

    model = Model(inputs=model_input, outputs=model_output, name='vggish')
    return model

# %%
# Reshape data for VGGish
X_train_vggish = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test_vggish = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

vggish_model = vggish_model((X_train_vggish.shape[1], 1), num_labels, dropout_rate=0.7, l2_reg=0.0002)
vggish_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Model summary
vggish_model.summary()
# Out:
# Model: "vggish"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 21, 1)]           0
#
#  conv1 (Conv1D)              (None, 21, 128)           512
#
#  pool1 (MaxPooling1D)        (None, 10, 128)           0
#
#  conv2 (Conv1D)              (None, 10, 256)           98560
#
#  pool2 (MaxPooling1D)        (None, 5, 256)            0
#
#  conv3 (Conv1D)              (None, 5, 512)            393728
#
#  conv4 (Conv1D)              (None, 5, 512)            786944
#
#  pool3 (MaxPooling1D)        (None, 2, 512)            0
#
#  conv5 (Conv1D)              (None, 2, 1024)           1573888
#
#  conv6 (Conv1D)              (None, 2, 1024)           3146752
#
#  pool4 (MaxPooling1D)        (None, 1, 1024)           0
#
#  flatten (Flatten)           (None, 1024)              0
#
#  fc1 (Dense)                 (None, 2048)              2099200
#
#  dropout1 (Dropout)          (None, 2048)              0
#
#  fc2 (Dense)                 (None, 2048)              4196352
#
#  dropout2 (Dropout)          (None, 2048)              0
#
#  predictions (Dense)         (None, 5)                 10245
#
# =================================================================
# Total params: 12306181 (46.94 MB)
# Trainable params: 12306181 (46.94 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Define checkpoint to save the best model
checkpoint_vggish = ModelCheckpoint(filepath='saved_models/audio_classification_vggish.hdf5', verbose=1, save_best_only=True)
np.save("vggish_labelencoder.npy", labelencoder.classes_)

# Implement early stopping based on validation loss
early_stopping_vggish = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)

# Train the model
start_vggish = datetime.now()
history_vggish = vggish_model.fit(X_train_vggish, y_train, batch_size=100, epochs=200,
                                  validation_data=(X_test_vggish, y_test),
                                  callbacks=[checkpoint_vggish, early_stopping_vggish], verbose=1)

duration_vggish = datetime.now() - start_vggish
print("Training completed in time: ", duration_vggish)
# Out:
# Epoch 1/200
# 44/44 [==============================] - ETA: 0s - loss: 30.4332 - accuracy: 0.2896
# Epoch 1: val_loss improved from inf to 12.28730, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 8s 54ms/step - loss: 30.4332 - accuracy: 0.2896 - val_loss: 12.2873 - val_accuracy: 0.3742
# Epoch 2/200
# 41/44 [==========================>...] - ETA: 0s - loss: 8.1390 - accuracy: 0.3868
# Epoch 2: val_loss improved from 12.28730 to 5.05844, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 27ms/step - loss: 7.9813 - accuracy: 0.3851 - val_loss: 5.0584 - val_accuracy: 0.3899
# Epoch 3/200
# 41/44 [==========================>...] - ETA: 0s - loss: 3.9495 - accuracy: 0.4139
# Epoch 3: val_loss improved from 5.05844 to 2.95634, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 25ms/step - loss: 3.8991 - accuracy: 0.4153 - val_loss: 2.9563 - val_accuracy: 0.4101
# Epoch 4/200
# 41/44 [==========================>...] - ETA: 0s - loss: 2.5543 - accuracy: 0.3998
# Epoch 4: val_loss improved from 2.95634 to 2.11745, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 26ms/step - loss: 2.5319 - accuracy: 0.4012 - val_loss: 2.1174 - val_accuracy: 0.4018
# Epoch 5/200
# 41/44 [==========================>...] - ETA: 0s - loss: 1.9511 - accuracy: 0.4229
# Epoch 5: val_loss improved from 2.11745 to 1.76667, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 25ms/step - loss: 1.9392 - accuracy: 0.4240 - val_loss: 1.7667 - val_accuracy: 0.4194
# Epoch 6/200
# 41/44 [==========================>...] - ETA: 0s - loss: 1.6713 - accuracy: 0.4298
# Epoch 6: val_loss improved from 1.76667 to 1.52760, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 3s 80ms/step - loss: 1.6668 - accuracy: 0.4270 - val_loss: 1.5276 - val_accuracy: 0.4599
# Epoch 7/200
# 41/44 [==========================>...] - ETA: 0s - loss: 1.5175 - accuracy: 0.4432
# Epoch 7: val_loss improved from 1.52760 to 1.44956, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 29ms/step - loss: 1.5156 - accuracy: 0.4404 - val_loss: 1.4496 - val_accuracy: 0.4461
# Epoch 8/200
# 41/44 [==========================>...] - ETA: 0s - loss: 1.4364 - accuracy: 0.4507
# Epoch 8: val_loss improved from 1.44956 to 1.38630, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 25ms/step - loss: 1.4340 - accuracy: 0.4554 - val_loss: 1.3863 - val_accuracy: 0.4535
# Epoch 9/200
# 41/44 [==========================>...] - ETA: 0s - loss: 1.4007 - accuracy: 0.4583
# Epoch 9: val_loss improved from 1.38630 to 1.36408, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 25ms/step - loss: 1.4005 - accuracy: 0.4577 - val_loss: 1.3641 - val_accuracy: 0.4829
# Epoch 10/200
# 41/44 [==========================>...] - ETA: 0s - loss: 1.3459 - accuracy: 0.4785
# Epoch 10: val_loss improved from 1.36408 to 1.26571, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 31ms/step - loss: 1.3444 - accuracy: 0.4794 - val_loss: 1.2657 - val_accuracy: 0.5143
# Epoch 11/200
# 41/44 [==========================>...] - ETA: 0s - loss: 1.2995 - accuracy: 0.4980
# Epoch 11: val_loss improved from 1.26571 to 1.25292, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 28ms/step - loss: 1.2974 - accuracy: 0.4973 - val_loss: 1.2529 - val_accuracy: 0.5493
# Epoch 12/200
# 41/44 [==========================>...] - ETA: 0s - loss: 1.3070 - accuracy: 0.5005
# Epoch 12: val_loss improved from 1.25292 to 1.24010, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 25ms/step - loss: 1.3032 - accuracy: 0.4999 - val_loss: 1.2401 - val_accuracy: 0.5336
# Epoch 13/200
# 41/44 [==========================>...] - ETA: 0s - loss: 1.2866 - accuracy: 0.5127
# Epoch 13: val_loss improved from 1.24010 to 1.18945, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 3s 69ms/step - loss: 1.2862 - accuracy: 0.5146 - val_loss: 1.1894 - val_accuracy: 0.5724
# Epoch 14/200
# 43/44 [============================>.] - ETA: 0s - loss: 1.2580 - accuracy: 0.5205
# Epoch 14: val_loss did not improve from 1.18945
# 44/44 [==============================] - 1s 23ms/step - loss: 1.2575 - accuracy: 0.5211 - val_loss: 1.2030 - val_accuracy: 0.5493
# Epoch 15/200
# 41/44 [==========================>...] - ETA: 0s - loss: 1.2635 - accuracy: 0.5259
# Epoch 15: val_loss did not improve from 1.18945
# 44/44 [==============================] - 1s 17ms/step - loss: 1.2615 - accuracy: 0.5276 - val_loss: 1.2190 - val_accuracy: 0.5364
# Epoch 16/200
# 44/44 [==============================] - ETA: 0s - loss: 1.2498 - accuracy: 0.5252
# Epoch 16: val_loss improved from 1.18945 to 1.18335, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 26ms/step - loss: 1.2498 - accuracy: 0.5252 - val_loss: 1.1833 - val_accuracy: 0.5576
# Epoch 17/200
# 41/44 [==========================>...] - ETA: 0s - loss: 1.2329 - accuracy: 0.5368
# Epoch 17: val_loss did not improve from 1.18335
# 44/44 [==============================] - 1s 17ms/step - loss: 1.2390 - accuracy: 0.5352 - val_loss: 1.1944 - val_accuracy: 0.5456
# Epoch 18/200
# 44/44 [==============================] - ETA: 0s - loss: 1.2230 - accuracy: 0.5407
# Epoch 18: val_loss did not improve from 1.18335
# 44/44 [==============================] - 1s 17ms/step - loss: 1.2230 - accuracy: 0.5407 - val_loss: 1.2726 - val_accuracy: 0.4949
# Epoch 19/200
# 41/44 [==========================>...] - ETA: 0s - loss: 1.1997 - accuracy: 0.5576
# Epoch 19: val_loss improved from 1.18335 to 1.16742, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 2s 36ms/step - loss: 1.1989 - accuracy: 0.5571 - val_loss: 1.1674 - val_accuracy: 0.5806
# Epoch 20/200
# 41/44 [==========================>...] - ETA: 0s - loss: 1.2185 - accuracy: 0.5510
# Epoch 20: val_loss did not improve from 1.16742
# 44/44 [==============================] - 1s 16ms/step - loss: 1.2144 - accuracy: 0.5504 - val_loss: 1.2928 - val_accuracy: 0.5318
# Epoch 21/200
# 44/44 [==============================] - ETA: 0s - loss: 1.2067 - accuracy: 0.5642
# Epoch 21: val_loss improved from 1.16742 to 1.14989, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 26ms/step - loss: 1.2067 - accuracy: 0.5642 - val_loss: 1.1499 - val_accuracy: 0.5770
# Epoch 22/200
# 43/44 [============================>.] - ETA: 0s - loss: 1.1845 - accuracy: 0.5688
# Epoch 22: val_loss improved from 1.14989 to 1.13915, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 25ms/step - loss: 1.1848 - accuracy: 0.5693 - val_loss: 1.1392 - val_accuracy: 0.5806
# Epoch 23/200
# 43/44 [============================>.] - ETA: 0s - loss: 1.1905 - accuracy: 0.5584
# Epoch 23: val_loss did not improve from 1.13915
# 44/44 [==============================] - 1s 19ms/step - loss: 1.1898 - accuracy: 0.5589 - val_loss: 1.1636 - val_accuracy: 0.5871
# Epoch 24/200
# 44/44 [==============================] - ETA: 0s - loss: 1.1712 - accuracy: 0.5707
# Epoch 24: val_loss did not improve from 1.13915
# 44/44 [==============================] - 1s 19ms/step - loss: 1.1712 - accuracy: 0.5707 - val_loss: 1.1715 - val_accuracy: 0.5622
# Epoch 25/200
# 41/44 [==========================>...] - ETA: 0s - loss: 1.1895 - accuracy: 0.5683
# Epoch 25: val_loss did not improve from 1.13915
# 44/44 [==============================] - 1s 17ms/step - loss: 1.1873 - accuracy: 0.5686 - val_loss: 1.1524 - val_accuracy: 0.6111
# Epoch 26/200
# 41/44 [==========================>...] - ETA: 0s - loss: 1.1419 - accuracy: 0.5971
# Epoch 26: val_loss improved from 1.13915 to 1.11033, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 25ms/step - loss: 1.1449 - accuracy: 0.5956 - val_loss: 1.1103 - val_accuracy: 0.5945
# Epoch 27/200
# 41/44 [==========================>...] - ETA: 0s - loss: 1.1443 - accuracy: 0.5883
# Epoch 27: val_loss did not improve from 1.11033
# 44/44 [==============================] - 1s 17ms/step - loss: 1.1413 - accuracy: 0.5893 - val_loss: 1.1718 - val_accuracy: 0.5853
# Epoch 28/200
# 41/44 [==========================>...] - ETA: 0s - loss: 1.1580 - accuracy: 0.5868
# Epoch 28: val_loss did not improve from 1.11033
# 44/44 [==============================] - 1s 17ms/step - loss: 1.1583 - accuracy: 0.5852 - val_loss: 1.1458 - val_accuracy: 0.5853
# Epoch 29/200
# 41/44 [==========================>...] - ETA: 0s - loss: 1.1325 - accuracy: 0.6010
# Epoch 29: val_loss did not improve from 1.11033
# 44/44 [==============================] - 1s 17ms/step - loss: 1.1333 - accuracy: 0.6013 - val_loss: 1.1233 - val_accuracy: 0.5945
# Epoch 30/200
# 41/44 [==========================>...] - ETA: 0s - loss: 1.1250 - accuracy: 0.6073
# Epoch 30: val_loss did not improve from 1.11033
# 44/44 [==============================] - 1s 17ms/step - loss: 1.1310 - accuracy: 0.6048 - val_loss: 1.1746 - val_accuracy: 0.5742
# Epoch 31/200
# 41/44 [==========================>...] - ETA: 0s - loss: 1.1294 - accuracy: 0.6027
# Epoch 31: val_loss did not improve from 1.11033
# 44/44 [==============================] - 1s 17ms/step - loss: 1.1326 - accuracy: 0.6000 - val_loss: 1.1379 - val_accuracy: 0.5871
# Epoch 32/200
# 44/44 [==============================] - ETA: 0s - loss: 1.1375 - accuracy: 0.6053
# Epoch 32: val_loss did not improve from 1.11033
# 44/44 [==============================] - 1s 17ms/step - loss: 1.1375 - accuracy: 0.6053 - val_loss: 1.1626 - val_accuracy: 0.6037
# Epoch 33/200
# 41/44 [==========================>...] - ETA: 0s - loss: 1.1204 - accuracy: 0.6232
# Epoch 33: val_loss improved from 1.11033 to 1.08029, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 25ms/step - loss: 1.1220 - accuracy: 0.6230 - val_loss: 1.0803 - val_accuracy: 0.6369
# Epoch 34/200
# 41/44 [==========================>...] - ETA: 0s - loss: 1.0924 - accuracy: 0.6317
# Epoch 34: val_loss improved from 1.08029 to 1.06928, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 25ms/step - loss: 1.0957 - accuracy: 0.6302 - val_loss: 1.0693 - val_accuracy: 0.6461
# Epoch 35/200
# 41/44 [==========================>...] - ETA: 0s - loss: 1.1035 - accuracy: 0.6305
# Epoch 35: val_loss did not improve from 1.06928
# 44/44 [==============================] - 1s 17ms/step - loss: 1.1039 - accuracy: 0.6295 - val_loss: 1.0960 - val_accuracy: 0.6562
# Epoch 36/200
# 44/44 [==============================] - ETA: 0s - loss: 1.0751 - accuracy: 0.6493
# Epoch 36: val_loss improved from 1.06928 to 1.06783, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 4s 85ms/step - loss: 1.0751 - accuracy: 0.6493 - val_loss: 1.0678 - val_accuracy: 0.6323
# Epoch 37/200
# 44/44 [==============================] - ETA: 0s - loss: 1.0806 - accuracy: 0.6541
# Epoch 37: val_loss improved from 1.06783 to 1.06774, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 29ms/step - loss: 1.0806 - accuracy: 0.6541 - val_loss: 1.0677 - val_accuracy: 0.6645
# Epoch 38/200
# 41/44 [==========================>...] - ETA: 0s - loss: 1.0809 - accuracy: 0.6663
# Epoch 38: val_loss did not improve from 1.06774
# 44/44 [==============================] - 1s 17ms/step - loss: 1.0781 - accuracy: 0.6668 - val_loss: 1.0706 - val_accuracy: 0.6369
# Epoch 39/200
# 41/44 [==========================>...] - ETA: 0s - loss: 1.0668 - accuracy: 0.6776
# Epoch 39: val_loss improved from 1.06774 to 1.03706, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 27ms/step - loss: 1.0682 - accuracy: 0.6765 - val_loss: 1.0371 - val_accuracy: 0.6793
# Epoch 40/200
# 41/44 [==========================>...] - ETA: 0s - loss: 1.0603 - accuracy: 0.6771
# Epoch 40: val_loss did not improve from 1.03706
# 44/44 [==============================] - 1s 17ms/step - loss: 1.0581 - accuracy: 0.6760 - val_loss: 1.1297 - val_accuracy: 0.6424
# Epoch 41/200
# 41/44 [==========================>...] - ETA: 0s - loss: 1.0372 - accuracy: 0.6973
# Epoch 41: val_loss improved from 1.03706 to 1.02362, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 31ms/step - loss: 1.0358 - accuracy: 0.6979 - val_loss: 1.0236 - val_accuracy: 0.6959
# Epoch 42/200
# 41/44 [==========================>...] - ETA: 0s - loss: 1.0381 - accuracy: 0.7080
# Epoch 42: val_loss did not improve from 1.02362
# 44/44 [==============================] - 1s 17ms/step - loss: 1.0392 - accuracy: 0.7079 - val_loss: 1.1107 - val_accuracy: 0.6793
# Epoch 43/200
# 41/44 [==========================>...] - ETA: 0s - loss: 1.0724 - accuracy: 0.6863
# Epoch 43: val_loss did not improve from 1.02362
# 44/44 [==============================] - 1s 17ms/step - loss: 1.0647 - accuracy: 0.6913 - val_loss: 1.0375 - val_accuracy: 0.7143
# Epoch 44/200
# 41/44 [==========================>...] - ETA: 0s - loss: 1.0135 - accuracy: 0.7276
# Epoch 44: val_loss improved from 1.02362 to 1.01573, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 26ms/step - loss: 1.0149 - accuracy: 0.7268 - val_loss: 1.0157 - val_accuracy: 0.7143
# Epoch 45/200
# 42/44 [===========================>..] - ETA: 0s - loss: 0.9915 - accuracy: 0.7410
# Epoch 45: val_loss did not improve from 1.01573
# 44/44 [==============================] - 1s 18ms/step - loss: 0.9912 - accuracy: 0.7413 - val_loss: 1.0428 - val_accuracy: 0.7152
# Epoch 46/200
# 42/44 [===========================>..] - ETA: 0s - loss: 1.0040 - accuracy: 0.7326
# Epoch 46: val_loss did not improve from 1.01573
# 44/44 [==============================] - 1s 18ms/step - loss: 1.0047 - accuracy: 0.7332 - val_loss: 1.0409 - val_accuracy: 0.7088
# Epoch 47/200
# 42/44 [===========================>..] - ETA: 0s - loss: 0.9711 - accuracy: 0.7543
# Epoch 47: val_loss improved from 1.01573 to 1.01539, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 27ms/step - loss: 0.9699 - accuracy: 0.7551 - val_loss: 1.0154 - val_accuracy: 0.7373
# Epoch 48/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.9512 - accuracy: 0.7710
# Epoch 48: val_loss did not improve from 1.01539
# 44/44 [==============================] - 1s 17ms/step - loss: 0.9527 - accuracy: 0.7727 - val_loss: 1.0409 - val_accuracy: 0.7152
# Epoch 49/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.9566 - accuracy: 0.7712
# Epoch 49: val_loss did not improve from 1.01539
# 44/44 [==============================] - 1s 17ms/step - loss: 0.9641 - accuracy: 0.7667 - val_loss: 1.0226 - val_accuracy: 0.7410
# Epoch 50/200
# 41/44 [==========================>...] - ETA: 0s - loss: 1.0008 - accuracy: 0.7493
# Epoch 50: val_loss improved from 1.01539 to 0.97845, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 26ms/step - loss: 0.9985 - accuracy: 0.7498 - val_loss: 0.9784 - val_accuracy: 0.7502
# Epoch 51/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.9255 - accuracy: 0.7910
# Epoch 51: val_loss improved from 0.97845 to 0.96185, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 27ms/step - loss: 0.9292 - accuracy: 0.7881 - val_loss: 0.9619 - val_accuracy: 0.7567
# Epoch 52/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.9456 - accuracy: 0.7859
# Epoch 52: val_loss did not improve from 0.96185
# 44/44 [==============================] - 1s 17ms/step - loss: 0.9418 - accuracy: 0.7874 - val_loss: 1.0319 - val_accuracy: 0.7401
# Epoch 53/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.9343 - accuracy: 0.7868
# Epoch 53: val_loss improved from 0.96185 to 0.95605, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 25ms/step - loss: 0.9317 - accuracy: 0.7881 - val_loss: 0.9560 - val_accuracy: 0.7935
# Epoch 54/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.8840 - accuracy: 0.8185
# Epoch 54: val_loss improved from 0.95605 to 0.93860, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 27ms/step - loss: 0.8866 - accuracy: 0.8176 - val_loss: 0.9386 - val_accuracy: 0.7742
# Epoch 55/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.9039 - accuracy: 0.7880
# Epoch 55: val_loss did not improve from 0.93860
# 44/44 [==============================] - 1s 17ms/step - loss: 0.9074 - accuracy: 0.7876 - val_loss: 0.9898 - val_accuracy: 0.7622
# Epoch 56/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.8940 - accuracy: 0.8107
# Epoch 56: val_loss did not improve from 0.93860
# 44/44 [==============================] - 1s 17ms/step - loss: 0.8930 - accuracy: 0.8105 - val_loss: 0.9821 - val_accuracy: 0.7889
# Epoch 57/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.8615 - accuracy: 0.8312
# Epoch 57: val_loss did not improve from 0.93860
# 44/44 [==============================] - 1s 16ms/step - loss: 0.8630 - accuracy: 0.8303 - val_loss: 1.0057 - val_accuracy: 0.7613
# Epoch 58/200
# 43/44 [============================>.] - ETA: 0s - loss: 0.8537 - accuracy: 0.8302
# Epoch 58: val_loss did not improve from 0.93860
# 44/44 [==============================] - 1s 18ms/step - loss: 0.8525 - accuracy: 0.8305 - val_loss: 1.0101 - val_accuracy: 0.7770
# Epoch 59/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.8528 - accuracy: 0.8344
# Epoch 59: val_loss did not improve from 0.93860
# 44/44 [==============================] - 1s 20ms/step - loss: 0.8502 - accuracy: 0.8358 - val_loss: 0.9788 - val_accuracy: 0.7908
# Epoch 60/200
# 43/44 [============================>.] - ETA: 0s - loss: 0.8453 - accuracy: 0.8370
# Epoch 60: val_loss did not improve from 0.93860
# 44/44 [==============================] - 1s 19ms/step - loss: 0.8460 - accuracy: 0.8370 - val_loss: 0.9905 - val_accuracy: 0.7926
# Epoch 61/200
# 44/44 [==============================] - ETA: 0s - loss: 0.8306 - accuracy: 0.8481
# Epoch 61: val_loss did not improve from 0.93860
# 44/44 [==============================] - 1s 17ms/step - loss: 0.8306 - accuracy: 0.8481 - val_loss: 0.9857 - val_accuracy: 0.7788
# Epoch 62/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.8342 - accuracy: 0.8456
# Epoch 62: val_loss did not improve from 0.93860
# 44/44 [==============================] - 1s 17ms/step - loss: 0.8363 - accuracy: 0.8451 - val_loss: 0.9680 - val_accuracy: 0.7963
# Epoch 63/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.7932 - accuracy: 0.8580
# Epoch 63: val_loss improved from 0.93860 to 0.93731, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 26ms/step - loss: 0.7906 - accuracy: 0.8587 - val_loss: 0.9373 - val_accuracy: 0.7982
# Epoch 64/200
# 43/44 [============================>.] - ETA: 0s - loss: 0.8830 - accuracy: 0.8312
# Epoch 64: val_loss improved from 0.93731 to 0.93100, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 30ms/step - loss: 0.8849 - accuracy: 0.8308 - val_loss: 0.9310 - val_accuracy: 0.8101
# Epoch 65/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.8171 - accuracy: 0.8541
# Epoch 65: val_loss did not improve from 0.93100
# 44/44 [==============================] - 1s 19ms/step - loss: 0.8190 - accuracy: 0.8531 - val_loss: 0.9551 - val_accuracy: 0.8074
# Epoch 66/200
# 43/44 [============================>.] - ETA: 0s - loss: 0.8427 - accuracy: 0.8463
# Epoch 66: val_loss improved from 0.93100 to 0.92356, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 3s 79ms/step - loss: 0.8420 - accuracy: 0.8464 - val_loss: 0.9236 - val_accuracy: 0.8111
# Epoch 67/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.7717 - accuracy: 0.8807
# Epoch 67: val_loss did not improve from 0.92356
# 44/44 [==============================] - 1s 19ms/step - loss: 0.7685 - accuracy: 0.8810 - val_loss: 1.0438 - val_accuracy: 0.7917
# Epoch 68/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.7855 - accuracy: 0.8698
# Epoch 68: val_loss improved from 0.92356 to 0.89379, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 29ms/step - loss: 0.7877 - accuracy: 0.8688 - val_loss: 0.8938 - val_accuracy: 0.8230
# Epoch 69/200
# 43/44 [============================>.] - ETA: 0s - loss: 0.7657 - accuracy: 0.8756
# Epoch 69: val_loss did not improve from 0.89379
# 44/44 [==============================] - 1s 19ms/step - loss: 0.7649 - accuracy: 0.8760 - val_loss: 0.9063 - val_accuracy: 0.8323
# Epoch 70/200
# 44/44 [==============================] - ETA: 0s - loss: 0.7542 - accuracy: 0.8877
# Epoch 70: val_loss did not improve from 0.89379
# 44/44 [==============================] - 1s 19ms/step - loss: 0.7542 - accuracy: 0.8877 - val_loss: 0.9223 - val_accuracy: 0.8359
# Epoch 71/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.7219 - accuracy: 0.8971
# Epoch 71: val_loss did not improve from 0.89379
# 44/44 [==============================] - 1s 17ms/step - loss: 0.7240 - accuracy: 0.8972 - val_loss: 0.9004 - val_accuracy: 0.8313
# Epoch 72/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.7438 - accuracy: 0.8880
# Epoch 72: val_loss did not improve from 0.89379
# 44/44 [==============================] - 1s 16ms/step - loss: 0.7430 - accuracy: 0.8886 - val_loss: 1.0941 - val_accuracy: 0.7585
# Epoch 73/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.7367 - accuracy: 0.8885
# Epoch 73: val_loss improved from 0.89379 to 0.87919, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 26ms/step - loss: 0.7376 - accuracy: 0.8879 - val_loss: 0.8792 - val_accuracy: 0.8369
# Epoch 74/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.7137 - accuracy: 0.9012
# Epoch 74: val_loss did not improve from 0.87919
# 44/44 [==============================] - 1s 16ms/step - loss: 0.7134 - accuracy: 0.9006 - val_loss: 0.9514 - val_accuracy: 0.8184
# Epoch 75/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.7113 - accuracy: 0.8998
# Epoch 75: val_loss did not improve from 0.87919
# 44/44 [==============================] - 1s 17ms/step - loss: 0.7101 - accuracy: 0.9006 - val_loss: 0.9011 - val_accuracy: 0.8479
# Epoch 76/200
# 44/44 [==============================] - ETA: 0s - loss: 0.7134 - accuracy: 0.8981
# Epoch 76: val_loss did not improve from 0.87919
# 44/44 [==============================] - 1s 17ms/step - loss: 0.7134 - accuracy: 0.8981 - val_loss: 0.9456 - val_accuracy: 0.8258
# Epoch 77/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.7430 - accuracy: 0.8893
# Epoch 77: val_loss did not improve from 0.87919
# 44/44 [==============================] - 1s 16ms/step - loss: 0.7427 - accuracy: 0.8884 - val_loss: 0.9086 - val_accuracy: 0.8378
# Epoch 78/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.7019 - accuracy: 0.9041
# Epoch 78: val_loss did not improve from 0.87919
# 44/44 [==============================] - 1s 16ms/step - loss: 0.7025 - accuracy: 0.9041 - val_loss: 0.9121 - val_accuracy: 0.8461
# Epoch 79/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.7073 - accuracy: 0.9056
# Epoch 79: val_loss did not improve from 0.87919
# 44/44 [==============================] - 1s 17ms/step - loss: 0.7079 - accuracy: 0.9052 - val_loss: 0.9691 - val_accuracy: 0.8166
# Epoch 80/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.7576 - accuracy: 0.8880
# Epoch 80: val_loss did not improve from 0.87919
# 44/44 [==============================] - 1s 17ms/step - loss: 0.7568 - accuracy: 0.8877 - val_loss: 0.9680 - val_accuracy: 0.8359
# Epoch 81/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.7171 - accuracy: 0.9095
# Epoch 81: val_loss did not improve from 0.87919
# 44/44 [==============================] - 1s 16ms/step - loss: 0.7149 - accuracy: 0.9094 - val_loss: 0.9177 - val_accuracy: 0.8369
# Epoch 82/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.6885 - accuracy: 0.9134
# Epoch 82: val_loss did not improve from 0.87919
# 44/44 [==============================] - 1s 16ms/step - loss: 0.6842 - accuracy: 0.9140 - val_loss: 0.9234 - val_accuracy: 0.8369
# Epoch 83/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.6625 - accuracy: 0.9205
# Epoch 83: val_loss improved from 0.87919 to 0.86909, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 30ms/step - loss: 0.6628 - accuracy: 0.9195 - val_loss: 0.8691 - val_accuracy: 0.8673
# Epoch 84/200
# 43/44 [============================>.] - ETA: 0s - loss: 0.6854 - accuracy: 0.9140
# Epoch 84: val_loss improved from 0.86909 to 0.86267, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 2s 35ms/step - loss: 0.6846 - accuracy: 0.9140 - val_loss: 0.8627 - val_accuracy: 0.8664
# Epoch 85/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.6409 - accuracy: 0.9283
# Epoch 85: val_loss did not improve from 0.86267
# 44/44 [==============================] - 1s 17ms/step - loss: 0.6404 - accuracy: 0.9288 - val_loss: 0.8974 - val_accuracy: 0.8470
# Epoch 86/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.6645 - accuracy: 0.9163
# Epoch 86: val_loss did not improve from 0.86267
# 44/44 [==============================] - 1s 17ms/step - loss: 0.6625 - accuracy: 0.9168 - val_loss: 0.9116 - val_accuracy: 0.8525
# Epoch 87/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.6595 - accuracy: 0.9163
# Epoch 87: val_loss did not improve from 0.86267
# 44/44 [==============================] - 1s 17ms/step - loss: 0.6600 - accuracy: 0.9161 - val_loss: 0.8829 - val_accuracy: 0.8608
# Epoch 88/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.6579 - accuracy: 0.9244
# Epoch 88: val_loss did not improve from 0.86267
# 44/44 [==============================] - 1s 17ms/step - loss: 0.6617 - accuracy: 0.9234 - val_loss: 0.9782 - val_accuracy: 0.8267
# Epoch 89/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.7131 - accuracy: 0.9024
# Epoch 89: val_loss did not improve from 0.86267
# 44/44 [==============================] - 1s 17ms/step - loss: 0.7096 - accuracy: 0.9036 - val_loss: 0.9699 - val_accuracy: 0.8479
# Epoch 90/200
# 44/44 [==============================] - ETA: 0s - loss: 0.7138 - accuracy: 0.9025
# Epoch 90: val_loss did not improve from 0.86267
# 44/44 [==============================] - 1s 17ms/step - loss: 0.7138 - accuracy: 0.9025 - val_loss: 0.9716 - val_accuracy: 0.8442
# Epoch 91/200
# 44/44 [==============================] - ETA: 0s - loss: 0.6957 - accuracy: 0.9101
# Epoch 91: val_loss did not improve from 0.86267
# 44/44 [==============================] - 1s 17ms/step - loss: 0.6957 - accuracy: 0.9101 - val_loss: 0.9738 - val_accuracy: 0.8341
# Epoch 92/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.6340 - accuracy: 0.9354
# Epoch 92: val_loss did not improve from 0.86267
# 44/44 [==============================] - 1s 17ms/step - loss: 0.6319 - accuracy: 0.9357 - val_loss: 0.8943 - val_accuracy: 0.8544
# Epoch 93/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.5996 - accuracy: 0.9449
# Epoch 93: val_loss improved from 0.86267 to 0.85182, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 27ms/step - loss: 0.6005 - accuracy: 0.9447 - val_loss: 0.8518 - val_accuracy: 0.8581
# Epoch 94/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.6766 - accuracy: 0.9139
# Epoch 94: val_loss did not improve from 0.85182
# 44/44 [==============================] - 1s 17ms/step - loss: 0.6784 - accuracy: 0.9112 - val_loss: 0.9651 - val_accuracy: 0.8359
# Epoch 95/200
# 44/44 [==============================] - ETA: 0s - loss: 0.6511 - accuracy: 0.9294
# Epoch 95: val_loss did not improve from 0.85182
# 44/44 [==============================] - 1s 17ms/step - loss: 0.6511 - accuracy: 0.9294 - val_loss: 0.8888 - val_accuracy: 0.8645
# Epoch 96/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.6144 - accuracy: 0.9405
# Epoch 96: val_loss did not improve from 0.85182
# 44/44 [==============================] - 1s 17ms/step - loss: 0.6140 - accuracy: 0.9398 - val_loss: 0.9341 - val_accuracy: 0.8627
# Epoch 97/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.5964 - accuracy: 0.9434
# Epoch 97: val_loss did not improve from 0.85182
# 44/44 [==============================] - 1s 18ms/step - loss: 0.5995 - accuracy: 0.9437 - val_loss: 0.8924 - val_accuracy: 0.8654
# Epoch 98/200
# 42/44 [===========================>..] - ETA: 0s - loss: 0.6175 - accuracy: 0.9383
# Epoch 98: val_loss did not improve from 0.85182
# 44/44 [==============================] - 1s 19ms/step - loss: 0.6165 - accuracy: 0.9389 - val_loss: 0.9573 - val_accuracy: 0.8535
# Epoch 99/200
# 44/44 [==============================] - ETA: 0s - loss: 0.6482 - accuracy: 0.9237
# Epoch 99: val_loss did not improve from 0.85182
# 44/44 [==============================] - 1s 21ms/step - loss: 0.6482 - accuracy: 0.9237 - val_loss: 0.9009 - val_accuracy: 0.8535
# Epoch 100/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.6307 - accuracy: 0.9359
# Epoch 100: val_loss did not improve from 0.85182
# 44/44 [==============================] - 1s 17ms/step - loss: 0.6333 - accuracy: 0.9352 - val_loss: 0.8839 - val_accuracy: 0.8728
# Epoch 101/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.6163 - accuracy: 0.9400
# Epoch 101: val_loss did not improve from 0.85182
# 44/44 [==============================] - 1s 17ms/step - loss: 0.6170 - accuracy: 0.9387 - val_loss: 0.9931 - val_accuracy: 0.8415
# Epoch 102/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.6543 - accuracy: 0.9202
# Epoch 102: val_loss did not improve from 0.85182
# 44/44 [==============================] - 1s 16ms/step - loss: 0.6512 - accuracy: 0.9221 - val_loss: 0.9538 - val_accuracy: 0.8415
# Epoch 103/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.6413 - accuracy: 0.9263
# Epoch 103: val_loss did not improve from 0.85182
# 44/44 [==============================] - 1s 17ms/step - loss: 0.6498 - accuracy: 0.9232 - val_loss: 0.9997 - val_accuracy: 0.8147
# Epoch 104/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.7300 - accuracy: 0.9027
# Epoch 104: val_loss did not improve from 0.85182
# 44/44 [==============================] - 1s 16ms/step - loss: 0.7270 - accuracy: 0.9039 - val_loss: 1.0346 - val_accuracy: 0.8240
# Epoch 105/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.6553 - accuracy: 0.9263
# Epoch 105: val_loss did not improve from 0.85182
# 44/44 [==============================] - 1s 17ms/step - loss: 0.6543 - accuracy: 0.9269 - val_loss: 0.9038 - val_accuracy: 0.8700
# Epoch 106/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.6363 - accuracy: 0.9349
# Epoch 106: val_loss did not improve from 0.85182
# 44/44 [==============================] - 1s 17ms/step - loss: 0.6385 - accuracy: 0.9347 - val_loss: 1.0135 - val_accuracy: 0.8424
# Epoch 107/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.6222 - accuracy: 0.9400
# Epoch 107: val_loss did not improve from 0.85182
# 44/44 [==============================] - 1s 17ms/step - loss: 0.6219 - accuracy: 0.9401 - val_loss: 0.9183 - val_accuracy: 0.8525
# Epoch 108/200
# 41/44 [==========================>...] - ETA: 0s - loss: 0.6025 - accuracy: 0.9461
# Epoch 108: val_loss did not improve from 0.85182
# 44/44 [==============================] - 1s 18ms/step - loss: 0.6071 - accuracy: 0.9444 - val_loss: 0.9137 - val_accuracy: 0.8498
# Training completed in time:  0:01:55.011490

# %%
test_accuracy=vggish_model.evaluate(X_test_vggish,y_test,verbose=0)
print(test_accuracy[1])
# Out:
# 0.8580645322799683

# %%
filename= "/content/wavfiles/101308-5.wav"
audio, sample_rate = librosa.load(filename, res_type='kaiser_fast')
mfccs_features = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=21)
mfccs_scaled_features = np.mean(mfccs_features.T,axis=0)

print(mfccs_scaled_features)
mfccs_scaled_features=mfccs_scaled_features.reshape(1,-1)
print(mfccs_scaled_features)
print(mfccs_scaled_features.shape)
predicted_label = vggish_model.predict(mfccs_scaled_features)
predicted_class_index = np.argmax(predicted_label)
prediction_class = labelencoder.inverse_transform([predicted_class_index])
print(f"The predicted bird is: {prediction_class}")
# Out:
# [-2.0822256e+02  4.7379898e+01 -4.1454041e+01  4.0189480e+01
#  -2.3528139e+01 -5.5456023e+00  1.8695351e+01  4.9905853e+00
#  -7.6499872e+00  1.0349575e+01 -5.9336252e+00  6.0427871e+00
#  -5.0681181e+00  8.7633657e-01  1.0736929e+00  2.0575190e+00
#  -6.6417375e+00  6.8580632e+00 -2.3993657e+00 -3.3767705e+00
#  -1.9962448e-01]
# [[-2.0822256e+02  4.7379898e+01 -4.1454041e+01  4.0189480e+01
#   -2.3528139e+01 -5.5456023e+00  1.8695351e+01  4.9905853e+00
#   -7.6499872e+00  1.0349575e+01 -5.9336252e+00  6.0427871e+00
#   -5.0681181e+00  8.7633657e-01  1.0736929e+00  2.0575190e+00
#   -6.6417375e+00  6.8580632e+00 -2.3993657e+00 -3.3767705e+00
#   -1.9962448e-01]]
# (1, 21)
# 1/1 [==============================] - 0s 283ms/step
# The predicted bird is: ['Northern Mockingbird']

# %% [markdown]
# $\Large \color{#495867}{\texttt{GRU}}$

# %%
from keras.models import Sequential
from keras.layers import GRU, Dense, Dropout
from keras.callbacks import ModelCheckpoint, EarlyStopping

# Define GRU model
model_gru = Sequential()
model_gru.add(GRU(128, input_shape=(X_train.shape[1], 1), return_sequences=True))
model_gru.add(GRU(128))
model_gru.add(Dropout(0.5))
model_gru.add(Dense(num_labels, activation='softmax'))

model_gru.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model_gru.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 21, 128)           50304
#
#  gru_1 (GRU)                 (None, 128)               99072
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 150021 (586.02 KB)
# Trainable params: 150021 (586.02 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
X_train_gru = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test_gru = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

checkpointer_gru = ModelCheckpoint(filepath='saved_models/audio_classification_gru.hdf5', verbose=1, save_best_only=True)
np.save("gru_labelencoder.npy", labelencoder.classes_)
early_stopping_gru = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# %%
history_gru = model_gru.fit(X_train_gru, y_train, epochs=30, batch_size=40,validation_data=(X_test_gru, y_test),callbacks=[checkpointer_gru, early_stopping_gru])
# Out:
# Epoch 1/30
# 105/109 [===========================>..] - ETA: 0s - loss: 1.5857 - accuracy: 0.2550
# Epoch 1: val_loss improved from inf to 1.55258, saving model to saved_models/audio_classification_gru.hdf5
# 109/109 [==============================] - 5s 14ms/step - loss: 1.5866 - accuracy: 0.2534 - val_loss: 1.5526 - val_accuracy: 0.2673
# Epoch 2/30
# 108/109 [============================>.] - ETA: 0s - loss: 1.5015 - accuracy: 0.3194
# Epoch 2: val_loss improved from 1.55258 to 1.39268, saving model to saved_models/audio_classification_gru.hdf5
# 109/109 [==============================] - 1s 7ms/step - loss: 1.5005 - accuracy: 0.3193 - val_loss: 1.3927 - val_accuracy: 0.3779
# Epoch 3/30
# 109/109 [==============================] - ETA: 0s - loss: 1.3063 - accuracy: 0.4434
# Epoch 3: val_loss improved from 1.39268 to 1.12390, saving model to saved_models/audio_classification_gru.hdf5
# 109/109 [==============================] - 1s 10ms/step - loss: 1.3063 - accuracy: 0.4434 - val_loss: 1.1239 - val_accuracy: 0.4903
# Epoch 4/30
# 104/109 [===========================>..] - ETA: 0s - loss: 1.0888 - accuracy: 0.5368
# Epoch 4: val_loss improved from 1.12390 to 0.96645, saving model to saved_models/audio_classification_gru.hdf5
# 109/109 [==============================] - 1s 9ms/step - loss: 1.0861 - accuracy: 0.5361 - val_loss: 0.9665 - val_accuracy: 0.6028
# Epoch 5/30
# 104/109 [===========================>..] - ETA: 0s - loss: 0.9401 - accuracy: 0.6149
# Epoch 5: val_loss improved from 0.96645 to 0.87893, saving model to saved_models/audio_classification_gru.hdf5
# 109/109 [==============================] - 1s 7ms/step - loss: 0.9429 - accuracy: 0.6131 - val_loss: 0.8789 - val_accuracy: 0.6369
# Epoch 6/30
# 105/109 [===========================>..] - ETA: 0s - loss: 0.8292 - accuracy: 0.6650
# Epoch 6: val_loss improved from 0.87893 to 0.77575, saving model to saved_models/audio_classification_gru.hdf5
# 109/109 [==============================] - 1s 7ms/step - loss: 0.8259 - accuracy: 0.6666 - val_loss: 0.7757 - val_accuracy: 0.6793
# Epoch 7/30
# 109/109 [==============================] - ETA: 0s - loss: 0.7311 - accuracy: 0.7088
# Epoch 7: val_loss improved from 0.77575 to 0.70024, saving model to saved_models/audio_classification_gru.hdf5
# 109/109 [==============================] - 1s 8ms/step - loss: 0.7311 - accuracy: 0.7088 - val_loss: 0.7002 - val_accuracy: 0.7207
# Epoch 8/30
# 109/109 [==============================] - ETA: 0s - loss: 0.6536 - accuracy: 0.7418
# Epoch 8: val_loss improved from 0.70024 to 0.67380, saving model to saved_models/audio_classification_gru.hdf5
# 109/109 [==============================] - 1s 8ms/step - loss: 0.6536 - accuracy: 0.7418 - val_loss: 0.6738 - val_accuracy: 0.7502
# Epoch 9/30
# 105/109 [===========================>..] - ETA: 0s - loss: 0.5849 - accuracy: 0.7769
# Epoch 9: val_loss improved from 0.67380 to 0.61020, saving model to saved_models/audio_classification_gru.hdf5
# 109/109 [==============================] - 1s 7ms/step - loss: 0.5861 - accuracy: 0.7766 - val_loss: 0.6102 - val_accuracy: 0.7687
# Epoch 10/30
# 109/109 [==============================] - ETA: 0s - loss: 0.4953 - accuracy: 0.8148
# Epoch 10: val_loss improved from 0.61020 to 0.54368, saving model to saved_models/audio_classification_gru.hdf5
# 109/109 [==============================] - 1s 7ms/step - loss: 0.4953 - accuracy: 0.8148 - val_loss: 0.5437 - val_accuracy: 0.7954
# Epoch 11/30
# 106/109 [============================>.] - ETA: 0s - loss: 0.4132 - accuracy: 0.8540
# Epoch 11: val_loss improved from 0.54368 to 0.50027, saving model to saved_models/audio_classification_gru.hdf5
# 109/109 [==============================] - 1s 7ms/step - loss: 0.4143 - accuracy: 0.8534 - val_loss: 0.5003 - val_accuracy: 0.8101
# Epoch 12/30
# 108/109 [============================>.] - ETA: 0s - loss: 0.3518 - accuracy: 0.8736
# Epoch 12: val_loss improved from 0.50027 to 0.47901, saving model to saved_models/audio_classification_gru.hdf5
# 109/109 [==============================] - 1s 8ms/step - loss: 0.3513 - accuracy: 0.8739 - val_loss: 0.4790 - val_accuracy: 0.8249
# Epoch 13/30
# 106/109 [============================>.] - ETA: 0s - loss: 0.3130 - accuracy: 0.8934
# Epoch 13: val_loss improved from 0.47901 to 0.46491, saving model to saved_models/audio_classification_gru.hdf5
# 109/109 [==============================] - 1s 8ms/step - loss: 0.3153 - accuracy: 0.8928 - val_loss: 0.4649 - val_accuracy: 0.8341
# Epoch 14/30
# 107/109 [============================>.] - ETA: 0s - loss: 0.2618 - accuracy: 0.9065
# Epoch 14: val_loss did not improve from 0.46491
# 109/109 [==============================] - 1s 7ms/step - loss: 0.2618 - accuracy: 0.9059 - val_loss: 0.4706 - val_accuracy: 0.8387
# Epoch 15/30
# 107/109 [============================>.] - ETA: 0s - loss: 0.2167 - accuracy: 0.9280
# Epoch 15: val_loss did not improve from 0.46491
# 109/109 [==============================] - 1s 7ms/step - loss: 0.2163 - accuracy: 0.9278 - val_loss: 0.4894 - val_accuracy: 0.8415
# Epoch 16/30
# 105/109 [===========================>..] - ETA: 0s - loss: 0.1931 - accuracy: 0.9360
# Epoch 16: val_loss improved from 0.46491 to 0.42069, saving model to saved_models/audio_classification_gru.hdf5
# 109/109 [==============================] - 1s 9ms/step - loss: 0.1917 - accuracy: 0.9371 - val_loss: 0.4207 - val_accuracy: 0.8691
# Epoch 17/30
# 106/109 [============================>.] - ETA: 0s - loss: 0.1736 - accuracy: 0.9427
# Epoch 17: val_loss did not improve from 0.42069
# 109/109 [==============================] - 1s 10ms/step - loss: 0.1734 - accuracy: 0.9424 - val_loss: 0.4309 - val_accuracy: 0.8581
# Epoch 18/30
# 102/109 [===========================>..] - ETA: 0s - loss: 0.1172 - accuracy: 0.9632
# Epoch 18: val_loss did not improve from 0.42069
# 109/109 [==============================] - 1s 9ms/step - loss: 0.1184 - accuracy: 0.9633 - val_loss: 0.4995 - val_accuracy: 0.8442
# Epoch 19/30
# 102/109 [===========================>..] - ETA: 0s - loss: 0.0865 - accuracy: 0.9745
# Epoch 19: val_loss did not improve from 0.42069
# 109/109 [==============================] - 1s 7ms/step - loss: 0.0897 - accuracy: 0.9735 - val_loss: 0.4431 - val_accuracy: 0.8839
# Epoch 20/30
# 102/109 [===========================>..] - ETA: 0s - loss: 0.0994 - accuracy: 0.9679
# Epoch 20: val_loss did not improve from 0.42069
# 109/109 [==============================] - 1s 8ms/step - loss: 0.0996 - accuracy: 0.9675 - val_loss: 0.4489 - val_accuracy: 0.8866
# Epoch 21/30
# 106/109 [============================>.] - ETA: 0s - loss: 0.0793 - accuracy: 0.9736
# Epoch 21: val_loss did not improve from 0.42069
# 109/109 [==============================] - 1s 8ms/step - loss: 0.0786 - accuracy: 0.9739 - val_loss: 0.4794 - val_accuracy: 0.8710

# %%
test_accuracy=model_gru.evaluate(X_test_gru,y_test,verbose=0)
print(test_accuracy[1])
# Out:
# 0.8691244125366211

# %%
filename= "/content/wavfiles/101308-5.wav"
audio, sample_rate = librosa.load(filename, res_type='kaiser_fast')
mfccs_features = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=21)
mfccs_scaled_features = np.mean(mfccs_features.T,axis=0)

print(mfccs_scaled_features)
mfccs_scaled_features=mfccs_scaled_features.reshape(1,-1)
print(mfccs_scaled_features)
print(mfccs_scaled_features.shape)
predicted_label = model_gru.predict(mfccs_scaled_features)
predicted_class_index = np.argmax(predicted_label)
prediction_class = labelencoder.inverse_transform([predicted_class_index])
print(f"The predicted bird is: {prediction_class}")
# Out:
# [-2.0822256e+02  4.7379898e+01 -4.1454041e+01  4.0189480e+01
#  -2.3528139e+01 -5.5456023e+00  1.8695351e+01  4.9905853e+00
#  -7.6499872e+00  1.0349575e+01 -5.9336252e+00  6.0427871e+00
#  -5.0681181e+00  8.7633657e-01  1.0736929e+00  2.0575190e+00
#  -6.6417375e+00  6.8580632e+00 -2.3993657e+00 -3.3767705e+00
#  -1.9962448e-01]
# [[-2.0822256e+02  4.7379898e+01 -4.1454041e+01  4.0189480e+01
#   -2.3528139e+01 -5.5456023e+00  1.8695351e+01  4.9905853e+00
#   -7.6499872e+00  1.0349575e+01 -5.9336252e+00  6.0427871e+00
#   -5.0681181e+00  8.7633657e-01  1.0736929e+00  2.0575190e+00
#   -6.6417375e+00  6.8580632e+00 -2.3993657e+00 -3.3767705e+00
#   -1.9962448e-01]]
# (1, 21)
# 1/1 [==============================] - 1s 563ms/step
# The predicted bird is: ['Northern Mockingbird']

# %%
from sklearn.metrics import classification_report
ypred = model.predict(X_test)
ypred = np.argmax(ypred, axis=1)
y_test_pred = np.argmax(y_test, axis=1)
print(classification_report(y_test_pred, ypred))
# Out:
# 34/34 [==============================] - 0s 2ms/step
#               precision    recall  f1-score   support
#
#            0       0.84      0.84      0.84       212
#            1       0.73      0.65      0.69       189
#            2       0.85      0.84      0.85       214
#            3       0.84      0.68      0.75       226
#            4       0.65      0.83      0.73       244
#
#     accuracy                           0.77      1085
#    macro avg       0.78      0.77      0.77      1085
# weighted avg       0.78      0.77      0.77      1085

# %%
from sklearn.metrics import classification_report
ypred = model_lstm.predict(X_test)
ypred = np.argmax(ypred, axis=1)
y_test_pred = np.argmax(y_test, axis=1)
print(classification_report(y_test_pred, ypred))
# Out:
# 34/34 [==============================] - 0s 3ms/step
#               precision    recall  f1-score   support
#
#            0       0.94      0.90      0.92       212
#            1       0.90      0.87      0.88       189
#            2       0.90      0.93      0.91       214
#            3       0.91      0.87      0.89       226
#            4       0.85      0.91      0.88       244
#
#     accuracy                           0.90      1085
#    macro avg       0.90      0.90      0.90      1085
# weighted avg       0.90      0.90      0.90      1085

# %%
from sklearn.metrics import classification_report
ypred = vggish_model.predict(X_test)
ypred = np.argmax(ypred, axis=1)
y_test_pred = np.argmax(y_test, axis=1)
print(classification_report(y_test_pred, ypred))
# Out:
# 34/34 [==============================] - 0s 5ms/step
#               precision    recall  f1-score   support
#
#            0       0.92      0.82      0.86       212
#            1       0.80      0.87      0.83       189
#            2       0.91      0.90      0.90       214
#            3       0.81      0.87      0.84       226
#            4       0.86      0.84      0.85       244
#
#     accuracy                           0.86      1085
#    macro avg       0.86      0.86      0.86      1085
# weighted avg       0.86      0.86      0.86      1085

# %%
import matplotlib.pyplot as plt
import os

def plot_metrics(history, title, save_path=None):
    plt.figure(figsize=(13, 6))

    # Plot accuracy
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title(f'{title} - Accuracy')
    plt.legend()

    # Plot loss
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title(f'{title} - Loss')
    plt.legend()

    plt.tight_layout()

    if save_path:
        os.makedirs(os.path.dirname(save_path), exist_ok=True)
        plt.savefig(save_path)
    else:
        plt.show()

# Plot graphs for the original model
plot_metrics(history, 'Sequential', 'figures/sequential_metrics.jpg')

# Plot graphs for the LSTM model
plot_metrics(history_lstm, 'LSTM', 'figures/lstm_metrics.jpg')

# Plot graphs for the VGGish model
plot_metrics(history_vggish, 'VGGish', 'figures/vggish_metrics.jpg')

# Plot graphs for the GRU model
plot_metrics(history_gru, 'GRU', 'figures/gru_metrics.jpg')
