# %% [markdown]
# <a href="https://colab.research.google.com/github/RahulBattula/Bird-Audio-Classification/blob/main/Practice_Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# $\huge \color{#1C110A}{\textbf{Bird's Audio Classification}}$

# %%
import pandas as pd
import os
import librosa

audio_dataset_path='/content/wavfiles'
metadata=pd.read_csv('/content/bird_songs_metadata.csv',usecols=['name','filename'])
metadata.head()
# Out:
#             name      filename
# 0  Bewick's Wren  557838-0.wav
# 1  Bewick's Wren  557838-1.wav
# 2  Bewick's Wren  557838-4.wav
# 3  Bewick's Wren  557838-5.wav
# 4  Bewick's Wren  557838-6.wav

# %%
metadata['name'].value_counts()
# Out:
# Song Sparrow            1256
# Northern Mockingbird    1182
# Northern Cardinal       1074
# American Robin          1017
# Bewick's Wren            893
# Name: name, dtype: int64

# %%
# import os
# os.environ['KAGGLE_USERNAME'] = 'rahulbattula1'
# os.environ['KAGGLE_KEY'] = '7220f5ccf343309b5f337d6ad9b49afc'

# %%
# !kaggle datasets download -d vinayshanbhag/bird-song-data-set

# %%
# !unzip bird-song-data-set.zip

# %%
ls -l ./wavfiles/ | grep -c ^-
# Out:
# 9107

# %%
import os
import librosa
import pandas as pd

audio_folder = "/content/wavfiles"
metadata = pd.read_csv('/content/bird_songs_metadata.csv', usecols=['name', 'filename'])

# Function to calculate audio duration and print files with 3 seconds duration
def get_audio_duration(row):
    file_path = os.path.join(audio_folder, row['filename'])

    # Check if the file exists
    if os.path.exists(file_path):
        try:
            audio_data, _ = librosa.load(file_path, sr=None)
            duration = librosa.get_duration(y=audio_data)

            return duration
        except Exception as e:
            print(f"Error processing {file_path}: {e}")
            return None
    else:
        print(f"File not found: {file_path}")
        return None

# Calculating duration for each audio file
metadata['duration'] = metadata.apply(get_audio_duration, axis=1)

count_greater_than_3s = (metadata['duration'] > 3).sum()
count_less_than_3s = (metadata['duration'] < 3).sum()
count_equal_to_3s = (metadata['duration'] == 3).sum()

print(f"Number of files with duration greater than 3 seconds: {count_greater_than_3s}")
print(f"Number of files with duration less than 3 seconds: {count_less_than_3s}")
print(f"Number of files with duration equal to 3 seconds: {count_equal_to_3s}")
# Out:
# Number of files with duration greater than 3 seconds: 0
# Number of files with duration less than 3 seconds: 0
# Number of files with duration equal to 3 seconds: 5422

# %%
import random
from scipy.io import wavfile
from IPython.display import Audio, display
import matplotlib.pyplot as plt

audio_folder = "/content/wavfiles"

def plot_and_play_wav(metadata, audio_folder):
    random_row = metadata.sample(n=1).iloc[0]
    audio_file_path = os.path.join(audio_folder, random_row['filename'])

    sample_rate, audio_data = wavfile.read(audio_file_path)
    random_color = '#%06x' % random.randint(0, 0xFFFFFF)

    print(f"Species: {random_row['name']}")
    print(f"Sample rate: {sample_rate}")
    print(f"Bit depth: {audio_data.dtype.itemsize * 8} bits")
    print(f"Bit rate: {sample_rate * audio_data.dtype.itemsize * 8} bps")
    print(f"Number of channels: {audio_data.shape[1] if len(audio_data.shape) > 1 else 1}")
    print(f"Audio data shape: {audio_data.shape}")
    print(f"Audio file path: {audio_file_path}")

    plt.figure(figsize=(8, 3))
    plt.plot(audio_data, color=random_color)
    plt.xlabel("Time (samples)")
    plt.ylabel("Amplitude")
    plt.title(f"Waveform - {random_row['name']}")
    plt.show()

    # Play the audio file
    display(Audio(audio_file_path))

# Iterate through each unique species and plot a random waveform
unique_species = metadata['name'].unique()
for species in unique_species:
    species_metadata = metadata[metadata['name'] == species]
    plot_and_play_wav(species_metadata, audio_folder)
# Out:
# Species: Bewick's Wren
# Sample rate: 22050
# Bit depth: 32 bits
# Bit rate: 705600 bps
# Number of channels: 1
# Audio data shape: (66150,)
# Audio file path: /content/wavfiles/173148-0.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Species: Northern Mockingbird
# Sample rate: 22050
# Bit depth: 32 bits
# Bit rate: 705600 bps
# Number of channels: 1
# Audio data shape: (66150,)
# Audio file path: /content/wavfiles/14212-3.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Species: American Robin
# Sample rate: 22050
# Bit depth: 32 bits
# Bit rate: 705600 bps
# Number of channels: 1
# Audio data shape: (66150,)
# Audio file path: /content/wavfiles/469605-6.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Species: Song Sparrow
# Sample rate: 22050
# Bit depth: 32 bits
# Bit rate: 705600 bps
# Number of channels: 1
# Audio data shape: (66150,)
# Audio file path: /content/wavfiles/18388-1.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Species: Northern Cardinal
# Sample rate: 22050
# Bit depth: 32 bits
# Bit rate: 705600 bps
# Number of channels: 1
# Audio data shape: (66150,)
# Audio file path: /content/wavfiles/321375-2.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# $\Large \color{blue}{\texttt{MFCC}}$

# %%
def features_extractor(file):
    audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast')
    mfccs_features = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=21)
    mfccs_scaled_features = np.mean(mfccs_features.T,axis=0)
    return mfccs_scaled_features

# %%
import numpy as np
from tqdm import tqdm
extracted_features=[]
for index_num,row in tqdm(metadata.iterrows()):
    file_name = os.path.join(os.path.abspath(audio_dataset_path), str(row["filename"]))
    final_class_labels=row["name"]
    data=features_extractor(file_name)
    extracted_features.append([data,final_class_labels])
# Out:
# 5422it [01:22, 65.79it/s]

# %%
extracted_features_df=pd.DataFrame(extracted_features,columns=['feature','class'])
extracted_features_df.head()
# Out:
#                                              feature          class
# 0  [-132.85225, 81.13991, 17.018225, 54.974297, -...  Bewick's Wren
# 1  [-147.74393, 99.42544, 20.885645, 44.11881, 1....  Bewick's Wren
# 2  [-92.42778, 84.10636, 17.362778, 53.86046, -8....  Bewick's Wren
# 3  [-93.07557, 81.17431, 16.225544, 52.088425, -8...  Bewick's Wren
# 4  [-107.959145, 92.416, 17.773256, 43.13245, -1....  Bewick's Wren

# %%
extracted_features_df['feature'].shape
# Out:
# (5422,)

# %%
extracted_features_df['feature'][0].shape
# Out:
# (21,)

# %%
pd.DataFrame(extracted_features_df['feature'][0])
# Out:
#              0
# 0  -132.852249
# 1    81.139908
# 2    17.018225
# 3    54.974297
# 4   -10.344643
# 5    24.577351
# 6     3.074978
# 7    19.339340
# 8     5.271629
# 9    15.171051
# 10   -0.072439
# 11    7.569126
# 12   10.887994
# 13    2.635523
# 14   -0.179219
# 15   10.019793
# 16   -4.870444
# 17    4.988724
# 18   -3.737550
# 19    6.274313
# 20   -1.888968

# %%
type(extracted_features_df['feature'])
# Out:
# pandas.core.series.Series

# %%
X=np.array(extracted_features_df['feature'].tolist())
y=np.array(extracted_features_df['class'].tolist())

# %%
type(X)
# Out:
# numpy.ndarray

# %%
X.shape
# Out:
# (5422, 21)

# %%
X[0]
# Out:
# array([-1.3285225e+02,  8.1139908e+01,  1.7018225e+01,  5.4974297e+01,
#        -1.0344643e+01,  2.4577351e+01,  3.0749784e+00,  1.9339340e+01,
#         5.2716293e+00,  1.5171051e+01, -7.2438858e-02,  7.5691257e+00,
#         1.0887994e+01,  2.6355228e+00, -1.7921886e-01,  1.0019793e+01,
#        -4.8704443e+00,  4.9887242e+00, -3.7375500e+00,  6.2743134e+00,
#        -1.8889681e+00], dtype=float32)

# %%
y.shape
# Out:
# (5422,)

# %%
y[0:10]
# Out:
# array(["Bewick's Wren", "Bewick's Wren", "Bewick's Wren", "Bewick's Wren",
#        "Bewick's Wren", "Bewick's Wren", "Bewick's Wren", "Bewick's Wren",
#        "Bewick's Wren", "Bewick's Wren"], dtype='<U20')

# %%
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
labelencoder=LabelEncoder()
y=to_categorical(labelencoder.fit_transform(y))

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
X_train
# Out:
# array([[-271.31616  ,  -26.419064 ,  -63.76474  , ...,    3.886096 ,
#            0.5488589,   -2.5603206],
#        [-401.3699   ,  -31.111534 ,  -92.245224 , ...,   -5.4280133,
#           -4.4046926,   -6.6012044],
#        [-366.7505   ,   -3.9161208, -118.178535 , ...,    5.0247483,
#           -4.953003 ,    3.951971 ],
#        ...,
#        [ -63.003605 ,   88.0372   ,  -30.77855  , ...,   -8.846015 ,
#           -8.056691 ,  -10.128775 ],
#        [-361.9076   ,   30.67692  ,  -64.73752  , ...,   -7.2064624,
#            3.933869 ,    9.0967455],
#        [-168.7206   ,    1.3105384,  -65.46302  , ...,   -5.7669735,
#           -2.3251848,   -5.445334 ]], dtype=float32)

# %%
X_train.shape
# Out:
# (4337, 21)

# %%
X_test.shape
# Out:
# (1085, 21)

# %%
y_train.shape
# Out:
# (4337, 5)

# %%
y_test.shape
# Out:
# (1085, 5)

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.15.0

# %%
from tensorflow.keras.models import Sequential,Model
from tensorflow.keras.layers import Dense,Dropout,Activation,Flatten,LSTM, Input, Conv1D, MaxPooling1D
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import Adam
from sklearn import metrics
import warnings
warnings.filterwarnings('ignore')

# %%
num_labels=y.shape[1]

# %%
num_labels
# Out:
# 5

# %% [markdown]
# $\Large \color{orange}{\texttt{Sequential}}$

# %%
model=Sequential()
###first layer
model.add(Dense(100,input_shape=(21,)))
model.add(Activation('relu'))
model.add(Dropout(0.5))
###second layer
model.add(Dense(200))
model.add(Activation('relu'))
model.add(Dropout(0.5))
###third layer
model.add(Dense(100))
model.add(Activation('relu'))
model.add(Dropout(0.5))
###final layer
model.add(Dense(num_labels))
model.add(Activation('softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 100)               2200
#
#  activation (Activation)     (None, 100)               0
#
#  dropout (Dropout)           (None, 100)               0
#
#  dense_1 (Dense)             (None, 200)               20200
#
#  activation_1 (Activation)   (None, 200)               0
#
#  dropout_1 (Dropout)         (None, 200)               0
#
#  dense_2 (Dense)             (None, 100)               20100
#
#  activation_2 (Activation)   (None, 100)               0
#
#  dropout_2 (Dropout)         (None, 100)               0
#
#  dense_3 (Dense)             (None, 5)                 505
#
#  activation_3 (Activation)   (None, 5)                 0
#
# =================================================================
# Total params: 43005 (167.99 KB)
# Trainable params: 43005 (167.99 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',metrics=['accuracy'],optimizer='adam')

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
from datetime import datetime
checkpointer = ModelCheckpoint(filepath='saved_models/audio_classification.hdf5',
                               verbose=1, save_best_only=True)
start = datetime.now()

history = model.fit(X_train, y_train, batch_size=32, epochs=100,
                    validation_data=(X_test, y_test), callbacks=[checkpointer], verbose=1)

duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Epoch 1/100
# 127/136 [===========================>..] - ETA: 0s - loss: 13.0009 - accuracy: 0.2404
# Epoch 1: val_loss improved from inf to 1.53214, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 6s 6ms/step - loss: 12.4743 - accuracy: 0.2398 - val_loss: 1.5321 - val_accuracy: 0.2147
# Epoch 2/100
# 130/136 [===========================>..] - ETA: 0s - loss: 2.7762 - accuracy: 0.2257
# Epoch 2: val_loss did not improve from 1.53214
# 136/136 [==============================] - 1s 6ms/step - loss: 2.7423 - accuracy: 0.2257 - val_loss: 1.6048 - val_accuracy: 0.2452
# Epoch 3/100
# 133/136 [============================>.] - ETA: 0s - loss: 1.8598 - accuracy: 0.2359
# Epoch 3: val_loss did not improve from 1.53214
# 136/136 [==============================] - 1s 6ms/step - loss: 1.8618 - accuracy: 0.2350 - val_loss: 1.6070 - val_accuracy: 0.2258
# Epoch 4/100
# 127/136 [===========================>..] - ETA: 0s - loss: 1.6981 - accuracy: 0.2372
# Epoch 4: val_loss did not improve from 1.53214
# 136/136 [==============================] - 1s 6ms/step - loss: 1.6956 - accuracy: 0.2384 - val_loss: 1.6064 - val_accuracy: 0.2249
# Epoch 5/100
# 126/136 [==========================>...] - ETA: 0s - loss: 1.6443 - accuracy: 0.2428
# Epoch 5: val_loss did not improve from 1.53214
# 136/136 [==============================] - 1s 7ms/step - loss: 1.6462 - accuracy: 0.2446 - val_loss: 1.5998 - val_accuracy: 0.2424
# Epoch 6/100
# 125/136 [==========================>...] - ETA: 0s - loss: 1.6203 - accuracy: 0.2520
# Epoch 6: val_loss did not improve from 1.53214
# 136/136 [==============================] - 1s 4ms/step - loss: 1.6158 - accuracy: 0.2527 - val_loss: 1.5753 - val_accuracy: 0.2876
# Epoch 7/100
# 129/136 [===========================>..] - ETA: 0s - loss: 1.5990 - accuracy: 0.2556
# Epoch 7: val_loss did not improve from 1.53214
# 136/136 [==============================] - 1s 5ms/step - loss: 1.5978 - accuracy: 0.2594 - val_loss: 1.5585 - val_accuracy: 0.2995
# Epoch 8/100
# 133/136 [============================>.] - ETA: 0s - loss: 1.5968 - accuracy: 0.2660
# Epoch 8: val_loss improved from 1.53214 to 1.51331, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 1.5981 - accuracy: 0.2659 - val_loss: 1.5133 - val_accuracy: 0.3336
# Epoch 9/100
# 130/136 [===========================>..] - ETA: 0s - loss: 1.5571 - accuracy: 0.2779
# Epoch 9: val_loss improved from 1.51331 to 1.46998, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 1.5575 - accuracy: 0.2767 - val_loss: 1.4700 - val_accuracy: 0.3548
# Epoch 10/100
# 130/136 [===========================>..] - ETA: 0s - loss: 1.5248 - accuracy: 0.2923
# Epoch 10: val_loss improved from 1.46998 to 1.37275, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 1.5222 - accuracy: 0.2940 - val_loss: 1.3727 - val_accuracy: 0.3751
# Epoch 11/100
# 136/136 [==============================] - ETA: 0s - loss: 1.4945 - accuracy: 0.2878
# Epoch 11: val_loss improved from 1.37275 to 1.35576, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 4ms/step - loss: 1.4945 - accuracy: 0.2878 - val_loss: 1.3558 - val_accuracy: 0.3502
# Epoch 12/100
# 125/136 [==========================>...] - ETA: 0s - loss: 1.4673 - accuracy: 0.2980
# Epoch 12: val_loss improved from 1.35576 to 1.25418, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 1.4638 - accuracy: 0.2970 - val_loss: 1.2542 - val_accuracy: 0.3834
# Epoch 13/100
# 135/136 [============================>.] - ETA: 0s - loss: 1.4293 - accuracy: 0.3234
# Epoch 13: val_loss improved from 1.25418 to 1.24103, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 1.4295 - accuracy: 0.3237 - val_loss: 1.2410 - val_accuracy: 0.3862
# Epoch 14/100
# 129/136 [===========================>..] - ETA: 0s - loss: 1.3969 - accuracy: 0.3224
# Epoch 14: val_loss improved from 1.24103 to 1.21223, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 1.3960 - accuracy: 0.3221 - val_loss: 1.2122 - val_accuracy: 0.3880
# Epoch 15/100
# 127/136 [===========================>..] - ETA: 0s - loss: 1.3862 - accuracy: 0.3317
# Epoch 15: val_loss did not improve from 1.21223
# 136/136 [==============================] - 1s 4ms/step - loss: 1.3864 - accuracy: 0.3336 - val_loss: 1.2206 - val_accuracy: 0.3917
# Epoch 16/100
# 124/136 [==========================>...] - ETA: 0s - loss: 1.3629 - accuracy: 0.3382
# Epoch 16: val_loss improved from 1.21223 to 1.18999, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 1.3662 - accuracy: 0.3383 - val_loss: 1.1900 - val_accuracy: 0.3963
# Epoch 17/100
# 124/136 [==========================>...] - ETA: 0s - loss: 1.3582 - accuracy: 0.3516
# Epoch 17: val_loss did not improve from 1.18999
# 136/136 [==============================] - 1s 4ms/step - loss: 1.3548 - accuracy: 0.3516 - val_loss: 1.2106 - val_accuracy: 0.3889
# Epoch 18/100
# 126/136 [==========================>...] - ETA: 0s - loss: 1.3347 - accuracy: 0.3631
# Epoch 18: val_loss improved from 1.18999 to 1.18737, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 1.3309 - accuracy: 0.3668 - val_loss: 1.1874 - val_accuracy: 0.4147
# Epoch 19/100
# 124/136 [==========================>...] - ETA: 0s - loss: 1.3317 - accuracy: 0.3700
# Epoch 19: val_loss did not improve from 1.18737
# 136/136 [==============================] - 1s 4ms/step - loss: 1.3325 - accuracy: 0.3657 - val_loss: 1.1964 - val_accuracy: 0.4313
# Epoch 20/100
# 135/136 [============================>.] - ETA: 0s - loss: 1.3070 - accuracy: 0.3745
# Epoch 20: val_loss improved from 1.18737 to 1.16688, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 1.3070 - accuracy: 0.3742 - val_loss: 1.1669 - val_accuracy: 0.4147
# Epoch 21/100
# 136/136 [==============================] - ETA: 0s - loss: 1.2880 - accuracy: 0.3756
# Epoch 21: val_loss did not improve from 1.16688
# 136/136 [==============================] - 1s 6ms/step - loss: 1.2880 - accuracy: 0.3756 - val_loss: 1.1728 - val_accuracy: 0.4111
# Epoch 22/100
# 135/136 [============================>.] - ETA: 0s - loss: 1.2978 - accuracy: 0.3866
# Epoch 22: val_loss did not improve from 1.16688
# 136/136 [==============================] - 1s 6ms/step - loss: 1.2978 - accuracy: 0.3874 - val_loss: 1.1728 - val_accuracy: 0.4258
# Epoch 23/100
# 128/136 [===========================>..] - ETA: 0s - loss: 1.2786 - accuracy: 0.3762
# Epoch 23: val_loss improved from 1.16688 to 1.14713, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 6ms/step - loss: 1.2810 - accuracy: 0.3768 - val_loss: 1.1471 - val_accuracy: 0.4415
# Epoch 24/100
# 123/136 [==========================>...] - ETA: 0s - loss: 1.2578 - accuracy: 0.3948
# Epoch 24: val_loss did not improve from 1.14713
# 136/136 [==============================] - 1s 6ms/step - loss: 1.2585 - accuracy: 0.3929 - val_loss: 1.1519 - val_accuracy: 0.4359
# Epoch 25/100
# 128/136 [===========================>..] - ETA: 0s - loss: 1.2732 - accuracy: 0.3997
# Epoch 25: val_loss improved from 1.14713 to 1.14691, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 1.2691 - accuracy: 0.4019 - val_loss: 1.1469 - val_accuracy: 0.4562
# Epoch 26/100
# 127/136 [===========================>..] - ETA: 0s - loss: 1.2300 - accuracy: 0.4173
# Epoch 26: val_loss improved from 1.14691 to 1.11912, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 1.2305 - accuracy: 0.4141 - val_loss: 1.1191 - val_accuracy: 0.4562
# Epoch 27/100
# 131/136 [===========================>..] - ETA: 0s - loss: 1.2228 - accuracy: 0.4225
# Epoch 27: val_loss improved from 1.11912 to 1.11209, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 4ms/step - loss: 1.2240 - accuracy: 0.4224 - val_loss: 1.1121 - val_accuracy: 0.5124
# Epoch 28/100
# 127/136 [===========================>..] - ETA: 0s - loss: 1.1955 - accuracy: 0.4441
# Epoch 28: val_loss improved from 1.11209 to 1.06080, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 1.1911 - accuracy: 0.4450 - val_loss: 1.0608 - val_accuracy: 0.5263
# Epoch 29/100
# 128/136 [===========================>..] - ETA: 0s - loss: 1.1803 - accuracy: 0.4448
# Epoch 29: val_loss improved from 1.06080 to 1.03694, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 1.1772 - accuracy: 0.4434 - val_loss: 1.0369 - val_accuracy: 0.5493
# Epoch 30/100
# 124/136 [==========================>...] - ETA: 0s - loss: 1.1788 - accuracy: 0.4541
# Epoch 30: val_loss improved from 1.03694 to 1.02013, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 1.1711 - accuracy: 0.4591 - val_loss: 1.0201 - val_accuracy: 0.5622
# Epoch 31/100
# 124/136 [==========================>...] - ETA: 0s - loss: 1.1511 - accuracy: 0.4766
# Epoch 31: val_loss improved from 1.02013 to 0.99658, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 1.1484 - accuracy: 0.4766 - val_loss: 0.9966 - val_accuracy: 0.5539
# Epoch 32/100
# 131/136 [===========================>..] - ETA: 0s - loss: 1.1339 - accuracy: 0.4757
# Epoch 32: val_loss did not improve from 0.99658
# 136/136 [==============================] - 1s 4ms/step - loss: 1.1329 - accuracy: 0.4754 - val_loss: 1.0151 - val_accuracy: 0.5677
# Epoch 33/100
# 127/136 [===========================>..] - ETA: 0s - loss: 1.1277 - accuracy: 0.4820
# Epoch 33: val_loss improved from 0.99658 to 0.99419, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 1.1325 - accuracy: 0.4794 - val_loss: 0.9942 - val_accuracy: 0.5530
# Epoch 34/100
# 134/136 [============================>.] - ETA: 0s - loss: 1.0959 - accuracy: 0.4944
# Epoch 34: val_loss improved from 0.99419 to 0.97154, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 1.0972 - accuracy: 0.4937 - val_loss: 0.9715 - val_accuracy: 0.5760
# Epoch 35/100
# 132/136 [============================>.] - ETA: 0s - loss: 1.0779 - accuracy: 0.5052
# Epoch 35: val_loss improved from 0.97154 to 0.95147, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 1.0774 - accuracy: 0.5047 - val_loss: 0.9515 - val_accuracy: 0.5696
# Epoch 36/100
# 126/136 [==========================>...] - ETA: 0s - loss: 1.1103 - accuracy: 0.4978
# Epoch 36: val_loss did not improve from 0.95147
# 136/136 [==============================] - 1s 5ms/step - loss: 1.1059 - accuracy: 0.5027 - val_loss: 0.9733 - val_accuracy: 0.5806
# Epoch 37/100
# 125/136 [==========================>...] - ETA: 0s - loss: 1.0676 - accuracy: 0.5205
# Epoch 37: val_loss improved from 0.95147 to 0.90774, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 1.0710 - accuracy: 0.5211 - val_loss: 0.9077 - val_accuracy: 0.6092
# Epoch 38/100
# 130/136 [===========================>..] - ETA: 0s - loss: 1.0685 - accuracy: 0.5154
# Epoch 38: val_loss did not improve from 0.90774
# 136/136 [==============================] - 1s 5ms/step - loss: 1.0691 - accuracy: 0.5128 - val_loss: 0.9152 - val_accuracy: 0.6037
# Epoch 39/100
# 133/136 [============================>.] - ETA: 0s - loss: 1.0478 - accuracy: 0.5240
# Epoch 39: val_loss did not improve from 0.90774
# 136/136 [==============================] - 1s 5ms/step - loss: 1.0463 - accuracy: 0.5262 - val_loss: 0.9096 - val_accuracy: 0.6111
# Epoch 40/100
# 136/136 [==============================] - ETA: 0s - loss: 1.0563 - accuracy: 0.5160
# Epoch 40: val_loss did not improve from 0.90774
# 136/136 [==============================] - 1s 6ms/step - loss: 1.0563 - accuracy: 0.5160 - val_loss: 0.9087 - val_accuracy: 0.6120
# Epoch 41/100
# 130/136 [===========================>..] - ETA: 0s - loss: 1.0329 - accuracy: 0.5305
# Epoch 41: val_loss improved from 0.90774 to 0.90145, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 6ms/step - loss: 1.0358 - accuracy: 0.5310 - val_loss: 0.9014 - val_accuracy: 0.6074
# Epoch 42/100
# 133/136 [============================>.] - ETA: 0s - loss: 1.0074 - accuracy: 0.5463
# Epoch 42: val_loss improved from 0.90145 to 0.85768, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 7ms/step - loss: 1.0087 - accuracy: 0.5472 - val_loss: 0.8577 - val_accuracy: 0.6442
# Epoch 43/100
# 132/136 [============================>.] - ETA: 0s - loss: 1.0122 - accuracy: 0.5388
# Epoch 43: val_loss did not improve from 0.85768
# 136/136 [==============================] - 1s 4ms/step - loss: 1.0114 - accuracy: 0.5395 - val_loss: 0.8863 - val_accuracy: 0.6387
# Epoch 44/100
# 127/136 [===========================>..] - ETA: 0s - loss: 0.9933 - accuracy: 0.5659
# Epoch 44: val_loss improved from 0.85768 to 0.84922, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 0.9965 - accuracy: 0.5647 - val_loss: 0.8492 - val_accuracy: 0.6221
# Epoch 45/100
# 134/136 [============================>.] - ETA: 0s - loss: 0.9883 - accuracy: 0.5618
# Epoch 45: val_loss did not improve from 0.84922
# 136/136 [==============================] - 1s 4ms/step - loss: 0.9916 - accuracy: 0.5614 - val_loss: 0.8622 - val_accuracy: 0.6286
# Epoch 46/100
# 132/136 [============================>.] - ETA: 0s - loss: 0.9778 - accuracy: 0.5682
# Epoch 46: val_loss improved from 0.84922 to 0.82909, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 4ms/step - loss: 0.9785 - accuracy: 0.5674 - val_loss: 0.8291 - val_accuracy: 0.6627
# Epoch 47/100
# 129/136 [===========================>..] - ETA: 0s - loss: 0.9838 - accuracy: 0.5690
# Epoch 47: val_loss did not improve from 0.82909
# 136/136 [==============================] - 1s 5ms/step - loss: 0.9812 - accuracy: 0.5679 - val_loss: 0.8330 - val_accuracy: 0.6636
# Epoch 48/100
# 132/136 [============================>.] - ETA: 0s - loss: 0.9721 - accuracy: 0.5746
# Epoch 48: val_loss did not improve from 0.82909
# 136/136 [==============================] - 1s 4ms/step - loss: 0.9745 - accuracy: 0.5741 - val_loss: 0.8335 - val_accuracy: 0.6710
# Epoch 49/100
# 125/136 [==========================>...] - ETA: 0s - loss: 0.9610 - accuracy: 0.5857
# Epoch 49: val_loss improved from 0.82909 to 0.80924, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 0.9552 - accuracy: 0.5868 - val_loss: 0.8092 - val_accuracy: 0.6535
# Epoch 50/100
# 130/136 [===========================>..] - ETA: 0s - loss: 0.9500 - accuracy: 0.5899
# Epoch 50: val_loss improved from 0.80924 to 0.79842, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 0.9504 - accuracy: 0.5893 - val_loss: 0.7984 - val_accuracy: 0.6571
# Epoch 51/100
# 127/136 [===========================>..] - ETA: 0s - loss: 0.9336 - accuracy: 0.5797
# Epoch 51: val_loss did not improve from 0.79842
# 136/136 [==============================] - 1s 5ms/step - loss: 0.9348 - accuracy: 0.5797 - val_loss: 0.8117 - val_accuracy: 0.6424
# Epoch 52/100
# 126/136 [==========================>...] - ETA: 0s - loss: 0.9286 - accuracy: 0.5883
# Epoch 52: val_loss did not improve from 0.79842
# 136/136 [==============================] - 1s 4ms/step - loss: 0.9340 - accuracy: 0.5868 - val_loss: 0.8129 - val_accuracy: 0.6866
# Epoch 53/100
# 128/136 [===========================>..] - ETA: 0s - loss: 0.9189 - accuracy: 0.6003
# Epoch 53: val_loss did not improve from 0.79842
# 136/136 [==============================] - 1s 5ms/step - loss: 0.9177 - accuracy: 0.6006 - val_loss: 0.8003 - val_accuracy: 0.6912
# Epoch 54/100
# 127/136 [===========================>..] - ETA: 0s - loss: 0.9240 - accuracy: 0.6014
# Epoch 54: val_loss improved from 0.79842 to 0.78702, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 0.9231 - accuracy: 0.5983 - val_loss: 0.7870 - val_accuracy: 0.6544
# Epoch 55/100
# 132/136 [============================>.] - ETA: 0s - loss: 0.8935 - accuracy: 0.6037
# Epoch 55: val_loss improved from 0.78702 to 0.77509, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 0.8940 - accuracy: 0.6032 - val_loss: 0.7751 - val_accuracy: 0.7088
# Epoch 56/100
# 128/136 [===========================>..] - ETA: 0s - loss: 0.8978 - accuracy: 0.6111
# Epoch 56: val_loss improved from 0.77509 to 0.76339, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 0.8959 - accuracy: 0.6131 - val_loss: 0.7634 - val_accuracy: 0.6986
# Epoch 57/100
# 124/136 [==========================>...] - ETA: 0s - loss: 0.8766 - accuracy: 0.6258
# Epoch 57: val_loss improved from 0.76339 to 0.74471, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 0.8819 - accuracy: 0.6237 - val_loss: 0.7447 - val_accuracy: 0.7207
# Epoch 58/100
# 133/136 [============================>.] - ETA: 0s - loss: 0.9071 - accuracy: 0.6137
# Epoch 58: val_loss did not improve from 0.74471
# 136/136 [==============================] - 1s 5ms/step - loss: 0.9051 - accuracy: 0.6159 - val_loss: 0.7625 - val_accuracy: 0.7069
# Epoch 59/100
# 135/136 [============================>.] - ETA: 0s - loss: 0.8948 - accuracy: 0.6231
# Epoch 59: val_loss did not improve from 0.74471
# 136/136 [==============================] - 1s 6ms/step - loss: 0.8935 - accuracy: 0.6239 - val_loss: 0.7490 - val_accuracy: 0.7143
# Epoch 60/100
# 127/136 [===========================>..] - ETA: 0s - loss: 0.8745 - accuracy: 0.6353
# Epoch 60: val_loss did not improve from 0.74471
# 136/136 [==============================] - 1s 6ms/step - loss: 0.8724 - accuracy: 0.6364 - val_loss: 0.7479 - val_accuracy: 0.7069
# Epoch 61/100
# 132/136 [============================>.] - ETA: 0s - loss: 0.8679 - accuracy: 0.6328
# Epoch 61: val_loss did not improve from 0.74471
# 136/136 [==============================] - 1s 6ms/step - loss: 0.8675 - accuracy: 0.6327 - val_loss: 0.7455 - val_accuracy: 0.7253
# Epoch 62/100
# 129/136 [===========================>..] - ETA: 0s - loss: 0.8654 - accuracy: 0.6378
# Epoch 62: val_loss improved from 0.74471 to 0.72932, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 0.8648 - accuracy: 0.6387 - val_loss: 0.7293 - val_accuracy: 0.7392
# Epoch 63/100
# 128/136 [===========================>..] - ETA: 0s - loss: 0.8726 - accuracy: 0.6223
# Epoch 63: val_loss did not improve from 0.72932
# 136/136 [==============================] - 1s 4ms/step - loss: 0.8713 - accuracy: 0.6235 - val_loss: 0.7359 - val_accuracy: 0.7373
# Epoch 64/100
# 128/136 [===========================>..] - ETA: 0s - loss: 0.8313 - accuracy: 0.6516
# Epoch 64: val_loss improved from 0.72932 to 0.70131, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 6ms/step - loss: 0.8352 - accuracy: 0.6500 - val_loss: 0.7013 - val_accuracy: 0.7346
# Epoch 65/100
# 129/136 [===========================>..] - ETA: 0s - loss: 0.8580 - accuracy: 0.6381
# Epoch 65: val_loss did not improve from 0.70131
# 136/136 [==============================] - 1s 7ms/step - loss: 0.8569 - accuracy: 0.6368 - val_loss: 0.7213 - val_accuracy: 0.7355
# Epoch 66/100
# 134/136 [============================>.] - ETA: 0s - loss: 0.8495 - accuracy: 0.6497
# Epoch 66: val_loss did not improve from 0.70131
# 136/136 [==============================] - 1s 8ms/step - loss: 0.8539 - accuracy: 0.6475 - val_loss: 0.7367 - val_accuracy: 0.7272
# Epoch 67/100
# 134/136 [============================>.] - ETA: 0s - loss: 0.8372 - accuracy: 0.6562
# Epoch 67: val_loss improved from 0.70131 to 0.69879, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 7ms/step - loss: 0.8363 - accuracy: 0.6564 - val_loss: 0.6988 - val_accuracy: 0.7327
# Epoch 68/100
# 130/136 [===========================>..] - ETA: 0s - loss: 0.8320 - accuracy: 0.6418
# Epoch 68: val_loss improved from 0.69879 to 0.69697, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 6ms/step - loss: 0.8308 - accuracy: 0.6431 - val_loss: 0.6970 - val_accuracy: 0.7456
# Epoch 69/100
# 127/136 [===========================>..] - ETA: 0s - loss: 0.8487 - accuracy: 0.6432
# Epoch 69: val_loss did not improve from 0.69697
# 136/136 [==============================] - 1s 5ms/step - loss: 0.8455 - accuracy: 0.6463 - val_loss: 0.7023 - val_accuracy: 0.7456
# Epoch 70/100
# 127/136 [===========================>..] - ETA: 0s - loss: 0.8234 - accuracy: 0.6562
# Epoch 70: val_loss did not improve from 0.69697
# 136/136 [==============================] - 1s 4ms/step - loss: 0.8248 - accuracy: 0.6553 - val_loss: 0.7050 - val_accuracy: 0.7318
# Epoch 71/100
# 128/136 [===========================>..] - ETA: 0s - loss: 0.7992 - accuracy: 0.6738
# Epoch 71: val_loss did not improve from 0.69697
# 136/136 [==============================] - 1s 5ms/step - loss: 0.8015 - accuracy: 0.6730 - val_loss: 0.7062 - val_accuracy: 0.7373
# Epoch 72/100
# 132/136 [============================>.] - ETA: 0s - loss: 0.8093 - accuracy: 0.6600
# Epoch 72: val_loss did not improve from 0.69697
# 136/136 [==============================] - 1s 5ms/step - loss: 0.8137 - accuracy: 0.6585 - val_loss: 0.6971 - val_accuracy: 0.7198
# Epoch 73/100
# 131/136 [===========================>..] - ETA: 0s - loss: 0.8167 - accuracy: 0.6577
# Epoch 73: val_loss improved from 0.69697 to 0.68573, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 4ms/step - loss: 0.8193 - accuracy: 0.6581 - val_loss: 0.6857 - val_accuracy: 0.7567
# Epoch 74/100
# 125/136 [==========================>...] - ETA: 0s - loss: 0.7981 - accuracy: 0.6610
# Epoch 74: val_loss did not improve from 0.68573
# 136/136 [==============================] - 1s 4ms/step - loss: 0.8003 - accuracy: 0.6615 - val_loss: 0.6929 - val_accuracy: 0.7392
# Epoch 75/100
# 132/136 [============================>.] - ETA: 0s - loss: 0.8038 - accuracy: 0.6652
# Epoch 75: val_loss did not improve from 0.68573
# 136/136 [==============================] - 1s 5ms/step - loss: 0.8075 - accuracy: 0.6647 - val_loss: 0.7021 - val_accuracy: 0.7465
# Epoch 76/100
# 135/136 [============================>.] - ETA: 0s - loss: 0.7980 - accuracy: 0.6736
# Epoch 76: val_loss did not improve from 0.68573
# 136/136 [==============================] - 1s 6ms/step - loss: 0.7967 - accuracy: 0.6744 - val_loss: 0.6925 - val_accuracy: 0.7502
# Epoch 77/100
# 134/136 [============================>.] - ETA: 0s - loss: 0.7984 - accuracy: 0.6667
# Epoch 77: val_loss improved from 0.68573 to 0.66252, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 7ms/step - loss: 0.7965 - accuracy: 0.6680 - val_loss: 0.6625 - val_accuracy: 0.7613
# Epoch 78/100
# 134/136 [============================>.] - ETA: 0s - loss: 0.7982 - accuracy: 0.6597
# Epoch 78: val_loss did not improve from 0.66252
# 136/136 [==============================] - 1s 6ms/step - loss: 0.7994 - accuracy: 0.6594 - val_loss: 0.6728 - val_accuracy: 0.7392
# Epoch 79/100
# 124/136 [==========================>...] - ETA: 0s - loss: 0.7876 - accuracy: 0.6820
# Epoch 79: val_loss did not improve from 0.66252
# 136/136 [==============================] - 1s 5ms/step - loss: 0.7925 - accuracy: 0.6781 - val_loss: 0.6715 - val_accuracy: 0.7493
# Epoch 80/100
# 127/136 [===========================>..] - ETA: 0s - loss: 0.7788 - accuracy: 0.6777
# Epoch 80: val_loss did not improve from 0.66252
# 136/136 [==============================] - 1s 5ms/step - loss: 0.7802 - accuracy: 0.6786 - val_loss: 0.6791 - val_accuracy: 0.7521
# Epoch 81/100
# 126/136 [==========================>...] - ETA: 0s - loss: 0.8000 - accuracy: 0.6627
# Epoch 81: val_loss did not improve from 0.66252
# 136/136 [==============================] - 1s 4ms/step - loss: 0.8008 - accuracy: 0.6617 - val_loss: 0.6699 - val_accuracy: 0.7512
# Epoch 82/100
# 131/136 [===========================>..] - ETA: 0s - loss: 0.7681 - accuracy: 0.6908
# Epoch 82: val_loss improved from 0.66252 to 0.63987, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 0.7678 - accuracy: 0.6899 - val_loss: 0.6399 - val_accuracy: 0.7696
# Epoch 83/100
# 136/136 [==============================] - ETA: 0s - loss: 0.7755 - accuracy: 0.6763
# Epoch 83: val_loss did not improve from 0.63987
# 136/136 [==============================] - 1s 5ms/step - loss: 0.7755 - accuracy: 0.6763 - val_loss: 0.6402 - val_accuracy: 0.7797
# Epoch 84/100
# 131/136 [===========================>..] - ETA: 0s - loss: 0.7636 - accuracy: 0.6925
# Epoch 84: val_loss did not improve from 0.63987
# 136/136 [==============================] - 1s 5ms/step - loss: 0.7694 - accuracy: 0.6906 - val_loss: 0.6739 - val_accuracy: 0.7594
# Epoch 85/100
# 127/136 [===========================>..] - ETA: 0s - loss: 0.7509 - accuracy: 0.6875
# Epoch 85: val_loss did not improve from 0.63987
# 136/136 [==============================] - 1s 4ms/step - loss: 0.7511 - accuracy: 0.6892 - val_loss: 0.6443 - val_accuracy: 0.7622
# Epoch 86/100
# 136/136 [==============================] - ETA: 0s - loss: 0.7620 - accuracy: 0.6873
# Epoch 86: val_loss improved from 0.63987 to 0.63452, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 0.7620 - accuracy: 0.6873 - val_loss: 0.6345 - val_accuracy: 0.7797
# Epoch 87/100
# 130/136 [===========================>..] - ETA: 0s - loss: 0.7659 - accuracy: 0.6863
# Epoch 87: val_loss did not improve from 0.63452
# 136/136 [==============================] - 1s 5ms/step - loss: 0.7715 - accuracy: 0.6871 - val_loss: 0.6691 - val_accuracy: 0.7622
# Epoch 88/100
# 133/136 [============================>.] - ETA: 0s - loss: 0.7639 - accuracy: 0.6894
# Epoch 88: val_loss improved from 0.63452 to 0.63093, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 0.7614 - accuracy: 0.6899 - val_loss: 0.6309 - val_accuracy: 0.7714
# Epoch 89/100
# 135/136 [============================>.] - ETA: 0s - loss: 0.7708 - accuracy: 0.6896
# Epoch 89: val_loss did not improve from 0.63093
# 136/136 [==============================] - 1s 5ms/step - loss: 0.7705 - accuracy: 0.6899 - val_loss: 0.6320 - val_accuracy: 0.7806
# Epoch 90/100
# 127/136 [===========================>..] - ETA: 0s - loss: 0.7524 - accuracy: 0.6927
# Epoch 90: val_loss improved from 0.63093 to 0.62345, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 6ms/step - loss: 0.7513 - accuracy: 0.6943 - val_loss: 0.6235 - val_accuracy: 0.7668
# Epoch 91/100
# 130/136 [===========================>..] - ETA: 0s - loss: 0.7407 - accuracy: 0.7031
# Epoch 91: val_loss did not improve from 0.62345
# 136/136 [==============================] - 1s 4ms/step - loss: 0.7459 - accuracy: 0.7023 - val_loss: 0.6259 - val_accuracy: 0.7751
# Epoch 92/100
# 130/136 [===========================>..] - ETA: 0s - loss: 0.7506 - accuracy: 0.6897
# Epoch 92: val_loss improved from 0.62345 to 0.62008, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 4ms/step - loss: 0.7525 - accuracy: 0.6892 - val_loss: 0.6201 - val_accuracy: 0.7825
# Epoch 93/100
# 128/136 [===========================>..] - ETA: 0s - loss: 0.7425 - accuracy: 0.6853
# Epoch 93: val_loss improved from 0.62008 to 0.61195, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 0.7442 - accuracy: 0.6850 - val_loss: 0.6120 - val_accuracy: 0.7806
# Epoch 94/100
# 127/136 [===========================>..] - ETA: 0s - loss: 0.7316 - accuracy: 0.7010
# Epoch 94: val_loss did not improve from 0.61195
# 136/136 [==============================] - 1s 6ms/step - loss: 0.7342 - accuracy: 0.7003 - val_loss: 0.6171 - val_accuracy: 0.7862
# Epoch 95/100
# 133/136 [============================>.] - ETA: 0s - loss: 0.7345 - accuracy: 0.6981
# Epoch 95: val_loss did not improve from 0.61195
# 136/136 [==============================] - 1s 7ms/step - loss: 0.7338 - accuracy: 0.6982 - val_loss: 0.6124 - val_accuracy: 0.7760
# Epoch 96/100
# 127/136 [===========================>..] - ETA: 0s - loss: 0.7443 - accuracy: 0.6988
# Epoch 96: val_loss did not improve from 0.61195
# 136/136 [==============================] - 1s 7ms/step - loss: 0.7478 - accuracy: 0.6973 - val_loss: 0.6344 - val_accuracy: 0.7742
# Epoch 97/100
# 130/136 [===========================>..] - ETA: 0s - loss: 0.7401 - accuracy: 0.7089
# Epoch 97: val_loss did not improve from 0.61195
# 136/136 [==============================] - 1s 7ms/step - loss: 0.7393 - accuracy: 0.7090 - val_loss: 0.6179 - val_accuracy: 0.7760
# Epoch 98/100
# 131/136 [===========================>..] - ETA: 0s - loss: 0.7303 - accuracy: 0.7006
# Epoch 98: val_loss did not improve from 0.61195
# 136/136 [==============================] - 1s 4ms/step - loss: 0.7304 - accuracy: 0.7007 - val_loss: 0.6185 - val_accuracy: 0.7696
# Epoch 99/100
# 128/136 [===========================>..] - ETA: 0s - loss: 0.7176 - accuracy: 0.7041
# Epoch 99: val_loss did not improve from 0.61195
# 136/136 [==============================] - 1s 4ms/step - loss: 0.7195 - accuracy: 0.7035 - val_loss: 0.6122 - val_accuracy: 0.7779
# Epoch 100/100
# 127/136 [===========================>..] - ETA: 0s - loss: 0.7346 - accuracy: 0.6993
# Epoch 100: val_loss did not improve from 0.61195
# 136/136 [==============================] - 1s 5ms/step - loss: 0.7370 - accuracy: 0.6973 - val_loss: 0.6369 - val_accuracy: 0.7650
# Training completed in time:  0:01:23.601936

# %%
test_accuracy=model.evaluate(X_test,y_test,verbose=0)
print(test_accuracy[1])
# Out:
# 0.764976978302002

# %% [markdown]
# $\Large \color{green}{\texttt{LSTM}}$

# %%
X_train_lstm = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test_lstm = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# %%
# Define LSTM model
model_lstm = Sequential()
model_lstm.add(LSTM(128, input_shape=(X_train.shape[1], 1), return_sequences=True))
model_lstm.add(LSTM(128))
model_lstm.add(Dropout(0.5))
model_lstm.add(Dense(num_labels, activation='softmax'))

model_lstm.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Add a dimension to input data for LSTM
X_train_lstm = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test_lstm = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# Define checkpoint to save the best model
checkpointer_lstm = ModelCheckpoint(filepath='saved_models/audio_classification_lstm.hdf5', verbose=1, save_best_only=True)

# Implement early stopping based on validation loss
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# %%
# Train LSTM model
start = datetime.now()
history_lstm = model_lstm.fit(X_train_lstm, y_train, batch_size=35, epochs=30,validation_data=(X_test_lstm, y_test),
                               callbacks=[checkpointer_lstm, early_stopping], verbose=1)
duration_lstm = datetime.now() - start
print("Training completed in time: ", duration_lstm)
# Out:
# Epoch 1/30
# 123/124 [============================>.] - ETA: 0s - loss: 1.5663 - accuracy: 0.2662
# Epoch 1: val_loss improved from inf to 1.49452, saving model to saved_models/audio_classification_lstm.hdf5
# 124/124 [==============================] - 6s 14ms/step - loss: 1.5669 - accuracy: 0.2661 - val_loss: 1.4945 - val_accuracy: 0.3373
# Epoch 2/30
# 118/124 [===========================>..] - ETA: 0s - loss: 1.4025 - accuracy: 0.3893
# Epoch 2: val_loss improved from 1.49452 to 1.23928, saving model to saved_models/audio_classification_lstm.hdf5
# 124/124 [==============================] - 1s 8ms/step - loss: 1.3990 - accuracy: 0.3922 - val_loss: 1.2393 - val_accuracy: 0.4571
# Epoch 3/30
# 117/124 [===========================>..] - ETA: 0s - loss: 1.2421 - accuracy: 0.4796
# Epoch 3: val_loss improved from 1.23928 to 1.12563, saving model to saved_models/audio_classification_lstm.hdf5
# 124/124 [==============================] - 1s 8ms/step - loss: 1.2389 - accuracy: 0.4817 - val_loss: 1.1256 - val_accuracy: 0.5171
# Epoch 4/30
# 121/124 [============================>.] - ETA: 0s - loss: 1.1173 - accuracy: 0.5344
# Epoch 4: val_loss improved from 1.12563 to 1.03213, saving model to saved_models/audio_classification_lstm.hdf5
# 124/124 [==============================] - 1s 8ms/step - loss: 1.1166 - accuracy: 0.5349 - val_loss: 1.0321 - val_accuracy: 0.5613
# Epoch 5/30
# 116/124 [===========================>..] - ETA: 0s - loss: 1.0095 - accuracy: 0.5845
# Epoch 5: val_loss improved from 1.03213 to 0.95842, saving model to saved_models/audio_classification_lstm.hdf5
# 124/124 [==============================] - 1s 8ms/step - loss: 1.0068 - accuracy: 0.5861 - val_loss: 0.9584 - val_accuracy: 0.6037
# Epoch 6/30
# 119/124 [===========================>..] - ETA: 0s - loss: 0.9016 - accuracy: 0.6365
# Epoch 6: val_loss improved from 0.95842 to 0.80555, saving model to saved_models/audio_classification_lstm.hdf5
# 124/124 [==============================] - 1s 8ms/step - loss: 0.9010 - accuracy: 0.6364 - val_loss: 0.8056 - val_accuracy: 0.6765
# Epoch 7/30
# 120/124 [============================>.] - ETA: 0s - loss: 0.8010 - accuracy: 0.6874
# Epoch 7: val_loss improved from 0.80555 to 0.76751, saving model to saved_models/audio_classification_lstm.hdf5
# 124/124 [==============================] - 1s 8ms/step - loss: 0.7998 - accuracy: 0.6878 - val_loss: 0.7675 - val_accuracy: 0.6959
# Epoch 8/30
# 122/124 [============================>.] - ETA: 0s - loss: 0.7209 - accuracy: 0.7227
# Epoch 8: val_loss improved from 0.76751 to 0.72497, saving model to saved_models/audio_classification_lstm.hdf5
# 124/124 [==============================] - 1s 9ms/step - loss: 0.7224 - accuracy: 0.7224 - val_loss: 0.7250 - val_accuracy: 0.6986
# Epoch 9/30
# 119/124 [===========================>..] - ETA: 0s - loss: 0.6456 - accuracy: 0.7582
# Epoch 9: val_loss improved from 0.72497 to 0.67610, saving model to saved_models/audio_classification_lstm.hdf5
# 124/124 [==============================] - 1s 10ms/step - loss: 0.6435 - accuracy: 0.7595 - val_loss: 0.6761 - val_accuracy: 0.7180
# Epoch 10/30
# 119/124 [===========================>..] - ETA: 0s - loss: 0.5811 - accuracy: 0.7825
# Epoch 10: val_loss improved from 0.67610 to 0.56573, saving model to saved_models/audio_classification_lstm.hdf5
# 124/124 [==============================] - 1s 10ms/step - loss: 0.5817 - accuracy: 0.7819 - val_loss: 0.5657 - val_accuracy: 0.7899
# Epoch 11/30
# 118/124 [===========================>..] - ETA: 0s - loss: 0.5169 - accuracy: 0.8012
# Epoch 11: val_loss improved from 0.56573 to 0.53150, saving model to saved_models/audio_classification_lstm.hdf5
# 124/124 [==============================] - 1s 8ms/step - loss: 0.5132 - accuracy: 0.8019 - val_loss: 0.5315 - val_accuracy: 0.8000
# Epoch 12/30
# 118/124 [===========================>..] - ETA: 0s - loss: 0.4332 - accuracy: 0.8443
# Epoch 12: val_loss did not improve from 0.53150
# 124/124 [==============================] - 1s 8ms/step - loss: 0.4348 - accuracy: 0.8432 - val_loss: 0.5479 - val_accuracy: 0.7880
# Epoch 13/30
# 117/124 [===========================>..] - ETA: 0s - loss: 0.3807 - accuracy: 0.8615
# Epoch 13: val_loss improved from 0.53150 to 0.52015, saving model to saved_models/audio_classification_lstm.hdf5
# 124/124 [==============================] - 1s 8ms/step - loss: 0.3802 - accuracy: 0.8600 - val_loss: 0.5201 - val_accuracy: 0.8009
# Epoch 14/30
# 117/124 [===========================>..] - ETA: 0s - loss: 0.3482 - accuracy: 0.8750
# Epoch 14: val_loss improved from 0.52015 to 0.51416, saving model to saved_models/audio_classification_lstm.hdf5
# 124/124 [==============================] - 1s 8ms/step - loss: 0.3513 - accuracy: 0.8730 - val_loss: 0.5142 - val_accuracy: 0.8184
# Epoch 15/30
# 119/124 [===========================>..] - ETA: 0s - loss: 0.3359 - accuracy: 0.8804
# Epoch 15: val_loss improved from 0.51416 to 0.48032, saving model to saved_models/audio_classification_lstm.hdf5
# 124/124 [==============================] - 1s 8ms/step - loss: 0.3335 - accuracy: 0.8817 - val_loss: 0.4803 - val_accuracy: 0.8267
# Epoch 16/30
# 117/124 [===========================>..] - ETA: 0s - loss: 0.2689 - accuracy: 0.9040
# Epoch 16: val_loss improved from 0.48032 to 0.43971, saving model to saved_models/audio_classification_lstm.hdf5
# 124/124 [==============================] - 1s 8ms/step - loss: 0.2673 - accuracy: 0.9055 - val_loss: 0.4397 - val_accuracy: 0.8571
# Epoch 17/30
# 118/124 [===========================>..] - ETA: 0s - loss: 0.2352 - accuracy: 0.9167
# Epoch 17: val_loss did not improve from 0.43971
# 124/124 [==============================] - 1s 8ms/step - loss: 0.2375 - accuracy: 0.9170 - val_loss: 0.5092 - val_accuracy: 0.8258
# Epoch 18/30
# 119/124 [===========================>..] - ETA: 0s - loss: 0.2273 - accuracy: 0.9239
# Epoch 18: val_loss improved from 0.43971 to 0.43649, saving model to saved_models/audio_classification_lstm.hdf5
# 124/124 [==============================] - 1s 8ms/step - loss: 0.2310 - accuracy: 0.9225 - val_loss: 0.4365 - val_accuracy: 0.8682
# Epoch 19/30
# 119/124 [===========================>..] - ETA: 0s - loss: 0.1968 - accuracy: 0.9306
# Epoch 19: val_loss improved from 0.43649 to 0.43055, saving model to saved_models/audio_classification_lstm.hdf5
# 124/124 [==============================] - 1s 8ms/step - loss: 0.1963 - accuracy: 0.9304 - val_loss: 0.4305 - val_accuracy: 0.8654
# Epoch 20/30
# 120/124 [============================>.] - ETA: 0s - loss: 0.1625 - accuracy: 0.9476
# Epoch 20: val_loss improved from 0.43055 to 0.39562, saving model to saved_models/audio_classification_lstm.hdf5
# 124/124 [==============================] - 1s 9ms/step - loss: 0.1624 - accuracy: 0.9472 - val_loss: 0.3956 - val_accuracy: 0.8829
# Epoch 21/30
# 120/124 [============================>.] - ETA: 0s - loss: 0.1737 - accuracy: 0.9390
# Epoch 21: val_loss did not improve from 0.39562
# 124/124 [==============================] - 1s 10ms/step - loss: 0.1729 - accuracy: 0.9396 - val_loss: 0.4800 - val_accuracy: 0.8535
# Epoch 22/30
# 121/124 [============================>.] - ETA: 0s - loss: 0.1627 - accuracy: 0.9485
# Epoch 22: val_loss improved from 0.39562 to 0.35837, saving model to saved_models/audio_classification_lstm.hdf5
# 124/124 [==============================] - 1s 12ms/step - loss: 0.1622 - accuracy: 0.9486 - val_loss: 0.3584 - val_accuracy: 0.8894
# Epoch 23/30
# 120/124 [============================>.] - ETA: 0s - loss: 0.0966 - accuracy: 0.9667
# Epoch 23: val_loss did not improve from 0.35837
# 124/124 [==============================] - 1s 8ms/step - loss: 0.0973 - accuracy: 0.9666 - val_loss: 0.4348 - val_accuracy: 0.8719
# Epoch 24/30
# 124/124 [==============================] - ETA: 0s - loss: 0.1334 - accuracy: 0.9537
# Epoch 24: val_loss did not improve from 0.35837
# 124/124 [==============================] - 1s 8ms/step - loss: 0.1334 - accuracy: 0.9537 - val_loss: 0.3947 - val_accuracy: 0.8857
# Epoch 25/30
# 118/124 [===========================>..] - ETA: 0s - loss: 0.1002 - accuracy: 0.9649
# Epoch 25: val_loss did not improve from 0.35837
# 124/124 [==============================] - 1s 8ms/step - loss: 0.1011 - accuracy: 0.9645 - val_loss: 0.3963 - val_accuracy: 0.8968
# Epoch 26/30
# 120/124 [============================>.] - ETA: 0s - loss: 0.1036 - accuracy: 0.9636
# Epoch 26: val_loss did not improve from 0.35837
# 124/124 [==============================] - 1s 7ms/step - loss: 0.1030 - accuracy: 0.9633 - val_loss: 0.4098 - val_accuracy: 0.8802
# Epoch 27/30
# 118/124 [===========================>..] - ETA: 0s - loss: 0.0966 - accuracy: 0.9695
# Epoch 27: val_loss did not improve from 0.35837
# 124/124 [==============================] - 1s 8ms/step - loss: 0.0968 - accuracy: 0.9691 - val_loss: 0.4590 - val_accuracy: 0.8793
# Training completed in time:  0:00:33.684443

# %%
test_accuracy=model_lstm.evaluate(X_test_lstm,y_test,verbose=0)
print(test_accuracy[1])
# Out:
# 0.8894008994102478

# %% [markdown]
# $\Large \color{purple}{\texttt{VGGish}}$

# %%
def vggish_model(input_shape, num_labels, dropout_rate=0.5, l2_reg=0.0001):
    model_input = Input(shape=input_shape, name='input')

    # Block 1
    x = Conv1D(128, kernel_size=3, activation='relu', padding='same', kernel_regularizer='l2', name='conv1')(model_input)
    x = MaxPooling1D(pool_size=2, name='pool1')(x)

    # Block 2
    x = Conv1D(256, kernel_size=3, activation='relu', padding='same', kernel_regularizer='l2', name='conv2')(x)
    x = MaxPooling1D(pool_size=2, name='pool2')(x)

    # Block 3
    x = Conv1D(512, kernel_size=3, activation='relu', padding='same', kernel_regularizer='l2', name='conv3')(x)
    x = Conv1D(512, kernel_size=3, activation='relu', padding='same', kernel_regularizer='l2', name='conv4')(x)
    x = MaxPooling1D(pool_size=2, name='pool3')(x)

    # Block 4
    x = Conv1D(1024, kernel_size=3, activation='relu', padding='same', kernel_regularizer='l2', name='conv5')(x)
    x = Conv1D(1024, kernel_size=3, activation='relu', padding='same', kernel_regularizer='l2', name='conv6')(x)
    x = MaxPooling1D(pool_size=2, name='pool4')(x)

    # Flatten and fully connected layers
    x = Flatten(name='flatten')(x)
    x = Dense(2048, activation='relu', kernel_regularizer='l2', name='fc1')(x)
    x = Dropout(dropout_rate, name='dropout1')(x)
    x = Dense(2048, activation='relu', kernel_regularizer='l2', name='fc2')(x)
    x = Dropout(dropout_rate, name='dropout2')(x)

    # Output layer
    model_output = Dense(num_labels, activation='softmax', name='predictions')(x)

    model = Model(inputs=model_input, outputs=model_output, name='vggish')
    return model

# %%
# Reshape data for VGGish
X_train_vggish = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test_vggish = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

vggish_model = vggish_model((X_train_vggish.shape[1], 1), num_labels, dropout_rate=0.7, l2_reg=0.0001)
vggish_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Model summary
vggish_model.summary()
# Out:
# Model: "vggish"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 21, 1)]           0
#
#  conv1 (Conv1D)              (None, 21, 128)           512
#
#  pool1 (MaxPooling1D)        (None, 10, 128)           0
#
#  conv2 (Conv1D)              (None, 10, 256)           98560
#
#  pool2 (MaxPooling1D)        (None, 5, 256)            0
#
#  conv3 (Conv1D)              (None, 5, 512)            393728
#
#  conv4 (Conv1D)              (None, 5, 512)            786944
#
#  pool3 (MaxPooling1D)        (None, 2, 512)            0
#
#  conv5 (Conv1D)              (None, 2, 1024)           1573888
#
#  conv6 (Conv1D)              (None, 2, 1024)           3146752
#
#  pool4 (MaxPooling1D)        (None, 1, 1024)           0
#
#  flatten (Flatten)           (None, 1024)              0
#
#  fc1 (Dense)                 (None, 2048)              2099200
#
#  dropout1 (Dropout)          (None, 2048)              0
#
#  fc2 (Dense)                 (None, 2048)              4196352
#
#  dropout2 (Dropout)          (None, 2048)              0
#
#  predictions (Dense)         (None, 5)                 10245
#
# =================================================================
# Total params: 12306181 (46.94 MB)
# Trainable params: 12306181 (46.94 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Define checkpoint to save the best model
checkpoint_vggish = ModelCheckpoint(filepath='saved_models/audio_classification_vggish.hdf5', verbose=1, save_best_only=True)

# Implement early stopping based on validation loss
early_stopping_vggish = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)

# Train the model
start_vggish = datetime.now()
history_vggish = vggish_model.fit(X_train_vggish, y_train, batch_size=100, epochs=150,
                                  validation_data=(X_test_vggish, y_test),
                                  callbacks=[checkpoint_vggish, early_stopping_vggish], verbose=1)

duration_vggish = datetime.now() - start_vggish
print("Training completed in time: ", duration_vggish)
# Out:
# Epoch 1/150
# 44/44 [==============================] - ETA: 0s - loss: 30.1581 - accuracy: 0.2921
# Epoch 1: val_loss improved from inf to 11.94755, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 9s 65ms/step - loss: 30.1581 - accuracy: 0.2921 - val_loss: 11.9475 - val_accuracy: 0.3871
# Epoch 2/150
# 41/44 [==========================>...] - ETA: 0s - loss: 8.0480 - accuracy: 0.3851
# Epoch 2: val_loss improved from 11.94755 to 5.12161, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 28ms/step - loss: 7.8965 - accuracy: 0.3878 - val_loss: 5.1216 - val_accuracy: 0.3908
# Epoch 3/150
# 41/44 [==========================>...] - ETA: 0s - loss: 4.0045 - accuracy: 0.3980
# Epoch 3: val_loss improved from 5.12161 to 3.01693, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 27ms/step - loss: 3.9544 - accuracy: 0.3989 - val_loss: 3.0169 - val_accuracy: 0.4212
# Epoch 4/150
# 41/44 [==========================>...] - ETA: 0s - loss: 2.5918 - accuracy: 0.4107
# Epoch 4: val_loss improved from 3.01693 to 2.14778, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 3s 68ms/step - loss: 2.5724 - accuracy: 0.4104 - val_loss: 2.1478 - val_accuracy: 0.4230
# Epoch 5/150
# 43/44 [============================>.] - ETA: 0s - loss: 1.9876 - accuracy: 0.4263
# Epoch 5: val_loss improved from 2.14778 to 1.92080, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 29ms/step - loss: 1.9860 - accuracy: 0.4259 - val_loss: 1.9208 - val_accuracy: 0.3788
# Epoch 6/150
# 44/44 [==============================] - ETA: 0s - loss: 1.7003 - accuracy: 0.4268
# Epoch 6: val_loss improved from 1.92080 to 1.63845, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 27ms/step - loss: 1.7003 - accuracy: 0.4268 - val_loss: 1.6384 - val_accuracy: 0.4332
# Epoch 7/150
# 43/44 [============================>.] - ETA: 0s - loss: 1.5691 - accuracy: 0.4386
# Epoch 7: val_loss improved from 1.63845 to 1.46217, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 2s 51ms/step - loss: 1.5688 - accuracy: 0.4376 - val_loss: 1.4622 - val_accuracy: 0.4387
# Epoch 8/150
# 43/44 [============================>.] - ETA: 0s - loss: 1.4947 - accuracy: 0.4286
# Epoch 8: val_loss improved from 1.46217 to 1.43219, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 28ms/step - loss: 1.4950 - accuracy: 0.4284 - val_loss: 1.4322 - val_accuracy: 0.4627
# Epoch 9/150
# 41/44 [==========================>...] - ETA: 0s - loss: 1.4126 - accuracy: 0.4402
# Epoch 9: val_loss improved from 1.43219 to 1.35124, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 28ms/step - loss: 1.4097 - accuracy: 0.4418 - val_loss: 1.3512 - val_accuracy: 0.4525
# Epoch 10/150
# 43/44 [============================>.] - ETA: 0s - loss: 1.3875 - accuracy: 0.4553
# Epoch 10: val_loss did not improve from 1.35124
# 44/44 [==============================] - 1s 17ms/step - loss: 1.3885 - accuracy: 0.4549 - val_loss: 1.3540 - val_accuracy: 0.4645
# Epoch 11/150
# 41/44 [==========================>...] - ETA: 0s - loss: 1.3449 - accuracy: 0.4727
# Epoch 11: val_loss improved from 1.35124 to 1.30029, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 27ms/step - loss: 1.3397 - accuracy: 0.4718 - val_loss: 1.3003 - val_accuracy: 0.4645
# Epoch 12/150
# 41/44 [==========================>...] - ETA: 0s - loss: 1.3129 - accuracy: 0.4827
# Epoch 12: val_loss improved from 1.30029 to 1.23996, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 27ms/step - loss: 1.3087 - accuracy: 0.4840 - val_loss: 1.2400 - val_accuracy: 0.5106
# Epoch 13/150
# 43/44 [============================>.] - ETA: 0s - loss: 1.2861 - accuracy: 0.4944
# Epoch 13: val_loss did not improve from 1.23996
# 44/44 [==============================] - 1s 18ms/step - loss: 1.2863 - accuracy: 0.4934 - val_loss: 1.2524 - val_accuracy: 0.5235
# Epoch 14/150
# 41/44 [==========================>...] - ETA: 0s - loss: 1.2914 - accuracy: 0.4939
# Epoch 14: val_loss improved from 1.23996 to 1.22393, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 28ms/step - loss: 1.2904 - accuracy: 0.4925 - val_loss: 1.2239 - val_accuracy: 0.4931
# Epoch 15/150
# 43/44 [============================>.] - ETA: 0s - loss: 1.2563 - accuracy: 0.5186
# Epoch 15: val_loss did not improve from 1.22393
# 44/44 [==============================] - 1s 18ms/step - loss: 1.2571 - accuracy: 0.5188 - val_loss: 1.2740 - val_accuracy: 0.4710
# Epoch 16/150
# 41/44 [==========================>...] - ETA: 0s - loss: 1.2798 - accuracy: 0.5090
# Epoch 16: val_loss improved from 1.22393 to 1.18668, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 27ms/step - loss: 1.2817 - accuracy: 0.5066 - val_loss: 1.1867 - val_accuracy: 0.5530
# Epoch 17/150
# 41/44 [==========================>...] - ETA: 0s - loss: 1.2361 - accuracy: 0.5293
# Epoch 17: val_loss improved from 1.18668 to 1.17224, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 31ms/step - loss: 1.2324 - accuracy: 0.5289 - val_loss: 1.1722 - val_accuracy: 0.5539
# Epoch 18/150
# 41/44 [==========================>...] - ETA: 0s - loss: 1.2314 - accuracy: 0.5346
# Epoch 18: val_loss did not improve from 1.17224
# 44/44 [==============================] - 1s 19ms/step - loss: 1.2302 - accuracy: 0.5342 - val_loss: 1.2208 - val_accuracy: 0.5521
# Epoch 19/150
# 42/44 [===========================>..] - ETA: 0s - loss: 1.2323 - accuracy: 0.5269
# Epoch 19: val_loss improved from 1.17224 to 1.17167, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 32ms/step - loss: 1.2345 - accuracy: 0.5280 - val_loss: 1.1717 - val_accuracy: 0.5604
# Epoch 20/150
# 42/44 [===========================>..] - ETA: 0s - loss: 1.2106 - accuracy: 0.5536
# Epoch 20: val_loss did not improve from 1.17167
# 44/44 [==============================] - 1s 18ms/step - loss: 1.2112 - accuracy: 0.5543 - val_loss: 1.1738 - val_accuracy: 0.5539
# Epoch 21/150
# 41/44 [==========================>...] - ETA: 0s - loss: 1.2329 - accuracy: 0.5390
# Epoch 21: val_loss improved from 1.17167 to 1.16044, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 26ms/step - loss: 1.2266 - accuracy: 0.5430 - val_loss: 1.1604 - val_accuracy: 0.5816
# Epoch 22/150
# 41/44 [==========================>...] - ETA: 0s - loss: 1.2014 - accuracy: 0.5480
# Epoch 22: val_loss did not improve from 1.16044
# 44/44 [==============================] - 1s 17ms/step - loss: 1.2055 - accuracy: 0.5458 - val_loss: 1.1804 - val_accuracy: 0.5512
# Epoch 23/150
# 41/44 [==========================>...] - ETA: 0s - loss: 1.1837 - accuracy: 0.5598
# Epoch 23: val_loss improved from 1.16044 to 1.15464, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 27ms/step - loss: 1.1857 - accuracy: 0.5564 - val_loss: 1.1546 - val_accuracy: 0.5668
# Epoch 24/150
# 41/44 [==========================>...] - ETA: 0s - loss: 1.1837 - accuracy: 0.5605
# Epoch 24: val_loss did not improve from 1.15464
# 44/44 [==============================] - 1s 17ms/step - loss: 1.1850 - accuracy: 0.5612 - val_loss: 1.2136 - val_accuracy: 0.5189
# Epoch 25/150
# 43/44 [============================>.] - ETA: 0s - loss: 1.1828 - accuracy: 0.5565
# Epoch 25: val_loss did not improve from 1.15464
# 44/44 [==============================] - 1s 17ms/step - loss: 1.1834 - accuracy: 0.5566 - val_loss: 1.1798 - val_accuracy: 0.5585
# Epoch 26/150
# 41/44 [==========================>...] - ETA: 0s - loss: 1.1858 - accuracy: 0.5600
# Epoch 26: val_loss improved from 1.15464 to 1.13756, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 27ms/step - loss: 1.1847 - accuracy: 0.5624 - val_loss: 1.1376 - val_accuracy: 0.5548
# Epoch 27/150
# 41/44 [==========================>...] - ETA: 0s - loss: 1.1736 - accuracy: 0.5595
# Epoch 27: val_loss did not improve from 1.13756
# 44/44 [==============================] - 1s 17ms/step - loss: 1.1735 - accuracy: 0.5605 - val_loss: 1.1872 - val_accuracy: 0.5558
# Epoch 28/150
# 44/44 [==============================] - ETA: 0s - loss: 1.1672 - accuracy: 0.5746
# Epoch 28: val_loss improved from 1.13756 to 1.12583, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 28ms/step - loss: 1.1672 - accuracy: 0.5746 - val_loss: 1.1258 - val_accuracy: 0.5862
# Epoch 29/150
# 42/44 [===========================>..] - ETA: 0s - loss: 1.1288 - accuracy: 0.5990
# Epoch 29: val_loss improved from 1.12583 to 1.11543, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 28ms/step - loss: 1.1324 - accuracy: 0.5979 - val_loss: 1.1154 - val_accuracy: 0.5806
# Epoch 30/150
# 41/44 [==========================>...] - ETA: 0s - loss: 1.1386 - accuracy: 0.5885
# Epoch 30: val_loss did not improve from 1.11543
# 44/44 [==============================] - 1s 19ms/step - loss: 1.1426 - accuracy: 0.5852 - val_loss: 1.1443 - val_accuracy: 0.5788
# Epoch 31/150
# 44/44 [==============================] - ETA: 0s - loss: 1.1547 - accuracy: 0.5880
# Epoch 31: val_loss improved from 1.11543 to 1.09586, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 32ms/step - loss: 1.1547 - accuracy: 0.5880 - val_loss: 1.0959 - val_accuracy: 0.6092
# Epoch 32/150
# 42/44 [===========================>..] - ETA: 0s - loss: 1.1324 - accuracy: 0.5964
# Epoch 32: val_loss did not improve from 1.09586
# 44/44 [==============================] - 1s 19ms/step - loss: 1.1314 - accuracy: 0.5976 - val_loss: 1.1201 - val_accuracy: 0.5751
# Epoch 33/150
# 42/44 [===========================>..] - ETA: 0s - loss: 1.1400 - accuracy: 0.6000
# Epoch 33: val_loss did not improve from 1.09586
# 44/44 [==============================] - 1s 19ms/step - loss: 1.1395 - accuracy: 0.6000 - val_loss: 1.1085 - val_accuracy: 0.6037
# Epoch 34/150
# 41/44 [==========================>...] - ETA: 0s - loss: 1.1217 - accuracy: 0.6144
# Epoch 34: val_loss did not improve from 1.09586
# 44/44 [==============================] - 1s 17ms/step - loss: 1.1190 - accuracy: 0.6131 - val_loss: 1.1266 - val_accuracy: 0.6101
# Epoch 35/150
# 41/44 [==========================>...] - ETA: 0s - loss: 1.1505 - accuracy: 0.6027
# Epoch 35: val_loss did not improve from 1.09586
# 44/44 [==============================] - 1s 17ms/step - loss: 1.1480 - accuracy: 0.6055 - val_loss: 1.1122 - val_accuracy: 0.6111
# Epoch 36/150
# 41/44 [==========================>...] - ETA: 0s - loss: 1.1137 - accuracy: 0.6173
# Epoch 36: val_loss did not improve from 1.09586
# 44/44 [==============================] - 1s 17ms/step - loss: 1.1144 - accuracy: 0.6172 - val_loss: 1.1430 - val_accuracy: 0.5825
# Epoch 37/150
# 41/44 [==========================>...] - ETA: 0s - loss: 1.1112 - accuracy: 0.6212
# Epoch 37: val_loss did not improve from 1.09586
# 44/44 [==============================] - 1s 17ms/step - loss: 1.1141 - accuracy: 0.6202 - val_loss: 1.1694 - val_accuracy: 0.6028
# Epoch 38/150
# 41/44 [==========================>...] - ETA: 0s - loss: 1.1332 - accuracy: 0.6173
# Epoch 38: val_loss did not improve from 1.09586
# 44/44 [==============================] - 1s 17ms/step - loss: 1.1294 - accuracy: 0.6214 - val_loss: 1.1125 - val_accuracy: 0.6221
# Epoch 39/150
# 44/44 [==============================] - ETA: 0s - loss: 1.0989 - accuracy: 0.6292
# Epoch 39: val_loss improved from 1.09586 to 1.07911, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 28ms/step - loss: 1.0989 - accuracy: 0.6292 - val_loss: 1.0791 - val_accuracy: 0.6267
# Epoch 40/150
# 41/44 [==========================>...] - ETA: 0s - loss: 1.0657 - accuracy: 0.6520
# Epoch 40: val_loss improved from 1.07911 to 1.06100, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 28ms/step - loss: 1.0656 - accuracy: 0.6521 - val_loss: 1.0610 - val_accuracy: 0.6341
# Epoch 41/150
# 41/44 [==========================>...] - ETA: 0s - loss: 1.0898 - accuracy: 0.6483
# Epoch 41: val_loss improved from 1.06100 to 1.05026, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 27ms/step - loss: 1.0901 - accuracy: 0.6468 - val_loss: 1.0503 - val_accuracy: 0.6378
# Epoch 42/150
# 41/44 [==========================>...] - ETA: 0s - loss: 1.0795 - accuracy: 0.6566
# Epoch 42: val_loss did not improve from 1.05026
# 44/44 [==============================] - 1s 17ms/step - loss: 1.0796 - accuracy: 0.6541 - val_loss: 1.0764 - val_accuracy: 0.6627
# Epoch 43/150
# 41/44 [==========================>...] - ETA: 0s - loss: 1.0677 - accuracy: 0.6661
# Epoch 43: val_loss did not improve from 1.05026
# 44/44 [==============================] - 1s 17ms/step - loss: 1.0672 - accuracy: 0.6643 - val_loss: 1.0555 - val_accuracy: 0.6488
# Epoch 44/150
# 41/44 [==========================>...] - ETA: 0s - loss: 1.0379 - accuracy: 0.6771
# Epoch 44: val_loss did not improve from 1.05026
# 44/44 [==============================] - 1s 17ms/step - loss: 1.0392 - accuracy: 0.6758 - val_loss: 1.1400 - val_accuracy: 0.6276
# Epoch 45/150
# 43/44 [============================>.] - ETA: 0s - loss: 1.0653 - accuracy: 0.6751
# Epoch 45: val_loss did not improve from 1.05026
# 44/44 [==============================] - 1s 19ms/step - loss: 1.0638 - accuracy: 0.6760 - val_loss: 1.0517 - val_accuracy: 0.6811
# Epoch 46/150
# 44/44 [==============================] - ETA: 0s - loss: 1.0257 - accuracy: 0.6853
# Epoch 46: val_loss did not improve from 1.05026
# 44/44 [==============================] - 1s 21ms/step - loss: 1.0257 - accuracy: 0.6853 - val_loss: 1.0527 - val_accuracy: 0.6839
# Epoch 47/150
# 43/44 [============================>.] - ETA: 0s - loss: 1.0515 - accuracy: 0.6791
# Epoch 47: val_loss improved from 1.05026 to 1.01694, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 31ms/step - loss: 1.0501 - accuracy: 0.6800 - val_loss: 1.0169 - val_accuracy: 0.6922
# Epoch 48/150
# 41/44 [==========================>...] - ETA: 0s - loss: 1.0026 - accuracy: 0.6998
# Epoch 48: val_loss did not improve from 1.01694
# 44/44 [==============================] - 1s 17ms/step - loss: 1.0053 - accuracy: 0.7000 - val_loss: 1.0250 - val_accuracy: 0.6645
# Epoch 49/150
# 41/44 [==========================>...] - ETA: 0s - loss: 1.0010 - accuracy: 0.7054
# Epoch 49: val_loss improved from 1.01694 to 0.99230, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 27ms/step - loss: 1.0097 - accuracy: 0.7026 - val_loss: 0.9923 - val_accuracy: 0.7069
# Epoch 50/150
# 41/44 [==========================>...] - ETA: 0s - loss: 1.0452 - accuracy: 0.6934
# Epoch 50: val_loss did not improve from 0.99230
# 44/44 [==============================] - 1s 17ms/step - loss: 1.0407 - accuracy: 0.6956 - val_loss: 1.0323 - val_accuracy: 0.6802
# Epoch 51/150
# 41/44 [==========================>...] - ETA: 0s - loss: 1.0283 - accuracy: 0.7005
# Epoch 51: val_loss did not improve from 0.99230
# 44/44 [==============================] - 1s 17ms/step - loss: 1.0251 - accuracy: 0.7009 - val_loss: 1.0024 - val_accuracy: 0.7060
# Epoch 52/150
# 41/44 [==========================>...] - ETA: 0s - loss: 0.9899 - accuracy: 0.7307
# Epoch 52: val_loss did not improve from 0.99230
# 44/44 [==============================] - 1s 17ms/step - loss: 0.9900 - accuracy: 0.7309 - val_loss: 1.0133 - val_accuracy: 0.6912
# Epoch 53/150
# 41/44 [==========================>...] - ETA: 0s - loss: 0.9687 - accuracy: 0.7405
# Epoch 53: val_loss improved from 0.99230 to 0.98973, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 27ms/step - loss: 0.9663 - accuracy: 0.7424 - val_loss: 0.9897 - val_accuracy: 0.7281
# Epoch 54/150
# 41/44 [==========================>...] - ETA: 0s - loss: 0.9448 - accuracy: 0.7466
# Epoch 54: val_loss did not improve from 0.98973
# 44/44 [==============================] - 1s 17ms/step - loss: 0.9382 - accuracy: 0.7501 - val_loss: 1.0225 - val_accuracy: 0.7069
# Epoch 55/150
# 41/44 [==========================>...] - ETA: 0s - loss: 0.9414 - accuracy: 0.7583
# Epoch 55: val_loss improved from 0.98973 to 0.98909, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 26ms/step - loss: 0.9452 - accuracy: 0.7572 - val_loss: 0.9891 - val_accuracy: 0.7309
# Epoch 56/150
# 41/44 [==========================>...] - ETA: 0s - loss: 0.9211 - accuracy: 0.7732
# Epoch 56: val_loss did not improve from 0.98909
# 44/44 [==============================] - 1s 17ms/step - loss: 0.9304 - accuracy: 0.7680 - val_loss: 1.0625 - val_accuracy: 0.6654
# Epoch 57/150
# 44/44 [==============================] - ETA: 0s - loss: 0.9705 - accuracy: 0.7480
# Epoch 57: val_loss improved from 0.98909 to 0.96694, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 26ms/step - loss: 0.9705 - accuracy: 0.7480 - val_loss: 0.9669 - val_accuracy: 0.7484
# Epoch 58/150
# 41/44 [==========================>...] - ETA: 0s - loss: 0.9436 - accuracy: 0.7693
# Epoch 58: val_loss did not improve from 0.96694
# 44/44 [==============================] - 1s 17ms/step - loss: 0.9453 - accuracy: 0.7678 - val_loss: 0.9820 - val_accuracy: 0.7447
# Epoch 59/150
# 42/44 [===========================>..] - ETA: 0s - loss: 0.9791 - accuracy: 0.7552
# Epoch 59: val_loss did not improve from 0.96694
# 44/44 [==============================] - 1s 19ms/step - loss: 0.9783 - accuracy: 0.7554 - val_loss: 1.1436 - val_accuracy: 0.6710
# Epoch 60/150
# 43/44 [============================>.] - ETA: 0s - loss: 0.9574 - accuracy: 0.7544
# Epoch 60: val_loss did not improve from 0.96694
# 44/44 [==============================] - 1s 21ms/step - loss: 0.9570 - accuracy: 0.7537 - val_loss: 0.9972 - val_accuracy: 0.7410
# Epoch 61/150
# 41/44 [==========================>...] - ETA: 0s - loss: 0.9122 - accuracy: 0.7868
# Epoch 61: val_loss improved from 0.96694 to 0.95731, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 31ms/step - loss: 0.9103 - accuracy: 0.7867 - val_loss: 0.9573 - val_accuracy: 0.7770
# Epoch 62/150
# 42/44 [===========================>..] - ETA: 0s - loss: 0.8913 - accuracy: 0.7988
# Epoch 62: val_loss improved from 0.95731 to 0.95653, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 29ms/step - loss: 0.8915 - accuracy: 0.7982 - val_loss: 0.9565 - val_accuracy: 0.7779
# Epoch 63/150
# 41/44 [==========================>...] - ETA: 0s - loss: 0.8834 - accuracy: 0.8046
# Epoch 63: val_loss did not improve from 0.95653
# 44/44 [==============================] - 1s 17ms/step - loss: 0.8819 - accuracy: 0.8061 - val_loss: 0.9865 - val_accuracy: 0.7613
# Epoch 64/150
# 41/44 [==========================>...] - ETA: 0s - loss: 0.8592 - accuracy: 0.8151
# Epoch 64: val_loss did not improve from 0.95653
# 44/44 [==============================] - 1s 17ms/step - loss: 0.8657 - accuracy: 0.8130 - val_loss: 1.1226 - val_accuracy: 0.7189
# Epoch 65/150
# 41/44 [==========================>...] - ETA: 0s - loss: 0.8963 - accuracy: 0.8061
# Epoch 65: val_loss did not improve from 0.95653
# 44/44 [==============================] - 1s 17ms/step - loss: 0.8942 - accuracy: 0.8082 - val_loss: 0.9697 - val_accuracy: 0.7742
# Epoch 66/150
# 41/44 [==========================>...] - ETA: 0s - loss: 0.8622 - accuracy: 0.8156
# Epoch 66: val_loss improved from 0.95653 to 0.95305, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 30ms/step - loss: 0.8630 - accuracy: 0.8167 - val_loss: 0.9530 - val_accuracy: 0.7770
# Epoch 67/150
# 44/44 [==============================] - ETA: 0s - loss: 0.8528 - accuracy: 0.8287
# Epoch 67: val_loss did not improve from 0.95305
# 44/44 [==============================] - 1s 17ms/step - loss: 0.8528 - accuracy: 0.8287 - val_loss: 1.0029 - val_accuracy: 0.7650
# Epoch 68/150
# 41/44 [==========================>...] - ETA: 0s - loss: 0.8340 - accuracy: 0.8317
# Epoch 68: val_loss improved from 0.95305 to 0.93528, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 26ms/step - loss: 0.8310 - accuracy: 0.8335 - val_loss: 0.9353 - val_accuracy: 0.8018
# Epoch 69/150
# 41/44 [==========================>...] - ETA: 0s - loss: 0.8166 - accuracy: 0.8473
# Epoch 69: val_loss did not improve from 0.93528
# 44/44 [==============================] - 1s 17ms/step - loss: 0.8148 - accuracy: 0.8497 - val_loss: 0.9527 - val_accuracy: 0.7853
# Epoch 70/150
# 44/44 [==============================] - ETA: 0s - loss: 0.8383 - accuracy: 0.8453
# Epoch 70: val_loss did not improve from 0.93528
# 44/44 [==============================] - 1s 17ms/step - loss: 0.8383 - accuracy: 0.8453 - val_loss: 1.0229 - val_accuracy: 0.7613
# Epoch 71/150
# 41/44 [==========================>...] - ETA: 0s - loss: 0.8677 - accuracy: 0.8202
# Epoch 71: val_loss did not improve from 0.93528
# 44/44 [==============================] - 1s 17ms/step - loss: 0.8673 - accuracy: 0.8213 - val_loss: 0.9478 - val_accuracy: 0.8111
# Epoch 72/150
# 41/44 [==========================>...] - ETA: 0s - loss: 0.7940 - accuracy: 0.8517
# Epoch 72: val_loss improved from 0.93528 to 0.93283, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 27ms/step - loss: 0.7934 - accuracy: 0.8522 - val_loss: 0.9328 - val_accuracy: 0.8129
# Epoch 73/150
# 44/44 [==============================] - ETA: 0s - loss: 0.7995 - accuracy: 0.8529
# Epoch 73: val_loss did not improve from 0.93283
# 44/44 [==============================] - 1s 21ms/step - loss: 0.7995 - accuracy: 0.8529 - val_loss: 0.9433 - val_accuracy: 0.8037
# Epoch 74/150
# 42/44 [===========================>..] - ETA: 0s - loss: 0.8019 - accuracy: 0.8531
# Epoch 74: val_loss did not improve from 0.93283
# 44/44 [==============================] - 1s 19ms/step - loss: 0.8027 - accuracy: 0.8527 - val_loss: 0.9771 - val_accuracy: 0.7908
# Epoch 75/150
# 42/44 [===========================>..] - ETA: 0s - loss: 0.7747 - accuracy: 0.8721
# Epoch 75: val_loss did not improve from 0.93283
# 44/44 [==============================] - 1s 19ms/step - loss: 0.7740 - accuracy: 0.8720 - val_loss: 0.9514 - val_accuracy: 0.7945
# Epoch 76/150
# 41/44 [==========================>...] - ETA: 0s - loss: 0.7482 - accuracy: 0.8805
# Epoch 76: val_loss improved from 0.93283 to 0.91719, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 26ms/step - loss: 0.7456 - accuracy: 0.8810 - val_loss: 0.9172 - val_accuracy: 0.8304
# Epoch 77/150
# 44/44 [==============================] - ETA: 0s - loss: 0.7590 - accuracy: 0.8780
# Epoch 77: val_loss did not improve from 0.91719
# 44/44 [==============================] - 1s 18ms/step - loss: 0.7590 - accuracy: 0.8780 - val_loss: 0.9230 - val_accuracy: 0.8267
# Epoch 78/150
# 44/44 [==============================] - ETA: 0s - loss: 0.7662 - accuracy: 0.8720
# Epoch 78: val_loss improved from 0.91719 to 0.91325, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 26ms/step - loss: 0.7662 - accuracy: 0.8720 - val_loss: 0.9133 - val_accuracy: 0.8295
# Epoch 79/150
# 41/44 [==========================>...] - ETA: 0s - loss: 0.7320 - accuracy: 0.8851
# Epoch 79: val_loss did not improve from 0.91325
# 44/44 [==============================] - 1s 17ms/step - loss: 0.7332 - accuracy: 0.8849 - val_loss: 0.9432 - val_accuracy: 0.8194
# Epoch 80/150
# 41/44 [==========================>...] - ETA: 0s - loss: 0.7214 - accuracy: 0.8910
# Epoch 80: val_loss did not improve from 0.91325
# 44/44 [==============================] - 1s 17ms/step - loss: 0.7193 - accuracy: 0.8912 - val_loss: 0.9721 - val_accuracy: 0.8221
# Epoch 81/150
# 41/44 [==========================>...] - ETA: 0s - loss: 0.7302 - accuracy: 0.8895
# Epoch 81: val_loss did not improve from 0.91325
# 44/44 [==============================] - 1s 17ms/step - loss: 0.7346 - accuracy: 0.8863 - val_loss: 1.0099 - val_accuracy: 0.7945
# Epoch 82/150
# 41/44 [==========================>...] - ETA: 0s - loss: 0.7010 - accuracy: 0.9007
# Epoch 82: val_loss did not improve from 0.91325
# 44/44 [==============================] - 1s 17ms/step - loss: 0.7071 - accuracy: 0.8990 - val_loss: 0.9740 - val_accuracy: 0.8194
# Epoch 83/150
# 41/44 [==========================>...] - ETA: 0s - loss: 0.7280 - accuracy: 0.8917
# Epoch 83: val_loss did not improve from 0.91325
# 44/44 [==============================] - 1s 17ms/step - loss: 0.7298 - accuracy: 0.8902 - val_loss: 1.0929 - val_accuracy: 0.7972
# Epoch 84/150
# 41/44 [==========================>...] - ETA: 0s - loss: 0.7978 - accuracy: 0.8678
# Epoch 84: val_loss did not improve from 0.91325
# 44/44 [==============================] - 1s 17ms/step - loss: 0.7981 - accuracy: 0.8670 - val_loss: 0.9542 - val_accuracy: 0.8221
# Epoch 85/150
# 41/44 [==========================>...] - ETA: 0s - loss: 0.7404 - accuracy: 0.8963
# Epoch 85: val_loss did not improve from 0.91325
# 44/44 [==============================] - 1s 17ms/step - loss: 0.7425 - accuracy: 0.8928 - val_loss: 0.9166 - val_accuracy: 0.8488
# Epoch 86/150
# 44/44 [==============================] - ETA: 0s - loss: 0.7232 - accuracy: 0.8983
# Epoch 86: val_loss did not improve from 0.91325
# 44/44 [==============================] - 1s 17ms/step - loss: 0.7232 - accuracy: 0.8983 - val_loss: 1.0432 - val_accuracy: 0.8037
# Epoch 87/150
# 41/44 [==========================>...] - ETA: 0s - loss: 0.6913 - accuracy: 0.9141
# Epoch 87: val_loss improved from 0.91325 to 0.90784, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 26ms/step - loss: 0.6895 - accuracy: 0.9140 - val_loss: 0.9078 - val_accuracy: 0.8470
# Epoch 88/150
# 44/44 [==============================] - ETA: 0s - loss: 0.6744 - accuracy: 0.9179
# Epoch 88: val_loss improved from 0.90784 to 0.88199, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 33ms/step - loss: 0.6744 - accuracy: 0.9179 - val_loss: 0.8820 - val_accuracy: 0.8433
# Epoch 89/150
# 42/44 [===========================>..] - ETA: 0s - loss: 0.6858 - accuracy: 0.9071
# Epoch 89: val_loss did not improve from 0.88199
# 44/44 [==============================] - 1s 19ms/step - loss: 0.6857 - accuracy: 0.9068 - val_loss: 0.9313 - val_accuracy: 0.8396
# Epoch 90/150
# 42/44 [===========================>..] - ETA: 0s - loss: 0.7167 - accuracy: 0.8983
# Epoch 90: val_loss did not improve from 0.88199
# 44/44 [==============================] - 1s 21ms/step - loss: 0.7128 - accuracy: 0.8999 - val_loss: 0.8994 - val_accuracy: 0.8479
# Epoch 91/150
# 41/44 [==========================>...] - ETA: 0s - loss: 0.6584 - accuracy: 0.9254
# Epoch 91: val_loss did not improve from 0.88199
# 44/44 [==============================] - 1s 17ms/step - loss: 0.6608 - accuracy: 0.9244 - val_loss: 0.9091 - val_accuracy: 0.8516
# Epoch 92/150
# 44/44 [==============================] - ETA: 0s - loss: 0.6735 - accuracy: 0.9151
# Epoch 92: val_loss did not improve from 0.88199
# 44/44 [==============================] - 1s 17ms/step - loss: 0.6735 - accuracy: 0.9151 - val_loss: 0.8921 - val_accuracy: 0.8516
# Epoch 93/150
# 41/44 [==========================>...] - ETA: 0s - loss: 0.7050 - accuracy: 0.9105
# Epoch 93: val_loss improved from 0.88199 to 0.86979, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 26ms/step - loss: 0.7096 - accuracy: 0.9078 - val_loss: 0.8698 - val_accuracy: 0.8571
# Epoch 94/150
# 41/44 [==========================>...] - ETA: 0s - loss: 0.6586 - accuracy: 0.9256
# Epoch 94: val_loss did not improve from 0.86979
# 44/44 [==============================] - 1s 17ms/step - loss: 0.6574 - accuracy: 0.9264 - val_loss: 0.9075 - val_accuracy: 0.8470
# Epoch 95/150
# 41/44 [==========================>...] - ETA: 0s - loss: 0.6764 - accuracy: 0.9141
# Epoch 95: val_loss did not improve from 0.86979
# 44/44 [==============================] - 1s 17ms/step - loss: 0.6767 - accuracy: 0.9138 - val_loss: 0.9729 - val_accuracy: 0.8304
# Epoch 96/150
# 44/44 [==============================] - ETA: 0s - loss: 0.6613 - accuracy: 0.9237
# Epoch 96: val_loss did not improve from 0.86979
# 44/44 [==============================] - 1s 17ms/step - loss: 0.6613 - accuracy: 0.9237 - val_loss: 0.9365 - val_accuracy: 0.8562
# Epoch 97/150
# 41/44 [==========================>...] - ETA: 0s - loss: 0.6504 - accuracy: 0.9205
# Epoch 97: val_loss did not improve from 0.86979
# 44/44 [==============================] - 1s 17ms/step - loss: 0.6498 - accuracy: 0.9216 - val_loss: 1.0119 - val_accuracy: 0.8157
# Epoch 98/150
# 44/44 [==============================] - ETA: 0s - loss: 0.6465 - accuracy: 0.9269
# Epoch 98: val_loss did not improve from 0.86979
# 44/44 [==============================] - 1s 17ms/step - loss: 0.6465 - accuracy: 0.9269 - val_loss: 1.0566 - val_accuracy: 0.7917
# Epoch 99/150
# 41/44 [==========================>...] - ETA: 0s - loss: 0.6746 - accuracy: 0.9168
# Epoch 99: val_loss did not improve from 0.86979
# 44/44 [==============================] - 1s 17ms/step - loss: 0.6752 - accuracy: 0.9165 - val_loss: 0.8927 - val_accuracy: 0.8562
# Epoch 100/150
# 41/44 [==========================>...] - ETA: 0s - loss: 0.6314 - accuracy: 0.9344
# Epoch 100: val_loss did not improve from 0.86979
# 44/44 [==============================] - 1s 17ms/step - loss: 0.6312 - accuracy: 0.9331 - val_loss: 0.8838 - val_accuracy: 0.8608
# Epoch 101/150
# 44/44 [==============================] - ETA: 0s - loss: 0.6233 - accuracy: 0.9313
# Epoch 101: val_loss did not improve from 0.86979
# 44/44 [==============================] - 1s 17ms/step - loss: 0.6233 - accuracy: 0.9313 - val_loss: 0.8941 - val_accuracy: 0.8507
# Epoch 102/150
# 41/44 [==========================>...] - ETA: 0s - loss: 0.6535 - accuracy: 0.9246
# Epoch 102: val_loss did not improve from 0.86979
# 44/44 [==============================] - 1s 17ms/step - loss: 0.6545 - accuracy: 0.9244 - val_loss: 1.0039 - val_accuracy: 0.8286
# Epoch 103/150
# 44/44 [==============================] - ETA: 0s - loss: 0.7199 - accuracy: 0.9087
# Epoch 103: val_loss did not improve from 0.86979
# 44/44 [==============================] - 1s 18ms/step - loss: 0.7199 - accuracy: 0.9087 - val_loss: 0.9694 - val_accuracy: 0.8488
# Epoch 104/150
# 41/44 [==========================>...] - ETA: 0s - loss: 0.6317 - accuracy: 0.9373
# Epoch 104: val_loss did not improve from 0.86979
# 44/44 [==============================] - 1s 19ms/step - loss: 0.6361 - accuracy: 0.9359 - val_loss: 1.1261 - val_accuracy: 0.7687
# Epoch 105/150
# 42/44 [===========================>..] - ETA: 0s - loss: 0.6744 - accuracy: 0.9207
# Epoch 105: val_loss did not improve from 0.86979
# 44/44 [==============================] - 1s 21ms/step - loss: 0.6711 - accuracy: 0.9216 - val_loss: 0.9271 - val_accuracy: 0.8525
# Epoch 106/150
# 44/44 [==============================] - ETA: 0s - loss: 0.6025 - accuracy: 0.9460
# Epoch 106: val_loss did not improve from 0.86979
# 44/44 [==============================] - 1s 21ms/step - loss: 0.6025 - accuracy: 0.9460 - val_loss: 0.9157 - val_accuracy: 0.8562
# Epoch 107/150
# 44/44 [==============================] - ETA: 0s - loss: 0.6125 - accuracy: 0.9440
# Epoch 107: val_loss did not improve from 0.86979
# 44/44 [==============================] - 1s 18ms/step - loss: 0.6125 - accuracy: 0.9440 - val_loss: 0.9799 - val_accuracy: 0.8378
# Epoch 108/150
# 41/44 [==========================>...] - ETA: 0s - loss: 0.6227 - accuracy: 0.9339
# Epoch 108: val_loss did not improve from 0.86979
# 44/44 [==============================] - 1s 18ms/step - loss: 0.6209 - accuracy: 0.9345 - val_loss: 0.9812 - val_accuracy: 0.8498
# Training completed in time:  0:01:52.077496

# %%
test_accuracy=vggish_model.evaluate(X_test_vggish,y_test,verbose=0)
print(test_accuracy[1])
# Out:
# 0.8571428656578064

# %% [markdown]
# $\Large \color{#495867}{\texttt{GRU}}$

# %%
from keras.models import Sequential
from keras.layers import GRU, Dense, Dropout
from keras.callbacks import ModelCheckpoint, EarlyStopping

# Define GRU model
model_gru = Sequential()
model_gru.add(GRU(128, input_shape=(X_train.shape[1], 1), return_sequences=True))
model_gru.add(GRU(128))
model_gru.add(Dropout(0.5))
model_gru.add(Dense(num_labels, activation='softmax'))

model_gru.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model_gru.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 21, 128)           50304
#
#  gru_1 (GRU)                 (None, 128)               99072
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 150021 (586.02 KB)
# Trainable params: 150021 (586.02 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Add a dimension to input data for GRU
X_train_gru = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test_gru = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# Define checkpoint to save the best model
checkpointer_gru = ModelCheckpoint(filepath='saved_models/audio_classification_gru.hdf5', verbose=1, save_best_only=True)

# Implement early stopping based on validation loss
early_stopping_gru = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# %%
history_gru = model_gru.fit(X_train_gru, y_train, epochs=30, batch_size=35,validation_data=(X_test_gru, y_test),callbacks=[checkpointer_gru, early_stopping_gru])
# Out:
# Epoch 1/30
# 118/124 [===========================>..] - ETA: 0s - loss: 1.5965 - accuracy: 0.2395
# Epoch 1: val_loss improved from inf to 1.53120, saving model to saved_models/audio_classification_gru.hdf5
# 124/124 [==============================] - 6s 13ms/step - loss: 1.5939 - accuracy: 0.2430 - val_loss: 1.5312 - val_accuracy: 0.2774
# Epoch 2/30
# 118/124 [===========================>..] - ETA: 0s - loss: 1.5060 - accuracy: 0.3148
# Epoch 2: val_loss improved from 1.53120 to 1.39565, saving model to saved_models/audio_classification_gru.hdf5
# 124/124 [==============================] - 1s 7ms/step - loss: 1.5043 - accuracy: 0.3175 - val_loss: 1.3957 - val_accuracy: 0.4000
# Epoch 3/30
# 124/124 [==============================] - ETA: 0s - loss: 1.2845 - accuracy: 0.4256
# Epoch 3: val_loss improved from 1.39565 to 1.10045, saving model to saved_models/audio_classification_gru.hdf5
# 124/124 [==============================] - 1s 8ms/step - loss: 1.2845 - accuracy: 0.4256 - val_loss: 1.1004 - val_accuracy: 0.5143
# Epoch 4/30
# 123/124 [============================>.] - ETA: 0s - loss: 1.0771 - accuracy: 0.5373
# Epoch 4: val_loss improved from 1.10045 to 0.92345, saving model to saved_models/audio_classification_gru.hdf5
# 124/124 [==============================] - 1s 8ms/step - loss: 1.0794 - accuracy: 0.5375 - val_loss: 0.9235 - val_accuracy: 0.6120
# Epoch 5/30
# 124/124 [==============================] - ETA: 0s - loss: 0.8966 - accuracy: 0.6288
# Epoch 5: val_loss improved from 0.92345 to 0.82440, saving model to saved_models/audio_classification_gru.hdf5
# 124/124 [==============================] - 1s 8ms/step - loss: 0.8966 - accuracy: 0.6288 - val_loss: 0.8244 - val_accuracy: 0.6571
# Epoch 6/30
# 123/124 [============================>.] - ETA: 0s - loss: 0.7676 - accuracy: 0.6841
# Epoch 6: val_loss improved from 0.82440 to 0.71699, saving model to saved_models/audio_classification_gru.hdf5
# 124/124 [==============================] - 1s 8ms/step - loss: 0.7689 - accuracy: 0.6837 - val_loss: 0.7170 - val_accuracy: 0.6995
# Epoch 7/30
# 120/124 [============================>.] - ETA: 0s - loss: 0.6485 - accuracy: 0.7426
# Epoch 7: val_loss improved from 0.71699 to 0.70431, saving model to saved_models/audio_classification_gru.hdf5
# 124/124 [==============================] - 1s 8ms/step - loss: 0.6535 - accuracy: 0.7418 - val_loss: 0.7043 - val_accuracy: 0.7134
# Epoch 8/30
# 123/124 [============================>.] - ETA: 0s - loss: 0.5587 - accuracy: 0.7840
# Epoch 8: val_loss improved from 0.70431 to 0.60175, saving model to saved_models/audio_classification_gru.hdf5
# 124/124 [==============================] - 1s 10ms/step - loss: 0.5594 - accuracy: 0.7842 - val_loss: 0.6017 - val_accuracy: 0.7373
# Epoch 9/30
# 123/124 [============================>.] - ETA: 0s - loss: 0.4649 - accuracy: 0.8262
# Epoch 9: val_loss improved from 0.60175 to 0.50110, saving model to saved_models/audio_classification_gru.hdf5
# 124/124 [==============================] - 1s 10ms/step - loss: 0.4644 - accuracy: 0.8259 - val_loss: 0.5011 - val_accuracy: 0.8018
# Epoch 10/30
# 119/124 [===========================>..] - ETA: 0s - loss: 0.3825 - accuracy: 0.8598
# Epoch 10: val_loss improved from 0.50110 to 0.50086, saving model to saved_models/audio_classification_gru.hdf5
# 124/124 [==============================] - 1s 10ms/step - loss: 0.3867 - accuracy: 0.8577 - val_loss: 0.5009 - val_accuracy: 0.8065
# Epoch 11/30
# 119/124 [===========================>..] - ETA: 0s - loss: 0.3280 - accuracy: 0.8816
# Epoch 11: val_loss improved from 0.50086 to 0.47929, saving model to saved_models/audio_classification_gru.hdf5
# 124/124 [==============================] - 1s 7ms/step - loss: 0.3303 - accuracy: 0.8810 - val_loss: 0.4793 - val_accuracy: 0.8323
# Epoch 12/30
# 118/124 [===========================>..] - ETA: 0s - loss: 0.2835 - accuracy: 0.8988
# Epoch 12: val_loss improved from 0.47929 to 0.47704, saving model to saved_models/audio_classification_gru.hdf5
# 124/124 [==============================] - 1s 8ms/step - loss: 0.2804 - accuracy: 0.9006 - val_loss: 0.4770 - val_accuracy: 0.8304
# Epoch 13/30
# 119/124 [===========================>..] - ETA: 0s - loss: 0.2122 - accuracy: 0.9287
# Epoch 13: val_loss improved from 0.47704 to 0.45609, saving model to saved_models/audio_classification_gru.hdf5
# 124/124 [==============================] - 1s 7ms/step - loss: 0.2131 - accuracy: 0.9283 - val_loss: 0.4561 - val_accuracy: 0.8498
# Epoch 14/30
# 123/124 [============================>.] - ETA: 0s - loss: 0.2045 - accuracy: 0.9326
# Epoch 14: val_loss did not improve from 0.45609
# 124/124 [==============================] - 1s 8ms/step - loss: 0.2048 - accuracy: 0.9322 - val_loss: 0.4620 - val_accuracy: 0.8470
# Epoch 15/30
# 121/124 [============================>.] - ETA: 0s - loss: 0.1623 - accuracy: 0.9462
# Epoch 15: val_loss improved from 0.45609 to 0.41078, saving model to saved_models/audio_classification_gru.hdf5
# 124/124 [==============================] - 1s 8ms/step - loss: 0.1635 - accuracy: 0.9456 - val_loss: 0.4108 - val_accuracy: 0.8700
# Epoch 16/30
# 123/124 [============================>.] - ETA: 0s - loss: 0.1216 - accuracy: 0.9593
# Epoch 16: val_loss did not improve from 0.41078
# 124/124 [==============================] - 1s 8ms/step - loss: 0.1217 - accuracy: 0.9592 - val_loss: 0.4880 - val_accuracy: 0.8590
# Epoch 17/30
# 117/124 [===========================>..] - ETA: 0s - loss: 0.1038 - accuracy: 0.9665
# Epoch 17: val_loss did not improve from 0.41078
# 124/124 [==============================] - 1s 7ms/step - loss: 0.1056 - accuracy: 0.9656 - val_loss: 0.4957 - val_accuracy: 0.8498
# Epoch 18/30
# 121/124 [============================>.] - ETA: 0s - loss: 0.1217 - accuracy: 0.9587
# Epoch 18: val_loss did not improve from 0.41078
# 124/124 [==============================] - 1s 7ms/step - loss: 0.1206 - accuracy: 0.9594 - val_loss: 0.4953 - val_accuracy: 0.8636
# Epoch 19/30
# 121/124 [============================>.] - ETA: 0s - loss: 0.0774 - accuracy: 0.9731
# Epoch 19: val_loss did not improve from 0.41078
# 124/124 [==============================] - 1s 8ms/step - loss: 0.0769 - accuracy: 0.9735 - val_loss: 0.4881 - val_accuracy: 0.8581
# Epoch 20/30
# 121/124 [============================>.] - ETA: 0s - loss: 0.0804 - accuracy: 0.9740
# Epoch 20: val_loss did not improve from 0.41078
# 124/124 [==============================] - 1s 7ms/step - loss: 0.0808 - accuracy: 0.9739 - val_loss: 0.5025 - val_accuracy: 0.8618

# %%
test_accuracy=model_gru.evaluate(X_test_gru,y_test,verbose=0)
print(test_accuracy[1])
# Out:
# 0.870046079158783

# %%
import matplotlib.pyplot as plt

def plot_metrics(history, title, save_path=None):
    plt.figure(figsize=(13, 6))

    # Plot accuracy
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Training Accuracy',color='#12130F')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy',color='#8FCB9B')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title(f'{title} - Accuracy')
    plt.legend()

    # Plot loss
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Training Loss',color='blue')
    plt.plot(history.history['val_loss'], label='Validation Loss',color='red')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title(f'{title} - Loss')
    plt.legend()

    plt.tight_layout()

    if save_path:
        plt.savefig(save_path)  # Save the figure in jpg format
    else:
        plt.show()

# Plot graphs for the original model
plot_metrics(history, 'Sequential', 'sequential_metrics.jpg')

# Plot graphs for the LSTM model
plot_metrics(history_lstm, 'LSTM', 'lstm_metrics.jpg')

# Plot graphs for the VGGish model
plot_metrics(history_vggish, 'VGGish', 'vggish_metrics.jpg')

plot_metrics(history_gru, 'GRU', 'gru_metrics.jpg')
