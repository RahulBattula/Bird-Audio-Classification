# %% [markdown]
# <a href="https://colab.research.google.com/github/RahulBattula/Bird-Audio-Classification/blob/main/Practice_Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# $\huge \color{#1C110A}{\textbf{Bird's Audio Classification}}$

# %%
import pandas as pd
import os
import librosa

audio_dataset_path='/content/wavfiles'
metadata=pd.read_csv('/content/bird_songs_metadata.csv',usecols=['name','filename'])
metadata.head()
# Out:
#             name      filename
# 0  Bewick's Wren  557838-0.wav
# 1  Bewick's Wren  557838-1.wav
# 2  Bewick's Wren  557838-4.wav
# 3  Bewick's Wren  557838-5.wav
# 4  Bewick's Wren  557838-6.wav

# %%
metadata['name'].value_counts()
# Out:
# Song Sparrow            1256
# Northern Mockingbird    1182
# Northern Cardinal       1074
# American Robin          1017
# Bewick's Wren            893
# Name: name, dtype: int64

# %%
# import os
# os.environ['KAGGLE_USERNAME'] = 'rahulbattula1'
# os.environ['KAGGLE_KEY'] = '7220f5ccf343309b5f337d6ad9b49afc'

# %%
# !kaggle datasets download -d vinayshanbhag/bird-song-data-set

# %%
# !unzip bird-song-data-set.zip

# %%
ls -l ./wavfiles/ | grep -c ^-
# Out:
# 9107

# %%
import os
import librosa
import pandas as pd

audio_folder = "/content/wavfiles"
metadata = pd.read_csv('/content/bird_songs_metadata.csv', usecols=['name', 'filename'])

# Function to calculate audio duration and print files with 3 seconds duration
def get_audio_duration(row):
    file_path = os.path.join(audio_folder, row['filename'])

    # Check if the file exists
    if os.path.exists(file_path):
        try:
            audio_data, _ = librosa.load(file_path, sr=None)
            duration = librosa.get_duration(y=audio_data)

            return duration
        except Exception as e:
            print(f"Error processing {file_path}: {e}")
            return None
    else:
        print(f"File not found: {file_path}")
        return None

# Calculating duration for each audio file
metadata['duration'] = metadata.apply(get_audio_duration, axis=1)

count_greater_than_3s = (metadata['duration'] > 3).sum()
count_less_than_3s = (metadata['duration'] < 3).sum()
count_equal_to_3s = (metadata['duration'] == 3).sum()

print(f"Number of files with duration greater than 3 seconds: {count_greater_than_3s}")
print(f"Number of files with duration less than 3 seconds: {count_less_than_3s}")
print(f"Number of files with duration equal to 3 seconds: {count_equal_to_3s}")
# Out:
# Number of files with duration greater than 3 seconds: 0
# Number of files with duration less than 3 seconds: 0
# Number of files with duration equal to 3 seconds: 5422

# %%
import random
from scipy.io import wavfile
from IPython.display import Audio, display
import matplotlib.pyplot as plt

audio_folder = "/content/wavfiles"

def plot_and_play_wav(metadata, audio_folder):
    random_row = metadata.sample(n=1).iloc[0]
    audio_file_path = os.path.join(audio_folder, random_row['filename'])

    sample_rate, audio_data = wavfile.read(audio_file_path)
    random_color = '#%06x' % random.randint(0, 0xFFFFFF)

    print(f"Species: {random_row['name']}")
    print(f"Sample rate: {sample_rate}")
    print(f"Bit depth: {audio_data.dtype.itemsize * 8} bits")
    print(f"Bit rate: {sample_rate * audio_data.dtype.itemsize * 8} bps")
    print(f"Number of channels: {audio_data.shape[1] if len(audio_data.shape) > 1 else 1}")
    print(f"Audio data shape: {audio_data.shape}")
    print(f"Audio file path: {audio_file_path}")

    plt.figure(figsize=(8, 3))
    plt.plot(audio_data, color=random_color)
    plt.xlabel("Time (samples)")
    plt.ylabel("Amplitude")
    plt.title(f"Waveform - {random_row['name']}")
    plt.show()

    # Play the audio file
    display(Audio(audio_file_path))

# Iterate through each unique species and plot a random waveform
unique_species = metadata['name'].unique()
for species in unique_species:
    species_metadata = metadata[metadata['name'] == species]
    plot_and_play_wav(species_metadata, audio_folder)
# Out:
# Species: Bewick's Wren
# Sample rate: 22050
# Bit depth: 32 bits
# Bit rate: 705600 bps
# Number of channels: 1
# Audio data shape: (66150,)
# Audio file path: /content/wavfiles/178015-1.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Species: Northern Mockingbird
# Sample rate: 22050
# Bit depth: 32 bits
# Bit rate: 705600 bps
# Number of channels: 1
# Audio data shape: (66150,)
# Audio file path: /content/wavfiles/563125-7.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Species: American Robin
# Sample rate: 22050
# Bit depth: 32 bits
# Bit rate: 705600 bps
# Number of channels: 1
# Audio data shape: (66150,)
# Audio file path: /content/wavfiles/564545-9.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Species: Song Sparrow
# Sample rate: 22050
# Bit depth: 32 bits
# Bit rate: 705600 bps
# Number of channels: 1
# Audio data shape: (66150,)
# Audio file path: /content/wavfiles/111671-6.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Species: Northern Cardinal
# Sample rate: 22050
# Bit depth: 32 bits
# Bit rate: 705600 bps
# Number of channels: 1
# Audio data shape: (66150,)
# Audio file path: /content/wavfiles/196163-12.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# $\Large \color{blue}{\texttt{MFCC}}$

# %%
def features_extractor(file):
    audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast')
    mfccs_features = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=29)
    mfccs_scaled_features = np.mean(mfccs_features.T,axis=0)
    return mfccs_scaled_features

# %%
import numpy as np
from tqdm import tqdm
extracted_features=[]
for index_num,row in tqdm(metadata.iterrows()):
    file_name = os.path.join(os.path.abspath(audio_dataset_path), str(row["filename"]))
    final_class_labels=row["name"]
    data=features_extractor(file_name)
    extracted_features.append([data,final_class_labels])
# Out:
# 5422it [01:20, 67.75it/s]

# %%
extracted_features_df=pd.DataFrame(extracted_features,columns=['feature','class'])
extracted_features_df.head()
# Out:
#                                              feature          class
# 0  [-132.85225, 81.13991, 17.018225, 54.974297, -...  Bewick's Wren
# 1  [-147.74393, 99.42544, 20.885645, 44.11881, 1....  Bewick's Wren
# 2  [-92.42778, 84.10636, 17.362778, 53.86046, -8....  Bewick's Wren
# 3  [-93.07557, 81.17431, 16.225544, 52.088425, -8...  Bewick's Wren
# 4  [-107.959145, 92.416, 17.773256, 43.13245, -1....  Bewick's Wren

# %%
extracted_features_df['feature'].shape
# Out:
# (5422,)

# %%
extracted_features_df['feature'][0].shape
# Out:
# (29,)

# %%
pd.DataFrame(extracted_features_df['feature'][0])
# Out:
#              0
# 0  -132.852249
# 1    81.139908
# 2    17.018225
# 3    54.974297
# 4   -10.344643
# 5    24.577351
# 6     3.074978
# 7    19.339340
# 8     5.271629
# 9    15.171051
# 10   -0.072439
# 11    7.569126
# 12   10.887994
# 13    2.635523
# 14   -0.179219
# 15   10.019793
# 16   -4.870444
# 17    4.988724
# 18   -3.737550
# 19    6.274313
# 20   -1.888968
# 21    4.598017
# 22   -0.808164
# 23    2.975708
# 24   -3.222350
# 25    1.768620
# 26   -6.026447
# 27    0.650376
# 28   -5.698422

# %%
type(extracted_features_df['feature'])
# Out:
# pandas.core.series.Series

# %%
X=np.array(extracted_features_df['feature'].tolist())
y=np.array(extracted_features_df['class'].tolist())

# %%
type(X)
# Out:
# numpy.ndarray

# %%
X.shape
# Out:
# (5422, 29)

# %%
X[0]
# Out:
# array([-1.3285225e+02,  8.1139908e+01,  1.7018225e+01,  5.4974297e+01,
#        -1.0344643e+01,  2.4577351e+01,  3.0749784e+00,  1.9339340e+01,
#         5.2716293e+00,  1.5171051e+01, -7.2438858e-02,  7.5691257e+00,
#         1.0887994e+01,  2.6355228e+00, -1.7921886e-01,  1.0019793e+01,
#        -4.8704443e+00,  4.9887242e+00, -3.7375500e+00,  6.2743134e+00,
#        -1.8889681e+00,  4.5980167e+00, -8.0816400e-01,  2.9757080e+00,
#        -3.2223499e+00,  1.7686201e+00, -6.0264468e+00,  6.5037578e-01,
#        -5.6984224e+00], dtype=float32)

# %%
y.shape
# Out:
# (5422,)

# %%
y[0:10]
# Out:
# array(["Bewick's Wren", "Bewick's Wren", "Bewick's Wren", "Bewick's Wren",
#        "Bewick's Wren", "Bewick's Wren", "Bewick's Wren", "Bewick's Wren",
#        "Bewick's Wren", "Bewick's Wren"], dtype='<U20')

# %%
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
labelencoder=LabelEncoder()
y=to_categorical(labelencoder.fit_transform(y))

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
X_train
# Out:
# array([[-2.71316162e+02, -2.64190636e+01, -6.37647400e+01, ...,
#         -2.72700238e+00,  5.40624142e+00,  1.09858942e+00],
#        [-4.01369904e+02, -3.11115341e+01, -9.22452240e+01, ...,
#         -2.77299553e-01, -4.23504639e+00, -3.84573650e+00],
#        [-3.66750488e+02, -3.91612077e+00, -1.18178535e+02, ...,
#          1.63709074e-01, -6.15807152e+00,  3.01525450e+00],
#        ...,
#        [-6.30036049e+01,  8.80372009e+01, -3.07785492e+01, ...,
#         -3.49993443e+00, -6.53113747e+00, -6.03709316e+00],
#        [-3.61907593e+02,  3.06769199e+01, -6.47375183e+01, ...,
#         -4.98553693e-01,  4.66802865e-01, -3.94135565e-01],
#        [-1.68720596e+02,  1.31053841e+00, -6.54630203e+01, ...,
#         -2.42758560e+00, -1.70078874e+00, -4.45585823e+00]], dtype=float32)

# %%
X_train.shape
# Out:
# (4337, 29)

# %%
X_test.shape
# Out:
# (1085, 29)

# %%
y_train.shape
# Out:
# (4337, 5)

# %%
y_test.shape
# Out:
# (1085, 5)

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.15.0

# %%
from tensorflow.keras.models import Sequential,Model
from tensorflow.keras.layers import Dense,Dropout,Activation,Flatten,LSTM, Input, Conv1D, MaxPooling1D
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import Adam
from sklearn import metrics
import warnings
warnings.filterwarnings('ignore')

# %%
num_labels=y.shape[1]

# %%
num_labels
# Out:
# 5

# %% [markdown]
# $\Large \color{orange}{\texttt{Sequential}}$

# %%
model=Sequential()
###first layer
model.add(Dense(100,input_shape=(29,)))
model.add(Activation('relu'))
model.add(Dropout(0.5))
###second layer
model.add(Dense(200))
model.add(Activation('relu'))
model.add(Dropout(0.5))
###third layer
model.add(Dense(100))
model.add(Activation('relu'))
model.add(Dropout(0.5))
###final layer
model.add(Dense(num_labels))
model.add(Activation('softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 100)               3000
#
#  activation (Activation)     (None, 100)               0
#
#  dropout (Dropout)           (None, 100)               0
#
#  dense_1 (Dense)             (None, 200)               20200
#
#  activation_1 (Activation)   (None, 200)               0
#
#  dropout_1 (Dropout)         (None, 200)               0
#
#  dense_2 (Dense)             (None, 100)               20100
#
#  activation_2 (Activation)   (None, 100)               0
#
#  dropout_2 (Dropout)         (None, 100)               0
#
#  dense_3 (Dense)             (None, 5)                 505
#
#  activation_3 (Activation)   (None, 5)                 0
#
# =================================================================
# Total params: 43805 (171.11 KB)
# Trainable params: 43805 (171.11 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',metrics=['accuracy'],optimizer='adam')

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
from datetime import datetime
checkpointer = ModelCheckpoint(filepath='saved_models/audio_classification.hdf5',
                               verbose=1, save_best_only=True)
start = datetime.now()

history = model.fit(X_train, y_train, batch_size=32, epochs=100,
                    validation_data=(X_test, y_test), callbacks=[checkpointer], verbose=1)

duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Epoch 1/100
# 131/136 [===========================>..] - ETA: 0s - loss: 16.4721 - accuracy: 0.2164
# Epoch 1: val_loss improved from inf to 1.61092, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 4s 6ms/step - loss: 16.0830 - accuracy: 0.2165 - val_loss: 1.6109 - val_accuracy: 0.1779
# Epoch 2/100
# 130/136 [===========================>..] - ETA: 0s - loss: 3.0365 - accuracy: 0.2180
# Epoch 2: val_loss improved from 1.61092 to 1.60834, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 3.0041 - accuracy: 0.2184 - val_loss: 1.6083 - val_accuracy: 0.1945
# Epoch 3/100
# 134/136 [============================>.] - ETA: 0s - loss: 1.9277 - accuracy: 0.2271
# Epoch 3: val_loss improved from 1.60834 to 1.60714, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 1.9245 - accuracy: 0.2273 - val_loss: 1.6071 - val_accuracy: 0.2249
# Epoch 4/100
# 125/136 [==========================>...] - ETA: 0s - loss: 1.7419 - accuracy: 0.2292
# Epoch 4: val_loss improved from 1.60714 to 1.60649, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 1.7442 - accuracy: 0.2271 - val_loss: 1.6065 - val_accuracy: 0.2249
# Epoch 5/100
# 134/136 [============================>.] - ETA: 0s - loss: 1.6823 - accuracy: 0.2337
# Epoch 5: val_loss improved from 1.60649 to 1.60615, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 1.6834 - accuracy: 0.2326 - val_loss: 1.6062 - val_accuracy: 0.2249
# Epoch 6/100
# 129/136 [===========================>..] - ETA: 0s - loss: 1.6520 - accuracy: 0.2294
# Epoch 6: val_loss improved from 1.60615 to 1.60608, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 1.6512 - accuracy: 0.2297 - val_loss: 1.6061 - val_accuracy: 0.2249
# Epoch 7/100
# 129/136 [===========================>..] - ETA: 0s - loss: 1.6271 - accuracy: 0.2359
# Epoch 7: val_loss did not improve from 1.60608
# 136/136 [==============================] - 1s 5ms/step - loss: 1.6285 - accuracy: 0.2343 - val_loss: 1.6062 - val_accuracy: 0.2249
# Epoch 8/100
# 131/136 [===========================>..] - ETA: 0s - loss: 1.6238 - accuracy: 0.2347
# Epoch 8: val_loss did not improve from 1.60608
# 136/136 [==============================] - 1s 5ms/step - loss: 1.6247 - accuracy: 0.2340 - val_loss: 1.6063 - val_accuracy: 0.2249
# Epoch 9/100
# 132/136 [============================>.] - ETA: 0s - loss: 1.6201 - accuracy: 0.2353
# Epoch 9: val_loss did not improve from 1.60608
# 136/136 [==============================] - 1s 5ms/step - loss: 1.6194 - accuracy: 0.2352 - val_loss: 1.6065 - val_accuracy: 0.2249
# Epoch 10/100
# 128/136 [===========================>..] - ETA: 0s - loss: 1.6178 - accuracy: 0.2312
# Epoch 10: val_loss did not improve from 1.60608
# 136/136 [==============================] - 1s 4ms/step - loss: 1.6174 - accuracy: 0.2317 - val_loss: 1.6067 - val_accuracy: 0.2249
# Epoch 11/100
# 131/136 [===========================>..] - ETA: 0s - loss: 1.6170 - accuracy: 0.2319
# Epoch 11: val_loss did not improve from 1.60608
# 136/136 [==============================] - 1s 4ms/step - loss: 1.6162 - accuracy: 0.2326 - val_loss: 1.6067 - val_accuracy: 0.2249
# Epoch 12/100
# 132/136 [============================>.] - ETA: 0s - loss: 1.6111 - accuracy: 0.2379
# Epoch 12: val_loss did not improve from 1.60608
# 136/136 [==============================] - 1s 4ms/step - loss: 1.6105 - accuracy: 0.2386 - val_loss: 1.6067 - val_accuracy: 0.2249
# Epoch 13/100
# 130/136 [===========================>..] - ETA: 0s - loss: 1.6098 - accuracy: 0.2344
# Epoch 13: val_loss did not improve from 1.60608
# 136/136 [==============================] - 1s 4ms/step - loss: 1.6098 - accuracy: 0.2347 - val_loss: 1.6069 - val_accuracy: 0.2249
# Epoch 14/100
# 128/136 [===========================>..] - ETA: 0s - loss: 1.6119 - accuracy: 0.2336
# Epoch 14: val_loss did not improve from 1.60608
# 136/136 [==============================] - 1s 5ms/step - loss: 1.6122 - accuracy: 0.2331 - val_loss: 1.6069 - val_accuracy: 0.2249
# Epoch 15/100
# 127/136 [===========================>..] - ETA: 0s - loss: 1.6055 - accuracy: 0.2365
# Epoch 15: val_loss did not improve from 1.60608
# 136/136 [==============================] - 1s 6ms/step - loss: 1.6055 - accuracy: 0.2345 - val_loss: 1.6070 - val_accuracy: 0.2249
# Epoch 16/100
# 133/136 [============================>.] - ETA: 0s - loss: 1.6090 - accuracy: 0.2336
# Epoch 16: val_loss did not improve from 1.60608
# 136/136 [==============================] - 1s 6ms/step - loss: 1.6088 - accuracy: 0.2329 - val_loss: 1.6070 - val_accuracy: 0.2249
# Epoch 17/100
# 128/136 [===========================>..] - ETA: 0s - loss: 1.6033 - accuracy: 0.2312
# Epoch 17: val_loss did not improve from 1.60608
# 136/136 [==============================] - 1s 6ms/step - loss: 1.6027 - accuracy: 0.2313 - val_loss: 1.6070 - val_accuracy: 0.2249
# Epoch 18/100
# 130/136 [===========================>..] - ETA: 0s - loss: 1.6072 - accuracy: 0.2327
# Epoch 18: val_loss did not improve from 1.60608
# 136/136 [==============================] - 1s 6ms/step - loss: 1.6078 - accuracy: 0.2326 - val_loss: 1.6070 - val_accuracy: 0.2249
# Epoch 19/100
# 130/136 [===========================>..] - ETA: 0s - loss: 1.6083 - accuracy: 0.2317
# Epoch 19: val_loss did not improve from 1.60608
# 136/136 [==============================] - 1s 4ms/step - loss: 1.6076 - accuracy: 0.2350 - val_loss: 1.6070 - val_accuracy: 0.2249
# Epoch 20/100
# 136/136 [==============================] - ETA: 0s - loss: 1.6051 - accuracy: 0.2329
# Epoch 20: val_loss did not improve from 1.60608
# 136/136 [==============================] - 1s 5ms/step - loss: 1.6051 - accuracy: 0.2329 - val_loss: 1.6071 - val_accuracy: 0.2249
# Epoch 21/100
# 126/136 [==========================>...] - ETA: 0s - loss: 1.6043 - accuracy: 0.2366
# Epoch 21: val_loss did not improve from 1.60608
# 136/136 [==============================] - 1s 5ms/step - loss: 1.6040 - accuracy: 0.2363 - val_loss: 1.6070 - val_accuracy: 0.2249
# Epoch 22/100
# 133/136 [============================>.] - ETA: 0s - loss: 1.6021 - accuracy: 0.2343
# Epoch 22: val_loss did not improve from 1.60608
# 136/136 [==============================] - 1s 4ms/step - loss: 1.6020 - accuracy: 0.2350 - val_loss: 1.6071 - val_accuracy: 0.2249
# Epoch 23/100
# 123/136 [==========================>...] - ETA: 0s - loss: 1.6054 - accuracy: 0.2376
# Epoch 23: val_loss did not improve from 1.60608
# 136/136 [==============================] - 1s 4ms/step - loss: 1.6063 - accuracy: 0.2373 - val_loss: 1.6071 - val_accuracy: 0.2249
# Epoch 24/100
# 128/136 [===========================>..] - ETA: 0s - loss: 1.6019 - accuracy: 0.2373
# Epoch 24: val_loss did not improve from 1.60608
# 136/136 [==============================] - 1s 4ms/step - loss: 1.6014 - accuracy: 0.2377 - val_loss: 1.6071 - val_accuracy: 0.2249
# Epoch 25/100
# 126/136 [==========================>...] - ETA: 0s - loss: 1.6016 - accuracy: 0.2403
# Epoch 25: val_loss did not improve from 1.60608
# 136/136 [==============================] - 1s 4ms/step - loss: 1.6017 - accuracy: 0.2382 - val_loss: 1.6071 - val_accuracy: 0.2249
# Epoch 26/100
# 132/136 [============================>.] - ETA: 0s - loss: 1.6022 - accuracy: 0.2396
# Epoch 26: val_loss did not improve from 1.60608
# 136/136 [==============================] - 1s 4ms/step - loss: 1.6016 - accuracy: 0.2398 - val_loss: 1.6070 - val_accuracy: 0.2258
# Epoch 27/100
# 129/136 [===========================>..] - ETA: 0s - loss: 1.5965 - accuracy: 0.2515
# Epoch 27: val_loss improved from 1.60608 to 1.60093, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 1.5973 - accuracy: 0.2516 - val_loss: 1.6009 - val_accuracy: 0.2544
# Epoch 28/100
# 136/136 [==============================] - ETA: 0s - loss: 1.5926 - accuracy: 0.2576
# Epoch 28: val_loss improved from 1.60093 to 1.58300, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 4ms/step - loss: 1.5926 - accuracy: 0.2576 - val_loss: 1.5830 - val_accuracy: 0.2894
# Epoch 29/100
# 127/136 [===========================>..] - ETA: 0s - loss: 1.5728 - accuracy: 0.2731
# Epoch 29: val_loss improved from 1.58300 to 1.52373, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 1.5715 - accuracy: 0.2748 - val_loss: 1.5237 - val_accuracy: 0.3484
# Epoch 30/100
# 129/136 [===========================>..] - ETA: 0s - loss: 1.5607 - accuracy: 0.2859
# Epoch 30: val_loss improved from 1.52373 to 1.46687, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 1.5583 - accuracy: 0.2875 - val_loss: 1.4669 - val_accuracy: 0.3825
# Epoch 31/100
# 135/136 [============================>.] - ETA: 0s - loss: 1.5331 - accuracy: 0.3028
# Epoch 31: val_loss did not improve from 1.46687
# 136/136 [==============================] - 1s 4ms/step - loss: 1.5330 - accuracy: 0.3025 - val_loss: 1.4990 - val_accuracy: 0.3364
# Epoch 32/100
# 129/136 [===========================>..] - ETA: 0s - loss: 1.5082 - accuracy: 0.3249
# Epoch 32: val_loss improved from 1.46687 to 1.37347, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 4ms/step - loss: 1.5069 - accuracy: 0.3233 - val_loss: 1.3735 - val_accuracy: 0.3889
# Epoch 33/100
# 129/136 [===========================>..] - ETA: 0s - loss: 1.4768 - accuracy: 0.3256
# Epoch 33: val_loss improved from 1.37347 to 1.34691, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 1.4749 - accuracy: 0.3260 - val_loss: 1.3469 - val_accuracy: 0.3889
# Epoch 34/100
# 133/136 [============================>.] - ETA: 0s - loss: 1.4125 - accuracy: 0.3400
# Epoch 34: val_loss improved from 1.34691 to 1.23293, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 6ms/step - loss: 1.4133 - accuracy: 0.3403 - val_loss: 1.2329 - val_accuracy: 0.3779
# Epoch 35/100
# 129/136 [===========================>..] - ETA: 0s - loss: 1.3648 - accuracy: 0.3624
# Epoch 35: val_loss improved from 1.23293 to 1.22123, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 6ms/step - loss: 1.3603 - accuracy: 0.3657 - val_loss: 1.2212 - val_accuracy: 0.3935
# Epoch 36/100
# 132/136 [============================>.] - ETA: 0s - loss: 1.3331 - accuracy: 0.3722
# Epoch 36: val_loss improved from 1.22123 to 1.19341, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 6ms/step - loss: 1.3309 - accuracy: 0.3728 - val_loss: 1.1934 - val_accuracy: 0.4184
# Epoch 37/100
# 125/136 [==========================>...] - ETA: 0s - loss: 1.2823 - accuracy: 0.3830
# Epoch 37: val_loss improved from 1.19341 to 1.18716, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 6ms/step - loss: 1.2894 - accuracy: 0.3800 - val_loss: 1.1872 - val_accuracy: 0.3954
# Epoch 38/100
# 132/136 [============================>.] - ETA: 0s - loss: 1.2905 - accuracy: 0.3904
# Epoch 38: val_loss improved from 1.18716 to 1.17349, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 1.2918 - accuracy: 0.3881 - val_loss: 1.1735 - val_accuracy: 0.4147
# Epoch 39/100
# 132/136 [============================>.] - ETA: 0s - loss: 1.2777 - accuracy: 0.4020
# Epoch 39: val_loss improved from 1.17349 to 1.15229, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 4ms/step - loss: 1.2753 - accuracy: 0.4040 - val_loss: 1.1523 - val_accuracy: 0.4276
# Epoch 40/100
# 127/136 [===========================>..] - ETA: 0s - loss: 1.2532 - accuracy: 0.4104
# Epoch 40: val_loss improved from 1.15229 to 1.12916, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 1.2475 - accuracy: 0.4127 - val_loss: 1.1292 - val_accuracy: 0.4498
# Epoch 41/100
# 136/136 [==============================] - ETA: 0s - loss: 1.2387 - accuracy: 0.4139
# Epoch 41: val_loss improved from 1.12916 to 1.11170, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 1.2387 - accuracy: 0.4139 - val_loss: 1.1117 - val_accuracy: 0.4728
# Epoch 42/100
# 125/136 [==========================>...] - ETA: 0s - loss: 1.2094 - accuracy: 0.4313
# Epoch 42: val_loss improved from 1.11170 to 1.07414, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 1.2081 - accuracy: 0.4328 - val_loss: 1.0741 - val_accuracy: 0.4894
# Epoch 43/100
# 131/136 [===========================>..] - ETA: 0s - loss: 1.1869 - accuracy: 0.4566
# Epoch 43: val_loss improved from 1.07414 to 1.03415, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 1.1894 - accuracy: 0.4556 - val_loss: 1.0342 - val_accuracy: 0.5263
# Epoch 44/100
# 124/136 [==========================>...] - ETA: 0s - loss: 1.1516 - accuracy: 0.4627
# Epoch 44: val_loss improved from 1.03415 to 1.00090, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 1.1485 - accuracy: 0.4639 - val_loss: 1.0009 - val_accuracy: 0.5429
# Epoch 45/100
# 125/136 [==========================>...] - ETA: 0s - loss: 1.1478 - accuracy: 0.4748
# Epoch 45: val_loss did not improve from 1.00090
# 136/136 [==============================] - 1s 5ms/step - loss: 1.1462 - accuracy: 0.4724 - val_loss: 1.0061 - val_accuracy: 0.5438
# Epoch 46/100
# 128/136 [===========================>..] - ETA: 0s - loss: 1.1172 - accuracy: 0.4797
# Epoch 46: val_loss improved from 1.00090 to 0.98126, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 1.1210 - accuracy: 0.4775 - val_loss: 0.9813 - val_accuracy: 0.5097
# Epoch 47/100
# 132/136 [============================>.] - ETA: 0s - loss: 1.1138 - accuracy: 0.4912
# Epoch 47: val_loss improved from 0.98126 to 0.96356, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 1.1110 - accuracy: 0.4900 - val_loss: 0.9636 - val_accuracy: 0.5613
# Epoch 48/100
# 133/136 [============================>.] - ETA: 0s - loss: 1.0819 - accuracy: 0.5101
# Epoch 48: val_loss did not improve from 0.96356
# 136/136 [==============================] - 1s 5ms/step - loss: 1.0801 - accuracy: 0.5084 - val_loss: 0.9676 - val_accuracy: 0.5041
# Epoch 49/100
# 132/136 [============================>.] - ETA: 0s - loss: 1.0765 - accuracy: 0.4974
# Epoch 49: val_loss improved from 0.96356 to 0.95989, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 4ms/step - loss: 1.0739 - accuracy: 0.4994 - val_loss: 0.9599 - val_accuracy: 0.5724
# Epoch 50/100
# 125/136 [==========================>...] - ETA: 0s - loss: 1.0551 - accuracy: 0.5117
# Epoch 50: val_loss improved from 0.95989 to 0.92684, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 1.0607 - accuracy: 0.5123 - val_loss: 0.9268 - val_accuracy: 0.5917
# Epoch 51/100
# 122/136 [=========================>....] - ETA: 0s - loss: 1.0344 - accuracy: 0.5179
# Epoch 51: val_loss improved from 0.92684 to 0.89802, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 1.0344 - accuracy: 0.5213 - val_loss: 0.8980 - val_accuracy: 0.5871
# Epoch 52/100
# 131/136 [===========================>..] - ETA: 0s - loss: 1.0269 - accuracy: 0.5308
# Epoch 52: val_loss did not improve from 0.89802
# 136/136 [==============================] - 1s 6ms/step - loss: 1.0254 - accuracy: 0.5294 - val_loss: 0.9140 - val_accuracy: 0.5871
# Epoch 53/100
# 126/136 [==========================>...] - ETA: 0s - loss: 1.0182 - accuracy: 0.5223
# Epoch 53: val_loss improved from 0.89802 to 0.88587, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 7ms/step - loss: 1.0191 - accuracy: 0.5232 - val_loss: 0.8859 - val_accuracy: 0.6083
# Epoch 54/100
# 136/136 [==============================] - ETA: 0s - loss: 1.0225 - accuracy: 0.5333
# Epoch 54: val_loss did not improve from 0.88587
# 136/136 [==============================] - 1s 6ms/step - loss: 1.0225 - accuracy: 0.5333 - val_loss: 0.8874 - val_accuracy: 0.6175
# Epoch 55/100
# 129/136 [===========================>..] - ETA: 0s - loss: 1.0022 - accuracy: 0.5504
# Epoch 55: val_loss improved from 0.88587 to 0.86635, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 7ms/step - loss: 0.9951 - accuracy: 0.5520 - val_loss: 0.8664 - val_accuracy: 0.6157
# Epoch 56/100
# 135/136 [============================>.] - ETA: 0s - loss: 0.9820 - accuracy: 0.5500
# Epoch 56: val_loss improved from 0.86635 to 0.85802, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 0.9814 - accuracy: 0.5508 - val_loss: 0.8580 - val_accuracy: 0.6286
# Epoch 57/100
# 130/136 [===========================>..] - ETA: 0s - loss: 0.9801 - accuracy: 0.5575
# Epoch 57: val_loss improved from 0.85802 to 0.84684, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 0.9808 - accuracy: 0.5561 - val_loss: 0.8468 - val_accuracy: 0.6406
# Epoch 58/100
# 129/136 [===========================>..] - ETA: 0s - loss: 0.9772 - accuracy: 0.5686
# Epoch 58: val_loss improved from 0.84684 to 0.81728, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 4ms/step - loss: 0.9814 - accuracy: 0.5665 - val_loss: 0.8173 - val_accuracy: 0.6369
# Epoch 59/100
# 130/136 [===========================>..] - ETA: 0s - loss: 0.9749 - accuracy: 0.5695
# Epoch 59: val_loss improved from 0.81728 to 0.81075, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 0.9750 - accuracy: 0.5691 - val_loss: 0.8107 - val_accuracy: 0.6544
# Epoch 60/100
# 129/136 [===========================>..] - ETA: 0s - loss: 0.9461 - accuracy: 0.5773
# Epoch 60: val_loss improved from 0.81075 to 0.79845, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 4ms/step - loss: 0.9459 - accuracy: 0.5764 - val_loss: 0.7985 - val_accuracy: 0.6498
# Epoch 61/100
# 127/136 [===========================>..] - ETA: 0s - loss: 0.9298 - accuracy: 0.5810
# Epoch 61: val_loss improved from 0.79845 to 0.78574, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 0.9288 - accuracy: 0.5813 - val_loss: 0.7857 - val_accuracy: 0.6618
# Epoch 62/100
# 129/136 [===========================>..] - ETA: 0s - loss: 0.9386 - accuracy: 0.5785
# Epoch 62: val_loss did not improve from 0.78574
# 136/136 [==============================] - 1s 5ms/step - loss: 0.9363 - accuracy: 0.5817 - val_loss: 0.7918 - val_accuracy: 0.6793
# Epoch 63/100
# 129/136 [===========================>..] - ETA: 0s - loss: 0.9114 - accuracy: 0.5913
# Epoch 63: val_loss improved from 0.78574 to 0.78316, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 4ms/step - loss: 0.9128 - accuracy: 0.5912 - val_loss: 0.7832 - val_accuracy: 0.6793
# Epoch 64/100
# 124/136 [==========================>...] - ETA: 0s - loss: 0.9218 - accuracy: 0.5905
# Epoch 64: val_loss improved from 0.78316 to 0.78274, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 0.9172 - accuracy: 0.5928 - val_loss: 0.7827 - val_accuracy: 0.6700
# Epoch 65/100
# 123/136 [==========================>...] - ETA: 0s - loss: 0.8901 - accuracy: 0.6065
# Epoch 65: val_loss improved from 0.78274 to 0.74393, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 0.8906 - accuracy: 0.6059 - val_loss: 0.7439 - val_accuracy: 0.6728
# Epoch 66/100
# 130/136 [===========================>..] - ETA: 0s - loss: 0.8884 - accuracy: 0.6019
# Epoch 66: val_loss did not improve from 0.74393
# 136/136 [==============================] - 1s 4ms/step - loss: 0.8902 - accuracy: 0.6023 - val_loss: 0.7642 - val_accuracy: 0.6636
# Epoch 67/100
# 132/136 [============================>.] - ETA: 0s - loss: 0.8909 - accuracy: 0.6027
# Epoch 67: val_loss did not improve from 0.74393
# 136/136 [==============================] - 1s 5ms/step - loss: 0.8888 - accuracy: 0.6034 - val_loss: 0.7482 - val_accuracy: 0.7069
# Epoch 68/100
# 132/136 [============================>.] - ETA: 0s - loss: 0.8802 - accuracy: 0.6226
# Epoch 68: val_loss did not improve from 0.74393
# 136/136 [==============================] - 1s 5ms/step - loss: 0.8793 - accuracy: 0.6228 - val_loss: 0.7581 - val_accuracy: 0.6811
# Epoch 69/100
# 130/136 [===========================>..] - ETA: 0s - loss: 0.9003 - accuracy: 0.6079
# Epoch 69: val_loss did not improve from 0.74393
# 136/136 [==============================] - 1s 4ms/step - loss: 0.8988 - accuracy: 0.6066 - val_loss: 0.7481 - val_accuracy: 0.7143
# Epoch 70/100
# 129/136 [===========================>..] - ETA: 0s - loss: 0.8426 - accuracy: 0.6197
# Epoch 70: val_loss improved from 0.74393 to 0.73071, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 0.8435 - accuracy: 0.6200 - val_loss: 0.7307 - val_accuracy: 0.7106
# Epoch 71/100
# 129/136 [===========================>..] - ETA: 0s - loss: 0.8588 - accuracy: 0.6284
# Epoch 71: val_loss improved from 0.73071 to 0.72645, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 6ms/step - loss: 0.8563 - accuracy: 0.6285 - val_loss: 0.7265 - val_accuracy: 0.7152
# Epoch 72/100
# 128/136 [===========================>..] - ETA: 0s - loss: 0.8809 - accuracy: 0.6125
# Epoch 72: val_loss did not improve from 0.72645
# 136/136 [==============================] - 1s 6ms/step - loss: 0.8763 - accuracy: 0.6156 - val_loss: 0.7460 - val_accuracy: 0.7281
# Epoch 73/100
# 136/136 [==============================] - ETA: 0s - loss: 0.8570 - accuracy: 0.6285
# Epoch 73: val_loss improved from 0.72645 to 0.70740, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 6ms/step - loss: 0.8570 - accuracy: 0.6285 - val_loss: 0.7074 - val_accuracy: 0.7410
# Epoch 74/100
# 135/136 [============================>.] - ETA: 0s - loss: 0.8438 - accuracy: 0.6400
# Epoch 74: val_loss did not improve from 0.70740
# 136/136 [==============================] - 1s 10ms/step - loss: 0.8443 - accuracy: 0.6396 - val_loss: 0.7182 - val_accuracy: 0.7475
# Epoch 75/100
# 123/136 [==========================>...] - ETA: 0s - loss: 0.8681 - accuracy: 0.6324
# Epoch 75: val_loss improved from 0.70740 to 0.70014, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 0.8604 - accuracy: 0.6341 - val_loss: 0.7001 - val_accuracy: 0.7318
# Epoch 76/100
# 127/136 [===========================>..] - ETA: 0s - loss: 0.8249 - accuracy: 0.6540
# Epoch 76: val_loss improved from 0.70014 to 0.69588, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 0.8288 - accuracy: 0.6514 - val_loss: 0.6959 - val_accuracy: 0.7465
# Epoch 77/100
# 132/136 [============================>.] - ETA: 0s - loss: 0.8470 - accuracy: 0.6390
# Epoch 77: val_loss did not improve from 0.69588
# 136/136 [==============================] - 1s 4ms/step - loss: 0.8475 - accuracy: 0.6387 - val_loss: 0.7240 - val_accuracy: 0.7419
# Epoch 78/100
# 124/136 [==========================>...] - ETA: 0s - loss: 0.8082 - accuracy: 0.6522
# Epoch 78: val_loss did not improve from 0.69588
# 136/136 [==============================] - 1s 4ms/step - loss: 0.8107 - accuracy: 0.6562 - val_loss: 0.6962 - val_accuracy: 0.7493
# Epoch 79/100
# 132/136 [============================>.] - ETA: 0s - loss: 0.8365 - accuracy: 0.6435
# Epoch 79: val_loss did not improve from 0.69588
# 136/136 [==============================] - 1s 5ms/step - loss: 0.8340 - accuracy: 0.6451 - val_loss: 0.6959 - val_accuracy: 0.7512
# Epoch 80/100
# 125/136 [==========================>...] - ETA: 0s - loss: 0.8010 - accuracy: 0.6625
# Epoch 80: val_loss improved from 0.69588 to 0.67572, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 0.8000 - accuracy: 0.6654 - val_loss: 0.6757 - val_accuracy: 0.7576
# Epoch 81/100
# 130/136 [===========================>..] - ETA: 0s - loss: 0.8003 - accuracy: 0.6613
# Epoch 81: val_loss did not improve from 0.67572
# 136/136 [==============================] - 1s 4ms/step - loss: 0.7953 - accuracy: 0.6636 - val_loss: 0.6772 - val_accuracy: 0.7585
# Epoch 82/100
# 130/136 [===========================>..] - ETA: 0s - loss: 0.7971 - accuracy: 0.6656
# Epoch 82: val_loss improved from 0.67572 to 0.66210, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 4ms/step - loss: 0.7979 - accuracy: 0.6643 - val_loss: 0.6621 - val_accuracy: 0.7622
# Epoch 83/100
# 133/136 [============================>.] - ETA: 0s - loss: 0.7999 - accuracy: 0.6687
# Epoch 83: val_loss did not improve from 0.66210
# 136/136 [==============================] - 1s 5ms/step - loss: 0.7990 - accuracy: 0.6700 - val_loss: 0.6764 - val_accuracy: 0.7604
# Epoch 84/100
# 130/136 [===========================>..] - ETA: 0s - loss: 0.8050 - accuracy: 0.6639
# Epoch 84: val_loss did not improve from 0.66210
# 136/136 [==============================] - 1s 4ms/step - loss: 0.8068 - accuracy: 0.6617 - val_loss: 0.6706 - val_accuracy: 0.7604
# Epoch 85/100
# 132/136 [============================>.] - ETA: 0s - loss: 0.7763 - accuracy: 0.6707
# Epoch 85: val_loss did not improve from 0.66210
# 136/136 [==============================] - 1s 4ms/step - loss: 0.7808 - accuracy: 0.6694 - val_loss: 0.6647 - val_accuracy: 0.7622
# Epoch 86/100
# 125/136 [==========================>...] - ETA: 0s - loss: 0.7903 - accuracy: 0.6680
# Epoch 86: val_loss improved from 0.66210 to 0.64446, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 0.7851 - accuracy: 0.6724 - val_loss: 0.6445 - val_accuracy: 0.7733
# Epoch 87/100
# 131/136 [===========================>..] - ETA: 0s - loss: 0.7904 - accuracy: 0.6729
# Epoch 87: val_loss did not improve from 0.64446
# 136/136 [==============================] - 1s 4ms/step - loss: 0.7902 - accuracy: 0.6742 - val_loss: 0.6450 - val_accuracy: 0.7714
# Epoch 88/100
# 135/136 [============================>.] - ETA: 0s - loss: 0.7987 - accuracy: 0.6674
# Epoch 88: val_loss improved from 0.64446 to 0.63515, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 7ms/step - loss: 0.7988 - accuracy: 0.6673 - val_loss: 0.6351 - val_accuracy: 0.7816
# Epoch 89/100
# 131/136 [===========================>..] - ETA: 0s - loss: 0.7754 - accuracy: 0.6815
# Epoch 89: val_loss did not improve from 0.63515
# 136/136 [==============================] - 1s 5ms/step - loss: 0.7751 - accuracy: 0.6783 - val_loss: 0.6584 - val_accuracy: 0.7816
# Epoch 90/100
# 134/136 [============================>.] - ETA: 0s - loss: 0.7678 - accuracy: 0.6812
# Epoch 90: val_loss improved from 0.63515 to 0.63188, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 7ms/step - loss: 0.7676 - accuracy: 0.6813 - val_loss: 0.6319 - val_accuracy: 0.7714
# Epoch 91/100
# 131/136 [===========================>..] - ETA: 0s - loss: 0.7531 - accuracy: 0.6873
# Epoch 91: val_loss improved from 0.63188 to 0.62267, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 7ms/step - loss: 0.7535 - accuracy: 0.6883 - val_loss: 0.6227 - val_accuracy: 0.7908
# Epoch 92/100
# 134/136 [============================>.] - ETA: 0s - loss: 0.7769 - accuracy: 0.6845
# Epoch 92: val_loss improved from 0.62267 to 0.61376, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 7ms/step - loss: 0.7761 - accuracy: 0.6848 - val_loss: 0.6138 - val_accuracy: 0.7963
# Epoch 93/100
# 124/136 [==========================>...] - ETA: 0s - loss: 0.7719 - accuracy: 0.6802
# Epoch 93: val_loss did not improve from 0.61376
# 136/136 [==============================] - 1s 5ms/step - loss: 0.7694 - accuracy: 0.6816 - val_loss: 0.6351 - val_accuracy: 0.7806
# Epoch 94/100
# 131/136 [===========================>..] - ETA: 0s - loss: 0.7589 - accuracy: 0.6861
# Epoch 94: val_loss did not improve from 0.61376
# 136/136 [==============================] - 1s 4ms/step - loss: 0.7607 - accuracy: 0.6848 - val_loss: 0.6214 - val_accuracy: 0.7788
# Epoch 95/100
# 129/136 [===========================>..] - ETA: 0s - loss: 0.7569 - accuracy: 0.6909
# Epoch 95: val_loss improved from 0.61376 to 0.61117, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 5ms/step - loss: 0.7529 - accuracy: 0.6922 - val_loss: 0.6112 - val_accuracy: 0.7779
# Epoch 96/100
# 132/136 [============================>.] - ETA: 0s - loss: 0.7474 - accuracy: 0.6953
# Epoch 96: val_loss did not improve from 0.61117
# 136/136 [==============================] - 1s 4ms/step - loss: 0.7481 - accuracy: 0.6959 - val_loss: 0.6118 - val_accuracy: 0.7742
# Epoch 97/100
# 126/136 [==========================>...] - ETA: 0s - loss: 0.7439 - accuracy: 0.6833
# Epoch 97: val_loss did not improve from 0.61117
# 136/136 [==============================] - 1s 4ms/step - loss: 0.7424 - accuracy: 0.6846 - val_loss: 0.6194 - val_accuracy: 0.7899
# Epoch 98/100
# 132/136 [============================>.] - ETA: 0s - loss: 0.7375 - accuracy: 0.6996
# Epoch 98: val_loss improved from 0.61117 to 0.60182, saving model to saved_models/audio_classification.hdf5
# 136/136 [==============================] - 1s 4ms/step - loss: 0.7357 - accuracy: 0.7009 - val_loss: 0.6018 - val_accuracy: 0.7880
# Epoch 99/100
# 125/136 [==========================>...] - ETA: 0s - loss: 0.7438 - accuracy: 0.7063
# Epoch 99: val_loss did not improve from 0.60182
# 136/136 [==============================] - 1s 4ms/step - loss: 0.7394 - accuracy: 0.7074 - val_loss: 0.6232 - val_accuracy: 0.7899
# Epoch 100/100
# 125/136 [==========================>...] - ETA: 0s - loss: 0.7500 - accuracy: 0.7040
# Epoch 100: val_loss did not improve from 0.60182
# 136/136 [==============================] - 1s 4ms/step - loss: 0.7530 - accuracy: 0.7042 - val_loss: 0.6134 - val_accuracy: 0.7963
# Training completed in time:  0:01:12.913913

# %%
test_accuracy=model.evaluate(X_test,y_test,verbose=0)
print(test_accuracy[1])
# Out:
# 0.7963133454322815

# %% [markdown]
# $\Large \color{green}{\texttt{LSTM}}$

# %%
X_train_lstm = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test_lstm = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# %%
# Define LSTM model
model_lstm = Sequential()
model_lstm.add(LSTM(128, input_shape=(X_train.shape[1], 1), return_sequences=True))
model_lstm.add(LSTM(128))
model_lstm.add(Dropout(0.5))
model_lstm.add(Dense(num_labels, activation='softmax'))

model_lstm.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Add a dimension to input data for LSTM
X_train_lstm = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test_lstm = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# Define checkpoint to save the best model
checkpointer_lstm = ModelCheckpoint(filepath='saved_models/audio_classification_lstm.hdf5', verbose=1, save_best_only=True)

# Implement early stopping based on validation loss
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# %%
# Train LSTM model
start = datetime.now()
history_lstm = model_lstm.fit(X_train_lstm, y_train, batch_size=35, epochs=30,validation_data=(X_test_lstm, y_test),
                               callbacks=[checkpointer_lstm, early_stopping], verbose=1)
duration_lstm = datetime.now() - start
print("Training completed in time: ", duration_lstm)
# Out:
# Epoch 1/30
# 120/124 [============================>.] - ETA: 0s - loss: 1.5810 - accuracy: 0.2652
# Epoch 1: val_loss improved from inf to 1.51026, saving model to saved_models/audio_classification_lstm.hdf5
# 124/124 [==============================] - 6s 20ms/step - loss: 1.5794 - accuracy: 0.2668 - val_loss: 1.5103 - val_accuracy: 0.3244
# Epoch 2/30
# 117/124 [===========================>..] - ETA: 0s - loss: 1.4677 - accuracy: 0.3495
# Epoch 2: val_loss improved from 1.51026 to 1.31729, saving model to saved_models/audio_classification_lstm.hdf5
# 124/124 [==============================] - 1s 11ms/step - loss: 1.4626 - accuracy: 0.3528 - val_loss: 1.3173 - val_accuracy: 0.4286
# Epoch 3/30
# 121/124 [============================>.] - ETA: 0s - loss: 1.2888 - accuracy: 0.4494
# Epoch 3: val_loss improved from 1.31729 to 1.12920, saving model to saved_models/audio_classification_lstm.hdf5
# 124/124 [==============================] - 1s 8ms/step - loss: 1.2869 - accuracy: 0.4515 - val_loss: 1.1292 - val_accuracy: 0.5207
# Epoch 4/30
# 117/124 [===========================>..] - ETA: 0s - loss: 1.1502 - accuracy: 0.5375
# Epoch 4: val_loss did not improve from 1.12920
# 124/124 [==============================] - 1s 8ms/step - loss: 1.1495 - accuracy: 0.5384 - val_loss: 1.1649 - val_accuracy: 0.5134
# Epoch 5/30
# 117/124 [===========================>..] - ETA: 0s - loss: 1.0621 - accuracy: 0.5744
# Epoch 5: val_loss improved from 1.12920 to 0.95924, saving model to saved_models/audio_classification_lstm.hdf5
# 124/124 [==============================] - 1s 8ms/step - loss: 1.0657 - accuracy: 0.5723 - val_loss: 0.9592 - val_accuracy: 0.6065
# Epoch 6/30
# 119/124 [===========================>..] - ETA: 0s - loss: 0.9558 - accuracy: 0.6226
# Epoch 6: val_loss improved from 0.95924 to 0.84109, saving model to saved_models/audio_classification_lstm.hdf5
# 124/124 [==============================] - 1s 8ms/step - loss: 0.9503 - accuracy: 0.6249 - val_loss: 0.8411 - val_accuracy: 0.6719
# Epoch 7/30
# 124/124 [==============================] - ETA: 0s - loss: 0.8521 - accuracy: 0.6631
# Epoch 7: val_loss improved from 0.84109 to 0.74373, saving model to saved_models/audio_classification_lstm.hdf5
# 124/124 [==============================] - 1s 8ms/step - loss: 0.8521 - accuracy: 0.6631 - val_loss: 0.7437 - val_accuracy: 0.7152
# Epoch 8/30
# 118/124 [===========================>..] - ETA: 0s - loss: 0.7575 - accuracy: 0.7094
# Epoch 8: val_loss improved from 0.74373 to 0.69061, saving model to saved_models/audio_classification_lstm.hdf5
# 124/124 [==============================] - 1s 8ms/step - loss: 0.7515 - accuracy: 0.7109 - val_loss: 0.6906 - val_accuracy: 0.7336
# Epoch 9/30
# 118/124 [===========================>..] - ETA: 0s - loss: 0.6654 - accuracy: 0.7521
# Epoch 9: val_loss did not improve from 0.69061
# 124/124 [==============================] - 1s 8ms/step - loss: 0.6656 - accuracy: 0.7505 - val_loss: 0.6967 - val_accuracy: 0.7419
# Epoch 10/30
# 118/124 [===========================>..] - ETA: 0s - loss: 0.5901 - accuracy: 0.7792
# Epoch 10: val_loss improved from 0.69061 to 0.61754, saving model to saved_models/audio_classification_lstm.hdf5
# 124/124 [==============================] - 1s 8ms/step - loss: 0.5929 - accuracy: 0.7775 - val_loss: 0.6175 - val_accuracy: 0.7733
# Epoch 11/30
# 123/124 [============================>.] - ETA: 0s - loss: 0.5222 - accuracy: 0.8107
# Epoch 11: val_loss did not improve from 0.61754
# 124/124 [==============================] - 1s 8ms/step - loss: 0.5212 - accuracy: 0.8114 - val_loss: 0.6297 - val_accuracy: 0.7742
# Epoch 12/30
# 120/124 [============================>.] - ETA: 0s - loss: 0.4601 - accuracy: 0.8376
# Epoch 12: val_loss improved from 0.61754 to 0.54772, saving model to saved_models/audio_classification_lstm.hdf5
# 124/124 [==============================] - 1s 11ms/step - loss: 0.4609 - accuracy: 0.8358 - val_loss: 0.5477 - val_accuracy: 0.8074
# Epoch 13/30
# 121/124 [============================>.] - ETA: 0s - loss: 0.4221 - accuracy: 0.8475
# Epoch 13: val_loss improved from 0.54772 to 0.49853, saving model to saved_models/audio_classification_lstm.hdf5
# 124/124 [==============================] - 2s 13ms/step - loss: 0.4207 - accuracy: 0.8481 - val_loss: 0.4985 - val_accuracy: 0.8323
# Epoch 14/30
# 122/124 [============================>.] - ETA: 0s - loss: 0.3592 - accuracy: 0.8740
# Epoch 14: val_loss improved from 0.49853 to 0.48207, saving model to saved_models/audio_classification_lstm.hdf5
# 124/124 [==============================] - 1s 10ms/step - loss: 0.3604 - accuracy: 0.8732 - val_loss: 0.4821 - val_accuracy: 0.8359
# Epoch 15/30
# 124/124 [==============================] - ETA: 0s - loss: 0.3369 - accuracy: 0.8836
# Epoch 15: val_loss did not improve from 0.48207
# 124/124 [==============================] - 1s 8ms/step - loss: 0.3369 - accuracy: 0.8836 - val_loss: 0.5873 - val_accuracy: 0.8184
# Epoch 16/30
# 119/124 [===========================>..] - ETA: 0s - loss: 0.2889 - accuracy: 0.8980
# Epoch 16: val_loss did not improve from 0.48207
# 124/124 [==============================] - 1s 9ms/step - loss: 0.2918 - accuracy: 0.8974 - val_loss: 0.5035 - val_accuracy: 0.8323
# Epoch 17/30
# 122/124 [============================>.] - ETA: 0s - loss: 0.2619 - accuracy: 0.9105
# Epoch 17: val_loss improved from 0.48207 to 0.43663, saving model to saved_models/audio_classification_lstm.hdf5
# 124/124 [==============================] - 1s 8ms/step - loss: 0.2604 - accuracy: 0.9110 - val_loss: 0.4366 - val_accuracy: 0.8544
# Epoch 18/30
# 121/124 [============================>.] - ETA: 0s - loss: 0.2316 - accuracy: 0.9169
# Epoch 18: val_loss did not improve from 0.43663
# 124/124 [==============================] - 1s 8ms/step - loss: 0.2329 - accuracy: 0.9165 - val_loss: 0.4641 - val_accuracy: 0.8461
# Epoch 19/30
# 124/124 [==============================] - ETA: 0s - loss: 0.2427 - accuracy: 0.9184
# Epoch 19: val_loss did not improve from 0.43663
# 124/124 [==============================] - 1s 8ms/step - loss: 0.2427 - accuracy: 0.9184 - val_loss: 0.4500 - val_accuracy: 0.8581
# Epoch 20/30
# 124/124 [==============================] - ETA: 0s - loss: 0.1890 - accuracy: 0.9371
# Epoch 20: val_loss did not improve from 0.43663
# 124/124 [==============================] - 1s 8ms/step - loss: 0.1890 - accuracy: 0.9371 - val_loss: 0.4570 - val_accuracy: 0.8673
# Epoch 21/30
# 121/124 [============================>.] - ETA: 0s - loss: 0.1791 - accuracy: 0.9379
# Epoch 21: val_loss improved from 0.43663 to 0.41991, saving model to saved_models/audio_classification_lstm.hdf5
# 124/124 [==============================] - 1s 8ms/step - loss: 0.1787 - accuracy: 0.9382 - val_loss: 0.4199 - val_accuracy: 0.8710
# Epoch 22/30
# 121/124 [============================>.] - ETA: 0s - loss: 0.1308 - accuracy: 0.9563
# Epoch 22: val_loss did not improve from 0.41991
# 124/124 [==============================] - 1s 8ms/step - loss: 0.1311 - accuracy: 0.9557 - val_loss: 0.5079 - val_accuracy: 0.8608
# Epoch 23/30
# 117/124 [===========================>..] - ETA: 0s - loss: 0.1353 - accuracy: 0.9534
# Epoch 23: val_loss did not improve from 0.41991
# 124/124 [==============================] - 1s 8ms/step - loss: 0.1421 - accuracy: 0.9511 - val_loss: 0.5133 - val_accuracy: 0.8581
# Epoch 24/30
# 122/124 [============================>.] - ETA: 0s - loss: 0.1667 - accuracy: 0.9438
# Epoch 24: val_loss improved from 0.41991 to 0.38720, saving model to saved_models/audio_classification_lstm.hdf5
# 124/124 [==============================] - 1s 11ms/step - loss: 0.1656 - accuracy: 0.9442 - val_loss: 0.3872 - val_accuracy: 0.8949
# Epoch 25/30
# 121/124 [============================>.] - ETA: 0s - loss: 0.1151 - accuracy: 0.9622
# Epoch 25: val_loss did not improve from 0.38720
# 124/124 [==============================] - 1s 11ms/step - loss: 0.1163 - accuracy: 0.9622 - val_loss: 0.4453 - val_accuracy: 0.8839
# Epoch 26/30
# 117/124 [===========================>..] - ETA: 0s - loss: 0.1366 - accuracy: 0.9538
# Epoch 26: val_loss did not improve from 0.38720
# 124/124 [==============================] - 1s 10ms/step - loss: 0.1389 - accuracy: 0.9534 - val_loss: 0.4838 - val_accuracy: 0.8673
# Epoch 27/30
# 124/124 [==============================] - ETA: 0s - loss: 0.0858 - accuracy: 0.9730
# Epoch 27: val_loss did not improve from 0.38720
# 124/124 [==============================] - 1s 8ms/step - loss: 0.0858 - accuracy: 0.9730 - val_loss: 0.4660 - val_accuracy: 0.8894
# Epoch 28/30
# 119/124 [===========================>..] - ETA: 0s - loss: 0.0864 - accuracy: 0.9709
# Epoch 28: val_loss did not improve from 0.38720
# 124/124 [==============================] - 1s 8ms/step - loss: 0.0866 - accuracy: 0.9707 - val_loss: 0.5826 - val_accuracy: 0.8664
# Epoch 29/30
# 117/124 [===========================>..] - ETA: 0s - loss: 0.1336 - accuracy: 0.9529
# Epoch 29: val_loss did not improve from 0.38720
# 124/124 [==============================] - 1s 8ms/step - loss: 0.1319 - accuracy: 0.9537 - val_loss: 0.3966 - val_accuracy: 0.8876
# Training completed in time:  0:00:36.940621

# %%
test_accuracy=model_lstm.evaluate(X_test_lstm,y_test,verbose=0)
print(test_accuracy[1])
# Out:
# 0.894930899143219

# %% [markdown]
# $\Large \color{purple}{\texttt{VGGish}}$

# %%
def vggish_model(input_shape, num_labels, dropout_rate=0.5, l2_reg=0.0001):
    model_input = Input(shape=input_shape, name='input')

    # Block 1
    x = Conv1D(128, kernel_size=3, activation='relu', padding='same', kernel_regularizer='l2', name='conv1')(model_input)
    x = MaxPooling1D(pool_size=2, name='pool1')(x)

    # Block 2
    x = Conv1D(256, kernel_size=3, activation='relu', padding='same', kernel_regularizer='l2', name='conv2')(x)
    x = MaxPooling1D(pool_size=2, name='pool2')(x)

    # Block 3
    x = Conv1D(512, kernel_size=3, activation='relu', padding='same', kernel_regularizer='l2', name='conv3')(x)
    x = Conv1D(512, kernel_size=3, activation='relu', padding='same', kernel_regularizer='l2', name='conv4')(x)
    x = MaxPooling1D(pool_size=2, name='pool3')(x)

    # Block 4
    x = Conv1D(1024, kernel_size=3, activation='relu', padding='same', kernel_regularizer='l2', name='conv5')(x)
    x = Conv1D(1024, kernel_size=3, activation='relu', padding='same', kernel_regularizer='l2', name='conv6')(x)
    x = MaxPooling1D(pool_size=2, name='pool4')(x)

    # Flatten and fully connected layers
    x = Flatten(name='flatten')(x)
    x = Dense(2048, activation='relu', kernel_regularizer='l2', name='fc1')(x)
    x = Dropout(dropout_rate, name='dropout1')(x)
    x = Dense(2048, activation='relu', kernel_regularizer='l2', name='fc2')(x)
    x = Dropout(dropout_rate, name='dropout2')(x)

    # Output layer
    model_output = Dense(num_labels, activation='softmax', name='predictions')(x)

    model = Model(inputs=model_input, outputs=model_output, name='vggish')
    return model

# %%
# Reshape data for VGGish
X_train_vggish = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test_vggish = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

vggish_model = vggish_model((X_train_vggish.shape[1], 1), num_labels, dropout_rate=0.7, l2_reg=0.0001)
vggish_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Model summary
vggish_model.summary()
# Out:
# Model: "vggish"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 29, 1)]           0
#
#  conv1 (Conv1D)              (None, 29, 128)           512
#
#  pool1 (MaxPooling1D)        (None, 14, 128)           0
#
#  conv2 (Conv1D)              (None, 14, 256)           98560
#
#  pool2 (MaxPooling1D)        (None, 7, 256)            0
#
#  conv3 (Conv1D)              (None, 7, 512)            393728
#
#  conv4 (Conv1D)              (None, 7, 512)            786944
#
#  pool3 (MaxPooling1D)        (None, 3, 512)            0
#
#  conv5 (Conv1D)              (None, 3, 1024)           1573888
#
#  conv6 (Conv1D)              (None, 3, 1024)           3146752
#
#  pool4 (MaxPooling1D)        (None, 1, 1024)           0
#
#  flatten (Flatten)           (None, 1024)              0
#
#  fc1 (Dense)                 (None, 2048)              2099200
#
#  dropout1 (Dropout)          (None, 2048)              0
#
#  fc2 (Dense)                 (None, 2048)              4196352
#
#  dropout2 (Dropout)          (None, 2048)              0
#
#  predictions (Dense)         (None, 5)                 10245
#
# =================================================================
# Total params: 12306181 (46.94 MB)
# Trainable params: 12306181 (46.94 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Define checkpoint to save the best model
checkpoint_vggish = ModelCheckpoint(filepath='saved_models/audio_classification_vggish.hdf5', verbose=1, save_best_only=True)

# Implement early stopping based on validation loss
early_stopping_vggish = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)

# Train the model
start_vggish = datetime.now()
history_vggish = vggish_model.fit(X_train_vggish, y_train, batch_size=100, epochs=150,
                                  validation_data=(X_test_vggish, y_test),
                                  callbacks=[checkpoint_vggish, early_stopping_vggish], verbose=1)

duration_vggish = datetime.now() - start_vggish
print("Training completed in time: ", duration_vggish)
# Out:
# Epoch 1/150
# 44/44 [==============================] - ETA: 0s - loss: 29.1054 - accuracy: 0.2333
# Epoch 1: val_loss improved from inf to 10.43010, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 8s 72ms/step - loss: 29.1054 - accuracy: 0.2333 - val_loss: 10.4301 - val_accuracy: 0.2396
# Epoch 2/150
# 41/44 [==========================>...] - ETA: 0s - loss: 6.5530 - accuracy: 0.3254
# Epoch 2: val_loss improved from 10.43010 to 3.90538, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 27ms/step - loss: 6.4180 - accuracy: 0.3263 - val_loss: 3.9054 - val_accuracy: 0.3982
# Epoch 3/150
# 41/44 [==========================>...] - ETA: 0s - loss: 3.0266 - accuracy: 0.3829
# Epoch 3: val_loss improved from 3.90538 to 2.25469, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 28ms/step - loss: 2.9876 - accuracy: 0.3862 - val_loss: 2.2547 - val_accuracy: 0.4028
# Epoch 4/150
# 41/44 [==========================>...] - ETA: 0s - loss: 2.0001 - accuracy: 0.4144
# Epoch 4: val_loss improved from 2.25469 to 1.72506, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 27ms/step - loss: 1.9903 - accuracy: 0.4125 - val_loss: 1.7251 - val_accuracy: 0.4184
# Epoch 5/150
# 41/44 [==========================>...] - ETA: 0s - loss: 1.6385 - accuracy: 0.4163
# Epoch 5: val_loss improved from 1.72506 to 1.50115, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 2s 37ms/step - loss: 1.6352 - accuracy: 0.4160 - val_loss: 1.5011 - val_accuracy: 0.4378
# Epoch 6/150
# 44/44 [==============================] - ETA: 0s - loss: 1.4830 - accuracy: 0.4284
# Epoch 6: val_loss improved from 1.50115 to 1.39766, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 28ms/step - loss: 1.4830 - accuracy: 0.4284 - val_loss: 1.3977 - val_accuracy: 0.4304
# Epoch 7/150
# 42/44 [===========================>..] - ETA: 0s - loss: 1.4152 - accuracy: 0.4345
# Epoch 7: val_loss improved from 1.39766 to 1.37928, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 28ms/step - loss: 1.4161 - accuracy: 0.4346 - val_loss: 1.3793 - val_accuracy: 0.4470
# Epoch 8/150
# 44/44 [==============================] - ETA: 0s - loss: 1.3780 - accuracy: 0.4379
# Epoch 8: val_loss improved from 1.37928 to 1.30940, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 3s 62ms/step - loss: 1.3780 - accuracy: 0.4379 - val_loss: 1.3094 - val_accuracy: 0.4654
# Epoch 9/150
# 43/44 [============================>.] - ETA: 0s - loss: 1.3435 - accuracy: 0.4419
# Epoch 9: val_loss improved from 1.30940 to 1.29374, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 2s 36ms/step - loss: 1.3428 - accuracy: 0.4415 - val_loss: 1.2937 - val_accuracy: 0.4562
# Epoch 10/150
# 43/44 [============================>.] - ETA: 0s - loss: 1.3082 - accuracy: 0.4507
# Epoch 10: val_loss improved from 1.29374 to 1.25480, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 30ms/step - loss: 1.3087 - accuracy: 0.4512 - val_loss: 1.2548 - val_accuracy: 0.4922
# Epoch 11/150
# 44/44 [==============================] - ETA: 0s - loss: 1.3190 - accuracy: 0.4538
# Epoch 11: val_loss did not improve from 1.25480
# 44/44 [==============================] - 1s 18ms/step - loss: 1.3190 - accuracy: 0.4538 - val_loss: 1.2849 - val_accuracy: 0.4747
# Epoch 12/150
# 44/44 [==============================] - ETA: 0s - loss: 1.2988 - accuracy: 0.4748
# Epoch 12: val_loss did not improve from 1.25480
# 44/44 [==============================] - 1s 18ms/step - loss: 1.2988 - accuracy: 0.4748 - val_loss: 1.2687 - val_accuracy: 0.5143
# Epoch 13/150
# 42/44 [===========================>..] - ETA: 0s - loss: 1.2739 - accuracy: 0.4905
# Epoch 13: val_loss improved from 1.25480 to 1.19732, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 28ms/step - loss: 1.2722 - accuracy: 0.4909 - val_loss: 1.1973 - val_accuracy: 0.5207
# Epoch 14/150
# 43/44 [============================>.] - ETA: 0s - loss: 1.2618 - accuracy: 0.5095
# Epoch 14: val_loss improved from 1.19732 to 1.18021, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 29ms/step - loss: 1.2617 - accuracy: 0.5084 - val_loss: 1.1802 - val_accuracy: 0.5594
# Epoch 15/150
# 42/44 [===========================>..] - ETA: 0s - loss: 1.2432 - accuracy: 0.5143
# Epoch 15: val_loss did not improve from 1.18021
# 44/44 [==============================] - 1s 18ms/step - loss: 1.2435 - accuracy: 0.5176 - val_loss: 1.1891 - val_accuracy: 0.5613
# Epoch 16/150
# 44/44 [==============================] - ETA: 0s - loss: 1.2371 - accuracy: 0.5266
# Epoch 16: val_loss did not improve from 1.18021
# 44/44 [==============================] - 1s 18ms/step - loss: 1.2371 - accuracy: 0.5266 - val_loss: 1.1990 - val_accuracy: 0.5189
# Epoch 17/150
# 42/44 [===========================>..] - ETA: 0s - loss: 1.2427 - accuracy: 0.5174
# Epoch 17: val_loss improved from 1.18021 to 1.17652, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 28ms/step - loss: 1.2421 - accuracy: 0.5190 - val_loss: 1.1765 - val_accuracy: 0.5613
# Epoch 18/150
# 41/44 [==========================>...] - ETA: 0s - loss: 1.2126 - accuracy: 0.5498
# Epoch 18: val_loss improved from 1.17652 to 1.16363, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 33ms/step - loss: 1.2112 - accuracy: 0.5485 - val_loss: 1.1636 - val_accuracy: 0.5558
# Epoch 19/150
# 44/44 [==============================] - ETA: 0s - loss: 1.2178 - accuracy: 0.5430
# Epoch 19: val_loss improved from 1.16363 to 1.14782, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 29ms/step - loss: 1.2178 - accuracy: 0.5430 - val_loss: 1.1478 - val_accuracy: 0.5659
# Epoch 20/150
# 43/44 [============================>.] - ETA: 0s - loss: 1.1957 - accuracy: 0.5630
# Epoch 20: val_loss did not improve from 1.14782
# 44/44 [==============================] - 1s 21ms/step - loss: 1.1951 - accuracy: 0.5638 - val_loss: 1.1596 - val_accuracy: 0.5714
# Epoch 21/150
# 44/44 [==============================] - ETA: 0s - loss: 1.2010 - accuracy: 0.5582
# Epoch 21: val_loss improved from 1.14782 to 1.13971, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 33ms/step - loss: 1.2010 - accuracy: 0.5582 - val_loss: 1.1397 - val_accuracy: 0.5926
# Epoch 22/150
# 43/44 [============================>.] - ETA: 0s - loss: 1.1742 - accuracy: 0.5744
# Epoch 22: val_loss improved from 1.13971 to 1.11254, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 34ms/step - loss: 1.1735 - accuracy: 0.5732 - val_loss: 1.1125 - val_accuracy: 0.6000
# Epoch 23/150
# 42/44 [===========================>..] - ETA: 0s - loss: 1.1797 - accuracy: 0.5802
# Epoch 23: val_loss did not improve from 1.11254
# 44/44 [==============================] - 1s 18ms/step - loss: 1.1786 - accuracy: 0.5813 - val_loss: 1.1560 - val_accuracy: 0.5853
# Epoch 24/150
# 42/44 [===========================>..] - ETA: 0s - loss: 1.1834 - accuracy: 0.5762
# Epoch 24: val_loss improved from 1.11254 to 1.10564, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 28ms/step - loss: 1.1832 - accuracy: 0.5771 - val_loss: 1.1056 - val_accuracy: 0.6101
# Epoch 25/150
# 43/44 [============================>.] - ETA: 0s - loss: 1.1499 - accuracy: 0.5953
# Epoch 25: val_loss did not improve from 1.10564
# 44/44 [==============================] - 1s 18ms/step - loss: 1.1513 - accuracy: 0.5947 - val_loss: 1.1364 - val_accuracy: 0.5935
# Epoch 26/150
# 43/44 [============================>.] - ETA: 0s - loss: 1.1809 - accuracy: 0.5881
# Epoch 26: val_loss did not improve from 1.10564
# 44/44 [==============================] - 1s 18ms/step - loss: 1.1794 - accuracy: 0.5896 - val_loss: 1.1546 - val_accuracy: 0.5825
# Epoch 27/150
# 44/44 [==============================] - ETA: 0s - loss: 1.1409 - accuracy: 0.6011
# Epoch 27: val_loss did not improve from 1.10564
# 44/44 [==============================] - 1s 18ms/step - loss: 1.1409 - accuracy: 0.6011 - val_loss: 1.1221 - val_accuracy: 0.5889
# Epoch 28/150
# 41/44 [==========================>...] - ETA: 0s - loss: 1.1610 - accuracy: 0.5922
# Epoch 28: val_loss did not improve from 1.10564
# 44/44 [==============================] - 1s 18ms/step - loss: 1.1614 - accuracy: 0.5912 - val_loss: 1.1312 - val_accuracy: 0.6065
# Epoch 29/150
# 43/44 [============================>.] - ETA: 0s - loss: 1.1109 - accuracy: 0.6202
# Epoch 29: val_loss did not improve from 1.10564
# 44/44 [==============================] - 1s 18ms/step - loss: 1.1112 - accuracy: 0.6189 - val_loss: 1.1143 - val_accuracy: 0.6258
# Epoch 30/150
# 43/44 [============================>.] - ETA: 0s - loss: 1.1232 - accuracy: 0.6160
# Epoch 30: val_loss did not improve from 1.10564
# 44/44 [==============================] - 1s 18ms/step - loss: 1.1218 - accuracy: 0.6163 - val_loss: 1.1297 - val_accuracy: 0.6175
# Epoch 31/150
# 44/44 [==============================] - ETA: 0s - loss: 1.1060 - accuracy: 0.6269
# Epoch 31: val_loss improved from 1.10564 to 1.06828, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 28ms/step - loss: 1.1060 - accuracy: 0.6269 - val_loss: 1.0683 - val_accuracy: 0.6276
# Epoch 32/150
# 42/44 [===========================>..] - ETA: 0s - loss: 1.0995 - accuracy: 0.6290
# Epoch 32: val_loss did not improve from 1.06828
# 44/44 [==============================] - 1s 18ms/step - loss: 1.0982 - accuracy: 0.6290 - val_loss: 1.1022 - val_accuracy: 0.6184
# Epoch 33/150
# 41/44 [==========================>...] - ETA: 0s - loss: 1.0795 - accuracy: 0.6341
# Epoch 33: val_loss did not improve from 1.06828
# 44/44 [==============================] - 1s 20ms/step - loss: 1.0817 - accuracy: 0.6332 - val_loss: 1.0906 - val_accuracy: 0.6221
# Epoch 34/150
# 41/44 [==========================>...] - ETA: 0s - loss: 1.0840 - accuracy: 0.6427
# Epoch 34: val_loss did not improve from 1.06828
# 44/44 [==============================] - 1s 20ms/step - loss: 1.0889 - accuracy: 0.6421 - val_loss: 1.0774 - val_accuracy: 0.6184
# Epoch 35/150
# 43/44 [============================>.] - ETA: 0s - loss: 1.0707 - accuracy: 0.6521
# Epoch 35: val_loss did not improve from 1.06828
# 44/44 [==============================] - 1s 19ms/step - loss: 1.0720 - accuracy: 0.6509 - val_loss: 1.1085 - val_accuracy: 0.6415
# Epoch 36/150
# 42/44 [===========================>..] - ETA: 0s - loss: 1.0873 - accuracy: 0.6481
# Epoch 36: val_loss did not improve from 1.06828
# 44/44 [==============================] - 1s 20ms/step - loss: 1.0863 - accuracy: 0.6498 - val_loss: 1.0724 - val_accuracy: 0.6507
# Epoch 37/150
# 44/44 [==============================] - ETA: 0s - loss: 1.0539 - accuracy: 0.6641
# Epoch 37: val_loss improved from 1.06828 to 1.04763, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 28ms/step - loss: 1.0539 - accuracy: 0.6641 - val_loss: 1.0476 - val_accuracy: 0.6525
# Epoch 38/150
# 41/44 [==========================>...] - ETA: 0s - loss: 1.0352 - accuracy: 0.6724
# Epoch 38: val_loss did not improve from 1.04763
# 44/44 [==============================] - 1s 18ms/step - loss: 1.0425 - accuracy: 0.6682 - val_loss: 1.0502 - val_accuracy: 0.6581
# Epoch 39/150
# 43/44 [============================>.] - ETA: 0s - loss: 1.0584 - accuracy: 0.6633
# Epoch 39: val_loss did not improve from 1.04763
# 44/44 [==============================] - 1s 18ms/step - loss: 1.0592 - accuracy: 0.6638 - val_loss: 1.1177 - val_accuracy: 0.6295
# Epoch 40/150
# 43/44 [============================>.] - ETA: 0s - loss: 1.0456 - accuracy: 0.6760
# Epoch 40: val_loss did not improve from 1.04763
# 44/44 [==============================] - 1s 18ms/step - loss: 1.0447 - accuracy: 0.6770 - val_loss: 1.2084 - val_accuracy: 0.5687
# Epoch 41/150
# 41/44 [==========================>...] - ETA: 0s - loss: 1.0448 - accuracy: 0.6654
# Epoch 41: val_loss did not improve from 1.04763
# 44/44 [==============================] - 1s 18ms/step - loss: 1.0421 - accuracy: 0.6661 - val_loss: 1.0598 - val_accuracy: 0.6461
# Epoch 42/150
# 43/44 [============================>.] - ETA: 0s - loss: 1.0092 - accuracy: 0.6907
# Epoch 42: val_loss improved from 1.04763 to 1.03468, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 27ms/step - loss: 1.0106 - accuracy: 0.6896 - val_loss: 1.0347 - val_accuracy: 0.6636
# Epoch 43/150
# 41/44 [==========================>...] - ETA: 0s - loss: 1.0435 - accuracy: 0.6712
# Epoch 43: val_loss did not improve from 1.03468
# 44/44 [==============================] - 1s 18ms/step - loss: 1.0373 - accuracy: 0.6751 - val_loss: 1.1356 - val_accuracy: 0.6166
# Epoch 44/150
# 42/44 [===========================>..] - ETA: 0s - loss: 1.0269 - accuracy: 0.6836
# Epoch 44: val_loss improved from 1.03468 to 1.01781, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 28ms/step - loss: 1.0290 - accuracy: 0.6823 - val_loss: 1.0178 - val_accuracy: 0.6553
# Epoch 45/150
# 43/44 [============================>.] - ETA: 0s - loss: 1.0123 - accuracy: 0.6830
# Epoch 45: val_loss did not improve from 1.01781
# 44/44 [==============================] - 1s 18ms/step - loss: 1.0130 - accuracy: 0.6825 - val_loss: 1.1583 - val_accuracy: 0.6498
# Epoch 46/150
# 44/44 [==============================] - ETA: 0s - loss: 1.0530 - accuracy: 0.6756
# Epoch 46: val_loss did not improve from 1.01781
# 44/44 [==============================] - 1s 18ms/step - loss: 1.0530 - accuracy: 0.6756 - val_loss: 1.0359 - val_accuracy: 0.6636
# Epoch 47/150
# 42/44 [===========================>..] - ETA: 0s - loss: 0.9816 - accuracy: 0.7002
# Epoch 47: val_loss did not improve from 1.01781
# 44/44 [==============================] - 1s 19ms/step - loss: 0.9830 - accuracy: 0.6998 - val_loss: 1.0522 - val_accuracy: 0.6820
# Epoch 48/150
# 43/44 [============================>.] - ETA: 0s - loss: 1.0070 - accuracy: 0.6844
# Epoch 48: val_loss did not improve from 1.01781
# 44/44 [==============================] - 1s 21ms/step - loss: 1.0079 - accuracy: 0.6837 - val_loss: 1.0460 - val_accuracy: 0.6627
# Epoch 49/150
# 41/44 [==========================>...] - ETA: 0s - loss: 0.9668 - accuracy: 0.7141
# Epoch 49: val_loss did not improve from 1.01781
# 44/44 [==============================] - 1s 19ms/step - loss: 0.9678 - accuracy: 0.7097 - val_loss: 1.0608 - val_accuracy: 0.6682
# Epoch 50/150
# 43/44 [============================>.] - ETA: 0s - loss: 0.9959 - accuracy: 0.6909
# Epoch 50: val_loss improved from 1.01781 to 1.01575, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 29ms/step - loss: 0.9965 - accuracy: 0.6913 - val_loss: 1.0158 - val_accuracy: 0.6710
# Epoch 51/150
# 41/44 [==========================>...] - ETA: 0s - loss: 0.9842 - accuracy: 0.6998
# Epoch 51: val_loss improved from 1.01575 to 1.00471, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 28ms/step - loss: 0.9854 - accuracy: 0.7012 - val_loss: 1.0047 - val_accuracy: 0.6802
# Epoch 52/150
# 44/44 [==============================] - ETA: 0s - loss: 0.9750 - accuracy: 0.7106
# Epoch 52: val_loss did not improve from 1.00471
# 44/44 [==============================] - 1s 18ms/step - loss: 0.9750 - accuracy: 0.7106 - val_loss: 1.0278 - val_accuracy: 0.6682
# Epoch 53/150
# 41/44 [==========================>...] - ETA: 0s - loss: 0.9711 - accuracy: 0.7093
# Epoch 53: val_loss did not improve from 1.00471
# 44/44 [==============================] - 1s 18ms/step - loss: 0.9649 - accuracy: 0.7111 - val_loss: 1.0386 - val_accuracy: 0.6848
# Epoch 54/150
# 41/44 [==========================>...] - ETA: 0s - loss: 0.9653 - accuracy: 0.7146
# Epoch 54: val_loss did not improve from 1.00471
# 44/44 [==============================] - 1s 18ms/step - loss: 0.9717 - accuracy: 0.7134 - val_loss: 1.0578 - val_accuracy: 0.6636
# Epoch 55/150
# 41/44 [==========================>...] - ETA: 0s - loss: 0.9660 - accuracy: 0.7173
# Epoch 55: val_loss improved from 1.00471 to 1.00107, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 29ms/step - loss: 0.9705 - accuracy: 0.7150 - val_loss: 1.0011 - val_accuracy: 0.6949
# Epoch 56/150
# 41/44 [==========================>...] - ETA: 0s - loss: 0.9376 - accuracy: 0.7224
# Epoch 56: val_loss improved from 1.00107 to 0.99599, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 27ms/step - loss: 0.9417 - accuracy: 0.7228 - val_loss: 0.9960 - val_accuracy: 0.7051
# Epoch 57/150
# 43/44 [============================>.] - ETA: 0s - loss: 0.9307 - accuracy: 0.7363
# Epoch 57: val_loss did not improve from 0.99599
# 44/44 [==============================] - 1s 18ms/step - loss: 0.9308 - accuracy: 0.7362 - val_loss: 1.0171 - val_accuracy: 0.6959
# Epoch 58/150
# 41/44 [==========================>...] - ETA: 0s - loss: 0.9295 - accuracy: 0.7273
# Epoch 58: val_loss improved from 0.99599 to 0.97575, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 31ms/step - loss: 0.9292 - accuracy: 0.7291 - val_loss: 0.9758 - val_accuracy: 0.7051
# Epoch 59/150
# 41/44 [==========================>...] - ETA: 0s - loss: 0.9374 - accuracy: 0.7259
# Epoch 59: val_loss did not improve from 0.97575
# 44/44 [==============================] - 1s 17ms/step - loss: 0.9340 - accuracy: 0.7268 - val_loss: 1.0074 - val_accuracy: 0.7088
# Epoch 60/150
# 42/44 [===========================>..] - ETA: 0s - loss: 0.9472 - accuracy: 0.7348
# Epoch 60: val_loss did not improve from 0.97575
# 44/44 [==============================] - 1s 18ms/step - loss: 0.9481 - accuracy: 0.7344 - val_loss: 1.1274 - val_accuracy: 0.6710
# Epoch 61/150
# 41/44 [==========================>...] - ETA: 0s - loss: 0.9400 - accuracy: 0.7322
# Epoch 61: val_loss did not improve from 0.97575
# 44/44 [==============================] - 1s 19ms/step - loss: 0.9373 - accuracy: 0.7335 - val_loss: 0.9957 - val_accuracy: 0.7152
# Epoch 62/150
# 42/44 [===========================>..] - ETA: 0s - loss: 0.8950 - accuracy: 0.7452
# Epoch 62: val_loss improved from 0.97575 to 0.96963, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 33ms/step - loss: 0.8987 - accuracy: 0.7438 - val_loss: 0.9696 - val_accuracy: 0.7235
# Epoch 63/150
# 41/44 [==========================>...] - ETA: 0s - loss: 0.9324 - accuracy: 0.7393
# Epoch 63: val_loss did not improve from 0.96963
# 44/44 [==============================] - 1s 19ms/step - loss: 0.9345 - accuracy: 0.7388 - val_loss: 0.9879 - val_accuracy: 0.7189
# Epoch 64/150
# 41/44 [==========================>...] - ETA: 0s - loss: 0.8935 - accuracy: 0.7588
# Epoch 64: val_loss improved from 0.96963 to 0.96656, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 27ms/step - loss: 0.8938 - accuracy: 0.7579 - val_loss: 0.9666 - val_accuracy: 0.7161
# Epoch 65/150
# 43/44 [============================>.] - ETA: 0s - loss: 0.8555 - accuracy: 0.7667
# Epoch 65: val_loss improved from 0.96656 to 0.95721, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 29ms/step - loss: 0.8581 - accuracy: 0.7662 - val_loss: 0.9572 - val_accuracy: 0.7253
# Epoch 66/150
# 43/44 [============================>.] - ETA: 0s - loss: 0.8698 - accuracy: 0.7640
# Epoch 66: val_loss did not improve from 0.95721
# 44/44 [==============================] - 1s 18ms/step - loss: 0.8712 - accuracy: 0.7641 - val_loss: 1.0044 - val_accuracy: 0.7180
# Epoch 67/150
# 44/44 [==============================] - ETA: 0s - loss: 0.8894 - accuracy: 0.7650
# Epoch 67: val_loss did not improve from 0.95721
# 44/44 [==============================] - 1s 18ms/step - loss: 0.8894 - accuracy: 0.7650 - val_loss: 0.9612 - val_accuracy: 0.7272
# Epoch 68/150
# 44/44 [==============================] - ETA: 0s - loss: 0.8827 - accuracy: 0.7729
# Epoch 68: val_loss did not improve from 0.95721
# 44/44 [==============================] - 1s 18ms/step - loss: 0.8827 - accuracy: 0.7729 - val_loss: 0.9765 - val_accuracy: 0.7226
# Epoch 69/150
# 41/44 [==========================>...] - ETA: 0s - loss: 0.8672 - accuracy: 0.7763
# Epoch 69: val_loss did not improve from 0.95721
# 44/44 [==============================] - 1s 17ms/step - loss: 0.8694 - accuracy: 0.7766 - val_loss: 0.9882 - val_accuracy: 0.7244
# Epoch 70/150
# 44/44 [==============================] - ETA: 0s - loss: 0.9083 - accuracy: 0.7588
# Epoch 70: val_loss did not improve from 0.95721
# 44/44 [==============================] - 1s 18ms/step - loss: 0.9083 - accuracy: 0.7588 - val_loss: 0.9936 - val_accuracy: 0.7272
# Epoch 71/150
# 44/44 [==============================] - ETA: 0s - loss: 0.8664 - accuracy: 0.7740
# Epoch 71: val_loss improved from 0.95721 to 0.92549, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 27ms/step - loss: 0.8664 - accuracy: 0.7740 - val_loss: 0.9255 - val_accuracy: 0.7539
# Epoch 72/150
# 43/44 [============================>.] - ETA: 0s - loss: 0.9019 - accuracy: 0.7653
# Epoch 72: val_loss did not improve from 0.92549
# 44/44 [==============================] - 1s 18ms/step - loss: 0.9022 - accuracy: 0.7650 - val_loss: 0.9823 - val_accuracy: 0.7272
# Epoch 73/150
# 44/44 [==============================] - ETA: 0s - loss: 0.8451 - accuracy: 0.7876
# Epoch 73: val_loss did not improve from 0.92549
# 44/44 [==============================] - 1s 17ms/step - loss: 0.8451 - accuracy: 0.7876 - val_loss: 0.9503 - val_accuracy: 0.7244
# Epoch 74/150
# 44/44 [==============================] - ETA: 0s - loss: 0.9031 - accuracy: 0.7664
# Epoch 74: val_loss did not improve from 0.92549
# 44/44 [==============================] - 1s 19ms/step - loss: 0.9031 - accuracy: 0.7664 - val_loss: 0.9621 - val_accuracy: 0.7438
# Epoch 75/150
# 41/44 [==========================>...] - ETA: 0s - loss: 0.8476 - accuracy: 0.7849
# Epoch 75: val_loss did not improve from 0.92549
# 44/44 [==============================] - 1s 19ms/step - loss: 0.8502 - accuracy: 0.7837 - val_loss: 0.9268 - val_accuracy: 0.7594
# Epoch 76/150
# 43/44 [============================>.] - ETA: 0s - loss: 0.8306 - accuracy: 0.7981
# Epoch 76: val_loss did not improve from 0.92549
# 44/44 [==============================] - 1s 20ms/step - loss: 0.8297 - accuracy: 0.7987 - val_loss: 0.9638 - val_accuracy: 0.7548
# Epoch 77/150
# 42/44 [===========================>..] - ETA: 0s - loss: 0.8387 - accuracy: 0.8005
# Epoch 77: val_loss did not improve from 0.92549
# 44/44 [==============================] - 1s 20ms/step - loss: 0.8409 - accuracy: 0.7989 - val_loss: 0.9717 - val_accuracy: 0.7447
# Epoch 78/150
# 44/44 [==============================] - ETA: 0s - loss: 0.8365 - accuracy: 0.7969
# Epoch 78: val_loss did not improve from 0.92549
# 44/44 [==============================] - 1s 18ms/step - loss: 0.8365 - accuracy: 0.7969 - val_loss: 0.9966 - val_accuracy: 0.7493
# Epoch 79/150
# 43/44 [============================>.] - ETA: 0s - loss: 0.8280 - accuracy: 0.8121
# Epoch 79: val_loss improved from 0.92549 to 0.91676, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 27ms/step - loss: 0.8278 - accuracy: 0.8112 - val_loss: 0.9168 - val_accuracy: 0.7705
# Epoch 80/150
# 44/44 [==============================] - ETA: 0s - loss: 0.7953 - accuracy: 0.8204
# Epoch 80: val_loss did not improve from 0.91676
# 44/44 [==============================] - 1s 18ms/step - loss: 0.7953 - accuracy: 0.8204 - val_loss: 0.9226 - val_accuracy: 0.7806
# Epoch 81/150
# 41/44 [==========================>...] - ETA: 0s - loss: 0.8280 - accuracy: 0.8078
# Epoch 81: val_loss did not improve from 0.91676
# 44/44 [==============================] - 1s 17ms/step - loss: 0.8293 - accuracy: 0.8075 - val_loss: 0.9866 - val_accuracy: 0.7382
# Epoch 82/150
# 41/44 [==========================>...] - ETA: 0s - loss: 0.8112 - accuracy: 0.8176
# Epoch 82: val_loss did not improve from 0.91676
# 44/44 [==============================] - 1s 17ms/step - loss: 0.8088 - accuracy: 0.8181 - val_loss: 1.0120 - val_accuracy: 0.7585
# Epoch 83/150
# 41/44 [==========================>...] - ETA: 0s - loss: 0.8502 - accuracy: 0.8012
# Epoch 83: val_loss did not improve from 0.91676
# 44/44 [==============================] - 1s 18ms/step - loss: 0.8531 - accuracy: 0.8003 - val_loss: 0.9894 - val_accuracy: 0.7742
# Epoch 84/150
# 41/44 [==========================>...] - ETA: 0s - loss: 0.8358 - accuracy: 0.8146
# Epoch 84: val_loss did not improve from 0.91676
# 44/44 [==============================] - 1s 17ms/step - loss: 0.8346 - accuracy: 0.8148 - val_loss: 0.9377 - val_accuracy: 0.7779
# Epoch 85/150
# 41/44 [==========================>...] - ETA: 0s - loss: 0.7938 - accuracy: 0.8346
# Epoch 85: val_loss did not improve from 0.91676
# 44/44 [==============================] - 1s 18ms/step - loss: 0.7904 - accuracy: 0.8354 - val_loss: 0.9205 - val_accuracy: 0.7705
# Epoch 86/150
# 43/44 [============================>.] - ETA: 0s - loss: 0.8209 - accuracy: 0.8270
# Epoch 86: val_loss did not improve from 0.91676
# 44/44 [==============================] - 1s 18ms/step - loss: 0.8221 - accuracy: 0.8271 - val_loss: 0.9904 - val_accuracy: 0.7392
# Epoch 87/150
# 41/44 [==========================>...] - ETA: 0s - loss: 0.8321 - accuracy: 0.8210
# Epoch 87: val_loss did not improve from 0.91676
# 44/44 [==============================] - 1s 17ms/step - loss: 0.8272 - accuracy: 0.8227 - val_loss: 1.0034 - val_accuracy: 0.7530
# Epoch 88/150
# 41/44 [==========================>...] - ETA: 0s - loss: 0.7838 - accuracy: 0.8380
# Epoch 88: val_loss did not improve from 0.91676
# 44/44 [==============================] - 1s 17ms/step - loss: 0.7847 - accuracy: 0.8374 - val_loss: 0.9848 - val_accuracy: 0.7788
# Epoch 89/150
# 44/44 [==============================] - ETA: 0s - loss: 0.8154 - accuracy: 0.8342
# Epoch 89: val_loss did not improve from 0.91676
# 44/44 [==============================] - 1s 18ms/step - loss: 0.8154 - accuracy: 0.8342 - val_loss: 1.0421 - val_accuracy: 0.7429
# Epoch 90/150
# 41/44 [==========================>...] - ETA: 0s - loss: 0.8763 - accuracy: 0.8068
# Epoch 90: val_loss did not improve from 0.91676
# 44/44 [==============================] - 1s 19ms/step - loss: 0.8764 - accuracy: 0.8068 - val_loss: 0.9657 - val_accuracy: 0.7954
# Epoch 91/150
# 44/44 [==============================] - ETA: 0s - loss: 0.7845 - accuracy: 0.8485
# Epoch 91: val_loss improved from 0.91676 to 0.91593, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 2s 37ms/step - loss: 0.7845 - accuracy: 0.8485 - val_loss: 0.9159 - val_accuracy: 0.8055
# Epoch 92/150
# 44/44 [==============================] - ETA: 0s - loss: 0.7579 - accuracy: 0.8564
# Epoch 92: val_loss did not improve from 0.91593
# 44/44 [==============================] - 1s 20ms/step - loss: 0.7579 - accuracy: 0.8564 - val_loss: 0.9722 - val_accuracy: 0.7843
# Epoch 93/150
# 43/44 [============================>.] - ETA: 0s - loss: 0.7728 - accuracy: 0.8535
# Epoch 93: val_loss improved from 0.91593 to 0.87403, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 27ms/step - loss: 0.7720 - accuracy: 0.8538 - val_loss: 0.8740 - val_accuracy: 0.8175
# Epoch 94/150
# 41/44 [==========================>...] - ETA: 0s - loss: 0.7209 - accuracy: 0.8839
# Epoch 94: val_loss did not improve from 0.87403
# 44/44 [==============================] - 1s 18ms/step - loss: 0.7172 - accuracy: 0.8849 - val_loss: 0.8940 - val_accuracy: 0.8074
# Epoch 95/150
# 43/44 [============================>.] - ETA: 0s - loss: 0.7316 - accuracy: 0.8770
# Epoch 95: val_loss did not improve from 0.87403
# 44/44 [==============================] - 1s 18ms/step - loss: 0.7305 - accuracy: 0.8776 - val_loss: 0.9337 - val_accuracy: 0.8037
# Epoch 96/150
# 44/44 [==============================] - ETA: 0s - loss: 0.7618 - accuracy: 0.8600
# Epoch 96: val_loss did not improve from 0.87403
# 44/44 [==============================] - 1s 18ms/step - loss: 0.7618 - accuracy: 0.8600 - val_loss: 0.9019 - val_accuracy: 0.8249
# Epoch 97/150
# 44/44 [==============================] - ETA: 0s - loss: 0.7757 - accuracy: 0.8603
# Epoch 97: val_loss did not improve from 0.87403
# 44/44 [==============================] - 1s 18ms/step - loss: 0.7757 - accuracy: 0.8603 - val_loss: 0.9438 - val_accuracy: 0.7982
# Epoch 98/150
# 41/44 [==========================>...] - ETA: 0s - loss: 0.7453 - accuracy: 0.8727
# Epoch 98: val_loss improved from 0.87403 to 0.84712, saving model to saved_models/audio_classification_vggish.hdf5
# 44/44 [==============================] - 1s 28ms/step - loss: 0.7506 - accuracy: 0.8713 - val_loss: 0.8471 - val_accuracy: 0.8369
# Epoch 99/150
# 41/44 [==========================>...] - ETA: 0s - loss: 0.7535 - accuracy: 0.8759
# Epoch 99: val_loss did not improve from 0.84712
# 44/44 [==============================] - 1s 18ms/step - loss: 0.7540 - accuracy: 0.8748 - val_loss: 0.9657 - val_accuracy: 0.8046
# Epoch 100/150
# 44/44 [==============================] - ETA: 0s - loss: 0.7258 - accuracy: 0.8916
# Epoch 100: val_loss did not improve from 0.84712
# 44/44 [==============================] - 1s 18ms/step - loss: 0.7258 - accuracy: 0.8916 - val_loss: 0.8745 - val_accuracy: 0.8295
# Epoch 101/150
# 44/44 [==============================] - ETA: 0s - loss: 0.7188 - accuracy: 0.8879
# Epoch 101: val_loss did not improve from 0.84712
# 44/44 [==============================] - 1s 18ms/step - loss: 0.7188 - accuracy: 0.8879 - val_loss: 1.0197 - val_accuracy: 0.7926
# Epoch 102/150
# 41/44 [==========================>...] - ETA: 0s - loss: 0.7463 - accuracy: 0.8795
# Epoch 102: val_loss did not improve from 0.84712
# 44/44 [==============================] - 1s 18ms/step - loss: 0.7506 - accuracy: 0.8787 - val_loss: 0.8888 - val_accuracy: 0.8406
# Epoch 103/150
# 41/44 [==========================>...] - ETA: 0s - loss: 0.6812 - accuracy: 0.9095
# Epoch 103: val_loss did not improve from 0.84712
# 44/44 [==============================] - 1s 18ms/step - loss: 0.6836 - accuracy: 0.9087 - val_loss: 0.8700 - val_accuracy: 0.8387
# Epoch 104/150
# 43/44 [============================>.] - ETA: 0s - loss: 0.6892 - accuracy: 0.8993
# Epoch 104: val_loss did not improve from 0.84712
# 44/44 [==============================] - 1s 19ms/step - loss: 0.6890 - accuracy: 0.8992 - val_loss: 0.9329 - val_accuracy: 0.8212
# Epoch 105/150
# 41/44 [==========================>...] - ETA: 0s - loss: 0.7844 - accuracy: 0.8680
# Epoch 105: val_loss did not improve from 0.84712
# 44/44 [==============================] - 1s 20ms/step - loss: 0.7890 - accuracy: 0.8644 - val_loss: 0.9504 - val_accuracy: 0.8138
# Epoch 106/150
# 44/44 [==============================] - ETA: 0s - loss: 0.6963 - accuracy: 0.9117
# Epoch 106: val_loss did not improve from 0.84712
# 44/44 [==============================] - 1s 20ms/step - loss: 0.6963 - accuracy: 0.9117 - val_loss: 0.9071 - val_accuracy: 0.8258
# Epoch 107/150
# 43/44 [============================>.] - ETA: 0s - loss: 0.7002 - accuracy: 0.9040
# Epoch 107: val_loss did not improve from 0.84712
# 44/44 [==============================] - 1s 20ms/step - loss: 0.7030 - accuracy: 0.9034 - val_loss: 0.8493 - val_accuracy: 0.8479
# Epoch 108/150
# 41/44 [==========================>...] - ETA: 0s - loss: 0.6519 - accuracy: 0.9212
# Epoch 108: val_loss did not improve from 0.84712
# 44/44 [==============================] - 1s 18ms/step - loss: 0.6510 - accuracy: 0.9211 - val_loss: 0.8654 - val_accuracy: 0.8535
# Epoch 109/150
# 41/44 [==========================>...] - ETA: 0s - loss: 0.6612 - accuracy: 0.9154
# Epoch 109: val_loss did not improve from 0.84712
# 44/44 [==============================] - 1s 18ms/step - loss: 0.6621 - accuracy: 0.9154 - val_loss: 0.9505 - val_accuracy: 0.8249
# Epoch 110/150
# 44/44 [==============================] - ETA: 0s - loss: 0.6689 - accuracy: 0.9151
# Epoch 110: val_loss did not improve from 0.84712
# 44/44 [==============================] - 1s 18ms/step - loss: 0.6689 - accuracy: 0.9151 - val_loss: 0.9213 - val_accuracy: 0.8313
# Epoch 111/150
# 41/44 [==========================>...] - ETA: 0s - loss: 0.6958 - accuracy: 0.9083
# Epoch 111: val_loss did not improve from 0.84712
# 44/44 [==============================] - 1s 18ms/step - loss: 0.7007 - accuracy: 0.9066 - val_loss: 0.8819 - val_accuracy: 0.8433
# Epoch 112/150
# 44/44 [==============================] - ETA: 0s - loss: 0.6814 - accuracy: 0.9122
# Epoch 112: val_loss did not improve from 0.84712
# 44/44 [==============================] - 1s 18ms/step - loss: 0.6814 - accuracy: 0.9122 - val_loss: 0.8883 - val_accuracy: 0.8323
# Epoch 113/150
# 41/44 [==========================>...] - ETA: 0s - loss: 0.6595 - accuracy: 0.9210
# Epoch 113: val_loss did not improve from 0.84712
# 44/44 [==============================] - 1s 19ms/step - loss: 0.6602 - accuracy: 0.9202 - val_loss: 0.9093 - val_accuracy: 0.8396
# Training completed in time:  0:01:56.761711

# %%
test_accuracy=vggish_model.evaluate(X_test_vggish,y_test,verbose=0)
print(test_accuracy[1])
# Out:
# 0.8368663787841797

# %% [markdown]
# $\Large \color{#495867}{\texttt{GRU}}$

# %%
from keras.models import Sequential
from keras.layers import GRU, Dense, Dropout
from keras.callbacks import ModelCheckpoint, EarlyStopping

# Define GRU model
model_gru = Sequential()
model_gru.add(GRU(128, input_shape=(X_train.shape[1], 1), return_sequences=True))
model_gru.add(GRU(128))
model_gru.add(Dropout(0.5))
model_gru.add(Dense(num_labels, activation='softmax'))

model_gru.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model_gru.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 29, 128)           50304
#
#  gru_1 (GRU)                 (None, 128)               99072
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 150021 (586.02 KB)
# Trainable params: 150021 (586.02 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Add a dimension to input data for GRU
X_train_gru = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test_gru = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# Define checkpoint to save the best model
checkpointer_gru = ModelCheckpoint(filepath='saved_models/audio_classification_gru.hdf5', verbose=1, save_best_only=True)

# Implement early stopping based on validation loss
early_stopping_gru = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# %%
history_gru = model_gru.fit(X_train_gru, y_train, epochs=30, batch_size=35,validation_data=(X_test_gru, y_test),callbacks=[checkpointer_gru, early_stopping_gru])
# Out:
# Epoch 1/30
# 120/124 [============================>.] - ETA: 0s - loss: 1.5883 - accuracy: 0.2679
# Epoch 1: val_loss improved from inf to 1.54841, saving model to saved_models/audio_classification_gru.hdf5
# 124/124 [==============================] - 6s 18ms/step - loss: 1.5870 - accuracy: 0.2679 - val_loss: 1.5484 - val_accuracy: 0.2774
# Epoch 2/30
# 118/124 [===========================>..] - ETA: 0s - loss: 1.5355 - accuracy: 0.3119
# Epoch 2: val_loss improved from 1.54841 to 1.47325, saving model to saved_models/audio_classification_gru.hdf5
# 124/124 [==============================] - 1s 10ms/step - loss: 1.5347 - accuracy: 0.3120 - val_loss: 1.4732 - val_accuracy: 0.3336
# Epoch 3/30
# 117/124 [===========================>..] - ETA: 0s - loss: 1.4613 - accuracy: 0.3587
# Epoch 3: val_loss improved from 1.47325 to 1.46287, saving model to saved_models/audio_classification_gru.hdf5
# 124/124 [==============================] - 1s 8ms/step - loss: 1.4586 - accuracy: 0.3602 - val_loss: 1.4629 - val_accuracy: 0.3760
# Epoch 4/30
# 118/124 [===========================>..] - ETA: 0s - loss: 1.3658 - accuracy: 0.4264
# Epoch 4: val_loss improved from 1.46287 to 1.21406, saving model to saved_models/audio_classification_gru.hdf5
# 124/124 [==============================] - 1s 8ms/step - loss: 1.3576 - accuracy: 0.4300 - val_loss: 1.2141 - val_accuracy: 0.4737
# Epoch 5/30
# 124/124 [==============================] - ETA: 0s - loss: 1.1624 - accuracy: 0.5225
# Epoch 5: val_loss improved from 1.21406 to 0.95386, saving model to saved_models/audio_classification_gru.hdf5
# 124/124 [==============================] - 1s 8ms/step - loss: 1.1624 - accuracy: 0.5225 - val_loss: 0.9539 - val_accuracy: 0.6203
# Epoch 6/30
# 118/124 [===========================>..] - ETA: 0s - loss: 0.9626 - accuracy: 0.6157
# Epoch 6: val_loss improved from 0.95386 to 0.84170, saving model to saved_models/audio_classification_gru.hdf5
# 124/124 [==============================] - 1s 7ms/step - loss: 0.9648 - accuracy: 0.6161 - val_loss: 0.8417 - val_accuracy: 0.6618
# Epoch 7/30
# 121/124 [============================>.] - ETA: 0s - loss: 0.8153 - accuracy: 0.6850
# Epoch 7: val_loss improved from 0.84170 to 0.76964, saving model to saved_models/audio_classification_gru.hdf5
# 124/124 [==============================] - 1s 8ms/step - loss: 0.8156 - accuracy: 0.6846 - val_loss: 0.7696 - val_accuracy: 0.6940
# Epoch 8/30
# 122/124 [============================>.] - ETA: 0s - loss: 0.7040 - accuracy: 0.7283
# Epoch 8: val_loss improved from 0.76964 to 0.70701, saving model to saved_models/audio_classification_gru.hdf5
# 124/124 [==============================] - 1s 8ms/step - loss: 0.7041 - accuracy: 0.7284 - val_loss: 0.7070 - val_accuracy: 0.7106
# Epoch 9/30
# 123/124 [============================>.] - ETA: 0s - loss: 0.5945 - accuracy: 0.7777
# Epoch 9: val_loss improved from 0.70701 to 0.58678, saving model to saved_models/audio_classification_gru.hdf5
# 124/124 [==============================] - 1s 8ms/step - loss: 0.5941 - accuracy: 0.7780 - val_loss: 0.5868 - val_accuracy: 0.7806
# Epoch 10/30
# 123/124 [============================>.] - ETA: 0s - loss: 0.5174 - accuracy: 0.8100
# Epoch 10: val_loss improved from 0.58678 to 0.52857, saving model to saved_models/audio_classification_gru.hdf5
# 124/124 [==============================] - 1s 8ms/step - loss: 0.5175 - accuracy: 0.8095 - val_loss: 0.5286 - val_accuracy: 0.7926
# Epoch 11/30
# 123/124 [============================>.] - ETA: 0s - loss: 0.4338 - accuracy: 0.8479
# Epoch 11: val_loss improved from 0.52857 to 0.52419, saving model to saved_models/audio_classification_gru.hdf5
# 124/124 [==============================] - 1s 8ms/step - loss: 0.4323 - accuracy: 0.8485 - val_loss: 0.5242 - val_accuracy: 0.8028
# Epoch 12/30
# 116/124 [===========================>..] - ETA: 0s - loss: 0.3606 - accuracy: 0.8761
# Epoch 12: val_loss did not improve from 0.52419
# 124/124 [==============================] - 1s 8ms/step - loss: 0.3628 - accuracy: 0.8769 - val_loss: 0.5282 - val_accuracy: 0.8074
# Epoch 13/30
# 122/124 [============================>.] - ETA: 0s - loss: 0.3232 - accuracy: 0.8892
# Epoch 13: val_loss did not improve from 0.52419
# 124/124 [==============================] - 1s 10ms/step - loss: 0.3232 - accuracy: 0.8896 - val_loss: 0.5399 - val_accuracy: 0.8258
# Epoch 14/30
# 121/124 [============================>.] - ETA: 0s - loss: 0.2640 - accuracy: 0.9072
# Epoch 14: val_loss improved from 0.52419 to 0.46417, saving model to saved_models/audio_classification_gru.hdf5
# 124/124 [==============================] - 1s 10ms/step - loss: 0.2638 - accuracy: 0.9075 - val_loss: 0.4642 - val_accuracy: 0.8525
# Epoch 15/30
# 121/124 [============================>.] - ETA: 0s - loss: 0.2107 - accuracy: 0.9296
# Epoch 15: val_loss did not improve from 0.46417
# 124/124 [==============================] - 1s 9ms/step - loss: 0.2092 - accuracy: 0.9306 - val_loss: 0.4790 - val_accuracy: 0.8507
# Epoch 16/30
# 124/124 [==============================] - ETA: 0s - loss: 0.2058 - accuracy: 0.9331
# Epoch 16: val_loss did not improve from 0.46417
# 124/124 [==============================] - 1s 7ms/step - loss: 0.2058 - accuracy: 0.9331 - val_loss: 0.5393 - val_accuracy: 0.8258
# Epoch 17/30
# 122/124 [============================>.] - ETA: 0s - loss: 0.1775 - accuracy: 0.9450
# Epoch 17: val_loss improved from 0.46417 to 0.40726, saving model to saved_models/audio_classification_gru.hdf5
# 124/124 [==============================] - 1s 8ms/step - loss: 0.1788 - accuracy: 0.9447 - val_loss: 0.4073 - val_accuracy: 0.8673
# Epoch 18/30
# 122/124 [============================>.] - ETA: 0s - loss: 0.1373 - accuracy: 0.9541
# Epoch 18: val_loss did not improve from 0.40726
# 124/124 [==============================] - 1s 7ms/step - loss: 0.1383 - accuracy: 0.9537 - val_loss: 0.4677 - val_accuracy: 0.8608
# Epoch 19/30
# 119/124 [===========================>..] - ETA: 0s - loss: 0.1268 - accuracy: 0.9582
# Epoch 19: val_loss did not improve from 0.40726
# 124/124 [==============================] - 1s 8ms/step - loss: 0.1281 - accuracy: 0.9576 - val_loss: 0.4274 - val_accuracy: 0.8747
# Epoch 20/30
# 121/124 [============================>.] - ETA: 0s - loss: 0.1049 - accuracy: 0.9667
# Epoch 20: val_loss did not improve from 0.40726
# 124/124 [==============================] - 1s 8ms/step - loss: 0.1048 - accuracy: 0.9663 - val_loss: 0.4520 - val_accuracy: 0.8673
# Epoch 21/30
# 119/124 [===========================>..] - ETA: 0s - loss: 0.1050 - accuracy: 0.9676
# Epoch 21: val_loss did not improve from 0.40726
# 124/124 [==============================] - 1s 8ms/step - loss: 0.1050 - accuracy: 0.9677 - val_loss: 0.4465 - val_accuracy: 0.8765
# Epoch 22/30
# 121/124 [============================>.] - ETA: 0s - loss: 0.0818 - accuracy: 0.9740
# Epoch 22: val_loss did not improve from 0.40726
# 124/124 [==============================] - 1s 8ms/step - loss: 0.0828 - accuracy: 0.9735 - val_loss: 0.5167 - val_accuracy: 0.8553

# %%
test_accuracy=model_gru.evaluate(X_test_gru,y_test,verbose=0)
print(test_accuracy[1])
# Out:
# 0.8672810792922974

# %%
import matplotlib.pyplot as plt

def plot_metrics(history, title, save_path=None):
    plt.figure(figsize=(13, 6))

    # Plot accuracy
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Training Accuracy',color='#12130F')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy',color='#8FCB9B')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title(f'{title} - Accuracy')
    plt.legend()

    # Plot loss
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Training Loss',color='blue')
    plt.plot(history.history['val_loss'], label='Validation Loss',color='red')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title(f'{title} - Loss')
    plt.legend()

    plt.tight_layout()

    if save_path:
        plt.savefig(save_path)  # Save the figure in jpg format
    else:
        plt.show()

# Plot graphs for the original model
plot_metrics(history, 'Sequential', 'sequential_metrics.jpg')

# Plot graphs for the LSTM model
plot_metrics(history_lstm, 'LSTM', 'lstm_metrics.jpg')

# Plot graphs for the VGGish model
plot_metrics(history_vggish, 'VGGish', 'vggish_metrics.jpg')

plot_metrics(history_gru, 'GRU', 'gru_metrics.jpg')
